# %% [markdown]
# ## 단순한 계층 구현하기

# %% [markdown]
# 곱셈 계층

# %%
class MulLayer:
    def __init__(self):
        self.x = None
        self.y = None
    
    def forward(self, x, y):
        self.x = x
        self.y = y
        out = x * y

        return out
    
    def backward(self, dout):
        dx = dout * self.y # x와 y를 바꾼다
        dy = dout * self.x
        
        return dx, dy

# %%
apple = 100
apple_num = 2
tax = 1.1

mul_apple_layer = MulLayer()
mul_tax_layer = MulLayer()

apple_price = mul_apple_layer.forward(apple, apple_num)
price = mul_tax_layer.forward(apple_price, tax) ## 사실 이 부분을 `mul_apple_layer`로 구해도 전혀 상관이 없다는 거..

print(price)
# Out:
# 220.00000000000003

# %%
dprice = 1
dapple_price, dtax = mul_tax_layer.backward(dprice)
dapple, dapple_num = mul_apple_layer.backward(dapple_price)

print(dapple, dapple_num, dtax)
# Out:
# 2.2 110.00000000000001 200

# %% [markdown]
# 덧셈 계층

# %%
class AddLayer:
    def __init__(self):
        pass

    def forward(self, x, y):
        out = x + y
        return out
    
    def backward(self, dout):
        dx = dout * 1 ## 위 forward의 식을 미분하면 자기 자신의 계수가 나오는데 여기서는 1임
        dy = dout * 1
        return dx, dy

# %%
# 변수 초기화
apple = 100
apple_num = 2
orange = 150
orange_num = 3
tax = 1.1

# 각 계층 생성
mul_apple_layer = MulLayer()
mul_orange_layer = MulLayer()
add_apple_orange_layer = AddLayer()
mul_tax_layer = MulLayer()

# forward
apple_price = mul_apple_layer.forward(apple, apple_num)
orange_price = mul_orange_layer.forward(orange, orange_num)
all_price = add_apple_orange_layer.forward(apple_price, orange_price)
price = mul_tax_layer.forward(all_price, tax)

# backward
dprice = 1
dall_price, dtax = mul_tax_layer.backward(dprice)
dapple_price, dorange_price = add_apple_orange_layer.backward(dall_price)
dapple, dapple_num = mul_apple_layer.backward(dapple_price)
dorange, dorange_num = mul_orange_layer.backward(dorange_price)

print(price)
print(dapple_num, dapple, dorange, dorange_num, dtax)
# Out:
# 715.0000000000001
# 110.00000000000001 2.2 3.3000000000000003 165.0 650

# %% [markdown]
# ## 활성화 함수 계층 구현하기

# %% [markdown]
# ReLU

# %%
class ReLU:
    def __init__(self):
        self.mask = None
    
    def forward(self, x):
        self.mask = (x <= 0)
        out = x.copy() ## 원본 arrary의 값이 변경되지 않을 수 있도록. 그래야 나중에 미분을 할 수 있음
        out[self.mask] = 0
        
        return out
    
    def backward(self, dout):
        dout[self.mask] = 0
        dx = dout ## 동일한 객체를 참조. 따라서 코드 가독성을 높이기 위한 작업으로 이해할 수 있음

        return dx

# %%
import numpy as np

x = np.array([[1.0, -0.5], [-2.0, 3.0]])
print(x)

mask = (x <= 0)
print(mask) ## 따라서 array의 값 중에서 0 이하인 값들을 전부 0으로 바꿀 수 있게 됨
# Out:
# [[ 1.  -0.5]
#  [-2.   3. ]]
# [[False  True]
#  [ True False]]

# %% [markdown]
# Sigmoid

# %%
class Sigmoid:
    def __init__(self):
        self.out = None

    def forward(self, x):
        out = 1 / (1 + np.exp(-x))
        self.out = out ## forward의 출력을 self.out에 저장해두기

        return out
    
    def backward(self, dout):
        dx = dout * (1.0 - self.out) * self.out ## forward의 출력을 이용하여 backward 계산하기

        return dx

# %% [markdown]
# ## Affine/Softmax 계층 구현하기

# %% [markdown]
# Affine 계층

# %%
X = np.random.rand(2)
W = np.random.rand(2, 3)
B = np.random.rand(3)

print(X.shape)
print(W.shape)
print(B.shape)

Y = np.dot(X, W) + B
print(Y)
# Out:
# (2,)
# (2, 3)
# (3,)
# [0.90018938 1.18194954 0.39798179]

# %% [markdown]
# 배치용 Affine 계층

# %%
X_dot_W = np.array([[0, 0, 0], [10, 10, 10]])
B = np.array([1,2,3])

print(X_dot_W)
print(X_dot_W + B) ## 편향은 배치 내 각 sample(data)에 공통적으로 더해진다
# Out:
# [[ 0  0  0]
#  [10 10 10]]
# [[ 1  2  3]
#  [11 12 13]]

# %%
dY = np.array([[1,2,3], [4,5,6]])
print(dY)

dB = np.sum(dY, axis=0) ## axis=0 이어야 행 단위로 합 연산이 가능
print(dB)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [5 7 9]

# %%
class Affine:
    def __init__(self, W, b):
        self.W = W
        self.b = b
        self.x = None
        self.dW = None
        self.db = None

    def forward(self, x):
        self.x = x
        out = np.dot(x, self.W) + self.b

        return out
    
    def backward(self, dout):
        ## 뺄셈이 가능하도록 원래 변수와의 차원을 맞춰서 미분 계수를 구해야 함
        dx = np.dot(dout, self.W.T)
        self.dW = np.dot(self.x.T, dout) ## 반환하지 않는 변수를 선언하는 이유는 무엇일까?
        self.db = np.sum(dout, axis=0)

        return dx

# %% [markdown]
# Softmax-with-Loss 계층

# %%
def softmax(x):
    if x.ndim == 2:
        x = x.T
        x = x - np.max(x, axis=0)
        y = np.exp(x) / np.sum(np.exp(x), axis=0)
        return y.T
    x = x - np.max(x)
    return np.exp(x) / np.sum(np.exp(x))

# %%
def cross_entropy_error(y, t):
    if y.ndim == 1:
        y = y.reshape(1, y.size)
        t = t.reshape(1, t.size)

    if y.size == t.size:
        t = t.argmax(axis=1)

    batch_size = y.shape[0]
    return -np.sum(np.log(y[np.arange(batch_size), t] + 1e-7)) / batch_size

# %%
class SoftmaxWithLoss:
    def __init__(self):
        self.loss = None
        self.y = None
        self.t = None
    
    def forward(self, x, t):
        self.t = t
        self.y = softmax(x)
        self.loss = cross_entropy_error(self.y, self.t)
        return self.loss
    
    def backward(self, dout=1):
        batch_size = self.t.shape[0]
        dx = (self.y - self.t) / batch_size
        return dx

# %% [markdown]
# ## 오차역전파법 구현하기

# %% [markdown]
# 오차역전파법을 이용한 신경망 구현하기

# %%
from collections import OrderedDict

# %%
def numerical_gradient(f, x):
    h = 1e-4
    grad = np.zeros_like(x)
    
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:
        idx = it.multi_index
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + h
        fxh1 = f(x)

        x[idx] = tmp_val - h
        fxh2 = f(x)

        grad[idx] = (fxh1-fxh2) / (2*h)
        x[idx] = tmp_val
        it.iternext()

    return grad

# %%
class TwoLayerNet:
    def __init__(self, input_size, hidden_size, output_size, weight_init_std=0.01):
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size) ## 어차피 0이므로 초기화 가중치를 곱할 필요가 없음
        self.params['W2'] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)

        self.layers = OrderedDict()
        self.layers['Affine1'] = Affine(self.params['W1'], self.params['b1'])
        self.layers['Relu1'] = ReLU()
        self.layers['Affine2'] = Affine(self.params['W2'], self.params['b2'])
        
        self.lastLayer = SoftmaxWithLoss()

    def predict(self, x):
        for layer in self.layers.values():
            x = layer.forward(x)
        return x
    
    def loss(self, x, t):
        y = self.predict(x)
        return self.lastLayer.forward(y, t)
    
    def accuracy(self, x, t):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        if t.ndim != 1: ## 원핫 벡터인 경우 값 하나로 변경해주는 과정
            t = np.argmax(t, axis=1)
        
        accuracy = np.sum(y == t) / float(x.shape[0])
        return accuracy
    
    def numerical_gradient(self, x, t):
        loss_W = lambda W: self.loss(x, t)

        grads = {}
        grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
        grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
        grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
        grads['b2'] = numerical_gradient(loss_W, self.params['b2'])
        return grads
    
    def gradient(self, x, t):
        self.loss(x, t)

        dout = 1
        dout = self.lastLayer.backward(dout)

        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)
        
        grads = {}
        grads['W1'] = self.layers['Affine1'].dW
        grads['b1'] = self.layers['Affine1'].db
        grads['W2'] = self.layers['Affine2'].dW
        grads['b2'] = self.layers['Affine2'].db

        return grads

# %% [markdown]
# 오차역전파법으로 구한 기울기 검증하기

# %%
## 여기에 나타난 오차값은 실행 시마다 달라짐
from dataset.mnist import load_mnist

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = TwoLayerNet(input_size=784, hidden_size=50, output_size=10)

x_batch = x_train[:3]
t_batch = t_train[:3]

grad_numerical = network.numerical_gradient(x_batch, t_batch)
grad_backprop = network.gradient(x_batch, t_batch)

for key in grad_numerical.keys():
    diff = np.average(np.abs(grad_backprop[key] - grad_numerical[key]))
    print(key + ":" + str(diff))
# Out:
# W1:4.2538532779391184e-10
# b1:2.5331802150654837e-09
# W2:6.208913918675607e-09
# b2:1.3971694101388986e-07

# %% [markdown]
# 오차역전파법을 사용한 학습 구현하기

# %%
from dataset.mnist import load_mnist
from tqdm.auto import tqdm
## 학습 시간이 무척 짧은 것을 알 수 있다.

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = TwoLayerNet(input_size=784, hidden_size=50, output_size=10)

iter_nums = 25000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size/batch_size, 1)

for i in tqdm(range(iter_nums)):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grad = network.gradient(x_batch, t_batch)

    for key in ('W1', 'b1', 'W2', 'b2'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        print(f"{i}th iter - train accuracy: {train_acc:.3f}%, test_accuracy: {test_acc:.3f}%")
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]
# 0th iter - train accuracy: 0.119%, test_accuracy: 0.116%
# 600th iter - train accuracy: 0.905%, test_accuracy: 0.907%
# 1200th iter - train accuracy: 0.924%, test_accuracy: 0.926%
# 1800th iter - train accuracy: 0.935%, test_accuracy: 0.936%
# 2400th iter - train accuracy: 0.944%, test_accuracy: 0.943%
# 3000th iter - train accuracy: 0.951%, test_accuracy: 0.950%
# 3600th iter - train accuracy: 0.957%, test_accuracy: 0.954%
# 4200th iter - train accuracy: 0.961%, test_accuracy: 0.957%
# 4800th iter - train accuracy: 0.965%, test_accuracy: 0.961%
# 5400th iter - train accuracy: 0.968%, test_accuracy: 0.964%
# 6000th iter - train accuracy: 0.971%, test_accuracy: 0.967%
# 6600th iter - train accuracy: 0.972%, test_accuracy: 0.968%
# 7200th iter - train accuracy: 0.975%, test_accuracy: 0.969%
# 7800th iter - train accuracy: 0.977%, test_accuracy: 0.971%
# 8400th iter - train accuracy: 0.978%, test_accuracy: 0.969%
# 9000th iter - train accuracy: 0.978%, test_accuracy: 0.971%
# 9600th iter - train accuracy: 0.979%, test_accuracy: 0.972%
# 10200th iter - train accuracy: 0.980%, test_accuracy: 0.972%
# 10800th iter - train accuracy: 0.982%, test_accuracy: 0.973%
# 11400th iter - train accuracy: 0.984%, test_accuracy: 0.973%
# 12000th iter - train accuracy: 0.984%, test_accuracy: 0.973%
# 12600th iter - train accuracy: 0.984%, test_accuracy: 0.974%
# 13200th iter - train accuracy: 0.985%, test_accuracy: 0.975%
# 13800th iter - train accuracy: 0.986%, test_accuracy: 0.974%
# 14400th iter - train accuracy: 0.987%, test_accuracy: 0.975%
# 15000th iter - train accuracy: 0.987%, test_accuracy: 0.975%
# 15600th iter - train accuracy: 0.987%, test_accuracy: 0.975%
# 16200th iter - train accuracy: 0.989%, test_accuracy: 0.975%
# 16800th iter - train accuracy: 0.986%, test_accuracy: 0.972%
# 17400th iter - train accuracy: 0.989%, test_accuracy: 0.974%
# 18000th iter - train accuracy: 0.990%, test_accuracy: 0.975%
# 18600th iter - train accuracy: 0.990%, test_accuracy: 0.975%
# 19200th iter - train accuracy: 0.990%, test_accuracy: 0.974%
# 19800th iter - train accuracy: 0.990%, test_accuracy: 0.976%
# 20400th iter - train accuracy: 0.991%, test_accuracy: 0.976%
# 21000th iter - train accuracy: 0.991%, test_accuracy: 0.975%
# 21600th iter - train accuracy: 0.992%, test_accuracy: 0.976%
# 22200th iter - train accuracy: 0.991%, test_accuracy: 0.976%
# 22800th iter - train accuracy: 0.993%, test_accuracy: 0.977%
# 23400th iter - train accuracy: 0.992%, test_accuracy: 0.975%
# 24000th iter - train accuracy: 0.992%, test_accuracy: 0.975%
# 24600th iter - train accuracy: 0.993%, test_accuracy: 0.975%

# %%
from dataset.mnist import load_mnist
from tqdm.auto import tqdm
## 학습 시간이 무척 짧은 것을 알 수 있다.

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = TwoLayerNet(input_size=784, hidden_size=70, output_size=10)

iter_nums = 25000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
train_acc_list = []
test_acc_list_70 = []

iter_per_epoch = max(train_size/batch_size, 1)

for i in tqdm(range(iter_nums)):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grad = network.gradient(x_batch, t_batch)

    for key in ('W1', 'b1', 'W2', 'b2'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list_70.append(test_acc)
        print(f"{i}th iter - train accuracy: {train_acc:.3f}%, test_accuracy: {test_acc:.3f}%")
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]
# 0th iter - train accuracy: 0.081%, test_accuracy: 0.081%
# 600th iter - train accuracy: 0.908%, test_accuracy: 0.911%
# 1200th iter - train accuracy: 0.925%, test_accuracy: 0.928%
# 1800th iter - train accuracy: 0.938%, test_accuracy: 0.938%
# 2400th iter - train accuracy: 0.948%, test_accuracy: 0.946%
# 3000th iter - train accuracy: 0.954%, test_accuracy: 0.950%
# 3600th iter - train accuracy: 0.958%, test_accuracy: 0.955%
# 4200th iter - train accuracy: 0.962%, test_accuracy: 0.956%
# 4800th iter - train accuracy: 0.965%, test_accuracy: 0.961%
# 5400th iter - train accuracy: 0.969%, test_accuracy: 0.964%
# 6000th iter - train accuracy: 0.971%, test_accuracy: 0.965%
# 6600th iter - train accuracy: 0.974%, test_accuracy: 0.966%
# 7200th iter - train accuracy: 0.975%, test_accuracy: 0.967%
# 7800th iter - train accuracy: 0.975%, test_accuracy: 0.967%
# 8400th iter - train accuracy: 0.979%, test_accuracy: 0.969%
# 9000th iter - train accuracy: 0.981%, test_accuracy: 0.970%
# 9600th iter - train accuracy: 0.981%, test_accuracy: 0.970%
# 10200th iter - train accuracy: 0.982%, test_accuracy: 0.971%
# 10800th iter - train accuracy: 0.983%, test_accuracy: 0.971%
# 11400th iter - train accuracy: 0.984%, test_accuracy: 0.971%
# 12000th iter - train accuracy: 0.985%, test_accuracy: 0.971%
# 12600th iter - train accuracy: 0.987%, test_accuracy: 0.974%
# 13200th iter - train accuracy: 0.986%, test_accuracy: 0.973%
# 13800th iter - train accuracy: 0.987%, test_accuracy: 0.975%
# 14400th iter - train accuracy: 0.988%, test_accuracy: 0.973%
# 15000th iter - train accuracy: 0.989%, test_accuracy: 0.973%
# 15600th iter - train accuracy: 0.989%, test_accuracy: 0.974%
# 16200th iter - train accuracy: 0.990%, test_accuracy: 0.975%
# 16800th iter - train accuracy: 0.989%, test_accuracy: 0.972%
# 17400th iter - train accuracy: 0.990%, test_accuracy: 0.973%
# 18000th iter - train accuracy: 0.991%, test_accuracy: 0.974%
# 18600th iter - train accuracy: 0.991%, test_accuracy: 0.975%
# 19200th iter - train accuracy: 0.993%, test_accuracy: 0.974%
# 19800th iter - train accuracy: 0.993%, test_accuracy: 0.974%
# 20400th iter - train accuracy: 0.993%, test_accuracy: 0.974%
# 21000th iter - train accuracy: 0.992%, test_accuracy: 0.974%
# 21600th iter - train accuracy: 0.992%, test_accuracy: 0.973%
# 22200th iter - train accuracy: 0.993%, test_accuracy: 0.973%
# 22800th iter - train accuracy: 0.995%, test_accuracy: 0.976%
# 23400th iter - train accuracy: 0.995%, test_accuracy: 0.975%
# 24000th iter - train accuracy: 0.993%, test_accuracy: 0.972%
# 24600th iter - train accuracy: 0.994%, test_accuracy: 0.975%

# %%
from dataset.mnist import load_mnist
from tqdm.auto import tqdm
## 학습 시간이 무척 짧은 것을 알 수 있다.

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = TwoLayerNet(input_size=784, hidden_size=100, output_size=10)

iter_nums = 25000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
train_acc_list = []
test_acc_list_100 = []

iter_per_epoch = max(train_size/batch_size, 1)

for i in tqdm(range(iter_nums)):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grad = network.gradient(x_batch, t_batch)

    for key in ('W1', 'b1', 'W2', 'b2'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list_100.append(test_acc)
        print(f"{i}th iter - train accuracy: {train_acc:.3f}%, test_accuracy: {test_acc:.3f}%")
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]
# 0th iter - train accuracy: 0.086%, test_accuracy: 0.087%
# 600th iter - train accuracy: 0.905%, test_accuracy: 0.909%
# 1200th iter - train accuracy: 0.925%, test_accuracy: 0.928%
# 1800th iter - train accuracy: 0.938%, test_accuracy: 0.938%
# 2400th iter - train accuracy: 0.950%, test_accuracy: 0.947%
# 3000th iter - train accuracy: 0.955%, test_accuracy: 0.953%
# 3600th iter - train accuracy: 0.961%, test_accuracy: 0.957%
# 4200th iter - train accuracy: 0.965%, test_accuracy: 0.960%
# 4800th iter - train accuracy: 0.967%, test_accuracy: 0.964%
# 5400th iter - train accuracy: 0.972%, test_accuracy: 0.966%
# 6000th iter - train accuracy: 0.973%, test_accuracy: 0.965%
# 6600th iter - train accuracy: 0.977%, test_accuracy: 0.969%
# 7200th iter - train accuracy: 0.979%, test_accuracy: 0.972%
# 7800th iter - train accuracy: 0.980%, test_accuracy: 0.972%
# 8400th iter - train accuracy: 0.982%, test_accuracy: 0.972%
# 9000th iter - train accuracy: 0.982%, test_accuracy: 0.973%
# 9600th iter - train accuracy: 0.984%, test_accuracy: 0.972%
# 10200th iter - train accuracy: 0.984%, test_accuracy: 0.972%
# 10800th iter - train accuracy: 0.986%, test_accuracy: 0.974%
# 11400th iter - train accuracy: 0.986%, test_accuracy: 0.974%
# 12000th iter - train accuracy: 0.987%, test_accuracy: 0.975%
# 12600th iter - train accuracy: 0.988%, test_accuracy: 0.975%
# 13200th iter - train accuracy: 0.989%, test_accuracy: 0.975%
# 13800th iter - train accuracy: 0.987%, test_accuracy: 0.973%
# 14400th iter - train accuracy: 0.991%, test_accuracy: 0.975%
# 15000th iter - train accuracy: 0.991%, test_accuracy: 0.976%
# 15600th iter - train accuracy: 0.992%, test_accuracy: 0.976%
# 16200th iter - train accuracy: 0.991%, test_accuracy: 0.976%
# 16800th iter - train accuracy: 0.992%, test_accuracy: 0.977%
# 17400th iter - train accuracy: 0.993%, test_accuracy: 0.976%
# 18000th iter - train accuracy: 0.994%, test_accuracy: 0.976%
# 18600th iter - train accuracy: 0.994%, test_accuracy: 0.977%
# 19200th iter - train accuracy: 0.994%, test_accuracy: 0.976%
# 19800th iter - train accuracy: 0.994%, test_accuracy: 0.976%
# 20400th iter - train accuracy: 0.994%, test_accuracy: 0.976%
# 21000th iter - train accuracy: 0.995%, test_accuracy: 0.977%
# 21600th iter - train accuracy: 0.995%, test_accuracy: 0.976%
# 22200th iter - train accuracy: 0.996%, test_accuracy: 0.978%
# 22800th iter - train accuracy: 0.996%, test_accuracy: 0.977%
# 23400th iter - train accuracy: 0.996%, test_accuracy: 0.977%
# 24000th iter - train accuracy: 0.996%, test_accuracy: 0.977%
# 24600th iter - train accuracy: 0.997%, test_accuracy: 0.977%

# %%
print(f"x_train: {len(x_train)}")
print(f"t_train: {len(t_train)}")
print(f"x_test: {len(x_test)}")
print(f"t_test: {len(t_test)}")
# Out:
# x_train: 60000
# t_train: 60000
# x_test: 10000
# t_test: 10000

# %%
import matplotlib.pyplot as plt


fig, (ax1, ax2) = plt.subplots(1,2)
fig.set_figheight(7)
fig.set_figwidth(15)

ax1.plot(np.arange(0, 20000, 600), test_acc_list, color='blue')
ax1.plot(np.arange(0, 20000, 600), test_acc_list_70, color='red')
ax1.plot(np.arange(0, 20000, 600), test_acc_list_100, color='green')

ax2.plot(np.arange(0, 20000, 600), test_acc_list, color='blue')
ax2.plot(np.arange(0, 20000, 600), test_acc_list_70, color='red')
ax2.plot(np.arange(0, 20000, 600), test_acc_list_100, color='green')
ax2.set_ylim(0.965, 0.979, 0.001)
ax2.set_yticks(np.arange(0.965, 0.979, 0.001))


plt.show()
# Out:
# /var/folders/hn/nrs0d2b91f1f7jdk9wdd8yfc0000gn/T/ipykernel_1140/2770030002.py:15: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax2.set_ylim(0.965, 0.979, 0.001)

# %%
from dataset.mnist import load_mnist
from tqdm.auto import tqdm
## 학습 시간이 무척 짧은 것을 알 수 있다.

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = TwoLayerNet(input_size=784, hidden_size=50, output_size=10)

iter_nums = 25000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size/batch_size, 1)

for i in tqdm(range(iter_nums)):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grad = network.gradient(x_batch, t_batch)

    for key in ('W1', 'b1', 'W2', 'b2'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        print(f"{i}th iter - train accuracy: {train_acc:.3f}%, test_accuracy: {test_acc:.3f}%")
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]
# 0th iter - train accuracy: 0.108%, test_accuracy: 0.103%
# 600th iter - train accuracy: 0.904%, test_accuracy: 0.908%
# 1200th iter - train accuracy: 0.922%, test_accuracy: 0.925%
# 1800th iter - train accuracy: 0.936%, test_accuracy: 0.937%
# 2400th iter - train accuracy: 0.944%, test_accuracy: 0.941%
# 3000th iter - train accuracy: 0.953%, test_accuracy: 0.950%
# 3600th iter - train accuracy: 0.957%, test_accuracy: 0.955%
# 4200th iter - train accuracy: 0.960%, test_accuracy: 0.957%
# 4800th iter - train accuracy: 0.964%, test_accuracy: 0.961%
# 5400th iter - train accuracy: 0.969%, test_accuracy: 0.962%
# 6000th iter - train accuracy: 0.968%, test_accuracy: 0.964%
# 6600th iter - train accuracy: 0.970%, test_accuracy: 0.964%
# 7200th iter - train accuracy: 0.974%, test_accuracy: 0.966%
# 7800th iter - train accuracy: 0.975%, test_accuracy: 0.967%
# 8400th iter - train accuracy: 0.977%, test_accuracy: 0.969%
# 9000th iter - train accuracy: 0.978%, test_accuracy: 0.968%
# 9600th iter - train accuracy: 0.979%, test_accuracy: 0.970%
# 10200th iter - train accuracy: 0.979%, test_accuracy: 0.969%
# 10800th iter - train accuracy: 0.981%, test_accuracy: 0.971%
# 11400th iter - train accuracy: 0.982%, test_accuracy: 0.971%
# 12000th iter - train accuracy: 0.983%, test_accuracy: 0.972%
# 12600th iter - train accuracy: 0.984%, test_accuracy: 0.972%
# 13200th iter - train accuracy: 0.984%, test_accuracy: 0.972%
# 13800th iter - train accuracy: 0.986%, test_accuracy: 0.974%
# 14400th iter - train accuracy: 0.985%, test_accuracy: 0.972%
# 15000th iter - train accuracy: 0.986%, test_accuracy: 0.972%
# 15600th iter - train accuracy: 0.987%, test_accuracy: 0.973%
# 16200th iter - train accuracy: 0.988%, test_accuracy: 0.972%
# 16800th iter - train accuracy: 0.988%, test_accuracy: 0.973%
# 17400th iter - train accuracy: 0.988%, test_accuracy: 0.973%
# 18000th iter - train accuracy: 0.989%, test_accuracy: 0.973%
# 18600th iter - train accuracy: 0.988%, test_accuracy: 0.973%
# 19200th iter - train accuracy: 0.990%, test_accuracy: 0.973%
# 19800th iter - train accuracy: 0.990%, test_accuracy: 0.973%
# 20400th iter - train accuracy: 0.990%, test_accuracy: 0.973%
# 21000th iter - train accuracy: 0.991%, test_accuracy: 0.974%
# 21600th iter - train accuracy: 0.992%, test_accuracy: 0.975%
# 22200th iter - train accuracy: 0.992%, test_accuracy: 0.974%
# 22800th iter - train accuracy: 0.992%, test_accuracy: 0.974%
# 23400th iter - train accuracy: 0.992%, test_accuracy: 0.973%
# 24000th iter - train accuracy: 0.993%, test_accuracy: 0.973%
# 24600th iter - train accuracy: 0.993%, test_accuracy: 0.975%

# %%
plt.plot(np.arange(0, 10000, 600), test_acc_list)
plt.show()

# %%
plt.plot(np.arange(0, 10000, 600), test_acc_list)
plt.ylim(0.9,1.0,0.005)
plt.show()
# Out:
# /var/folders/hn/nrs0d2b91f1f7jdk9wdd8yfc0000gn/T/ipykernel_18851/3066349409.py:2: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(0.9,1.0,0.005)

# %% [markdown]
# ### 레이어를 추가하면 어떻게 될까?
# 데이터의 개수는 충분하므로 모델의 복잡도를 늘려도 될 것 같다는 아이디어

# %%
class ThreeLayerNet:
    def __init__(self, input_size, hidden_size, output_size, weight_init_std=0.01):
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size) ## 어차피 0이므로 초기화 가중치를 곱할 필요가 없음
        self.params['W2'] = weight_init_std * np.random.randn(hidden_size, hidden_size)
        self.params['b2'] = np.zeros(hidden_size)
        self.params['W3'] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params['b3'] = np.zeros(output_size) ## 어차피 0이므로 초기화 가중치를 곱할 필요가 없음        

        self.layers = OrderedDict()
        self.layers['Affine1'] = Affine(self.params['W1'], self.params['b1'])
        self.layers['Relu1'] = ReLU()
        self.layers['Affine2'] = Affine(self.params['W2'], self.params['b2'])
        self.layers['Relu2'] = ReLU()
        self.layers['Affine3'] = Affine(self.params['W3'], self.params['b3'])
        
        self.lastLayer = SoftmaxWithLoss()

    def predict(self, x):
        for layer in self.layers.values():
            x = layer.forward(x)
        return x
    
    def loss(self, x, t):
        y = self.predict(x)
        return self.lastLayer.forward(y, t)
    
    def accuracy(self, x, t):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        if t.ndim != 1: ## 원핫 벡터인 경우 값 하나로 변경해주는 과정
            t = np.argmax(t, axis=1)
        
        accuracy = np.sum(y == t) / float(x.shape[0])
        return accuracy
    
    def numerical_gradient(self, x, t):
        loss_W = lambda W: self.loss(x, t)

        grads = {}
        grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
        grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
        grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
        grads['b2'] = numerical_gradient(loss_W, self.params['b2'])
        grads['W3'] = numerical_gradient(loss_W, self.params['W3'])
        grads['b3'] = numerical_gradient(loss_W, self.params['b3'])
        return grads
    
    def gradient(self, x, t):
        self.loss(x, t)

        dout = 1
        dout = self.lastLayer.backward(dout)

        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)
        
        grads = {}
        grads['W1'] = self.layers['Affine1'].dW
        grads['b1'] = self.layers['Affine1'].db
        grads['W2'] = self.layers['Affine2'].dW
        grads['b2'] = self.layers['Affine2'].db
        grads['W3'] = self.layers['Affine3'].dW
        grads['b3'] = self.layers['Affine3'].db

        return grads

# %%
from dataset.mnist import load_mnist
from tqdm.auto import tqdm
## 학습 시간이 무척 짧은 것을 알 수 있다.

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = ThreeLayerNet(input_size=784, hidden_size=50, output_size=10)

iter_nums = 25000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
train_acc_list_three_50 = []
test_acc_list_three_50 = []

iter_per_epoch = max(train_size/batch_size, 1)

for i in tqdm(range(iter_nums)):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grad = network.gradient(x_batch, t_batch)

    for key in ('W1', 'b1', 'W2', 'b2', 'W3', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list_three_50.append(train_acc)
        test_acc_list_three_50.append(test_acc)
        print(f"{i}th iter - train accuracy: {train_acc:.3f}%, test_accuracy: {test_acc:.3f}%")
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]
# 0th iter - train accuracy: 0.099%, test_accuracy: 0.101%
# 600th iter - train accuracy: 0.733%, test_accuracy: 0.739%
# 1200th iter - train accuracy: 0.894%, test_accuracy: 0.893%
# 1800th iter - train accuracy: 0.926%, test_accuracy: 0.925%
# 2400th iter - train accuracy: 0.939%, test_accuracy: 0.941%
# 3000th iter - train accuracy: 0.952%, test_accuracy: 0.949%
# 3600th iter - train accuracy: 0.962%, test_accuracy: 0.958%
# 4200th iter - train accuracy: 0.965%, test_accuracy: 0.959%
# 4800th iter - train accuracy: 0.972%, test_accuracy: 0.965%
# 5400th iter - train accuracy: 0.974%, test_accuracy: 0.969%
# 6000th iter - train accuracy: 0.973%, test_accuracy: 0.966%
# 6600th iter - train accuracy: 0.978%, test_accuracy: 0.967%
# 7200th iter - train accuracy: 0.981%, test_accuracy: 0.970%
# 7800th iter - train accuracy: 0.982%, test_accuracy: 0.971%
# 8400th iter - train accuracy: 0.984%, test_accuracy: 0.973%
# 9000th iter - train accuracy: 0.984%, test_accuracy: 0.968%
# 9600th iter - train accuracy: 0.984%, test_accuracy: 0.968%
# 10200th iter - train accuracy: 0.984%, test_accuracy: 0.968%
# 10800th iter - train accuracy: 0.986%, test_accuracy: 0.970%
# 11400th iter - train accuracy: 0.984%, test_accuracy: 0.969%
# 12000th iter - train accuracy: 0.986%, test_accuracy: 0.969%
# 12600th iter - train accuracy: 0.989%, test_accuracy: 0.974%
# 13200th iter - train accuracy: 0.991%, test_accuracy: 0.973%
# 13800th iter - train accuracy: 0.991%, test_accuracy: 0.973%
# 14400th iter - train accuracy: 0.992%, test_accuracy: 0.975%
# 15000th iter - train accuracy: 0.992%, test_accuracy: 0.974%
# 15600th iter - train accuracy: 0.992%, test_accuracy: 0.972%
# 16200th iter - train accuracy: 0.993%, test_accuracy: 0.973%
# 16800th iter - train accuracy: 0.992%, test_accuracy: 0.972%
# 17400th iter - train accuracy: 0.994%, test_accuracy: 0.973%
# 18000th iter - train accuracy: 0.994%, test_accuracy: 0.972%
# 18600th iter - train accuracy: 0.996%, test_accuracy: 0.975%
# 19200th iter - train accuracy: 0.995%, test_accuracy: 0.974%
# 19800th iter - train accuracy: 0.993%, test_accuracy: 0.970%
# 20400th iter - train accuracy: 0.995%, test_accuracy: 0.973%
# 21000th iter - train accuracy: 0.992%, test_accuracy: 0.968%
# 21600th iter - train accuracy: 0.995%, test_accuracy: 0.972%
# 22200th iter - train accuracy: 0.997%, test_accuracy: 0.974%
# 22800th iter - train accuracy: 0.997%, test_accuracy: 0.974%
# 23400th iter - train accuracy: 0.997%, test_accuracy: 0.972%
# 24000th iter - train accuracy: 0.998%, test_accuracy: 0.973%
# 24600th iter - train accuracy: 0.996%, test_accuracy: 0.973%

# %%
import matplotlib.pyplot as plt

plt.plot(np.arange(0, 20000, 600), test_acc_list, color='blue')
plt.plot(np.arange(0, 20000, 600), test_acc_list_70, color='red')
plt.plot(np.arange(0, 20000, 600), test_acc_list_100, color='green')
plt.plot(np.arange(0, 20000, 600), test_acc_list_three_50, color='black')
plt.ylim(0.965, 0.979, 0.001)
plt.yticks(np.arange(0.965, 0.979, 0.001))


plt.show()
# Out:
# /var/folders/hn/nrs0d2b91f1f7jdk9wdd8yfc0000gn/T/ipykernel_1140/3427928467.py:7: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(0.965, 0.979, 0.001)

# %%
from dataset.mnist import load_mnist
from tqdm.auto import tqdm
## 학습 시간이 무척 짧은 것을 알 수 있다.

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = ThreeLayerNet(input_size=784, hidden_size=70, output_size=10)

iter_nums = 25000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
train_acc_list_three_70 = []
test_acc_list_three_70 = []

iter_per_epoch = max(train_size/batch_size, 1)

for i in tqdm(range(iter_nums)):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grad = network.gradient(x_batch, t_batch)

    for key in ('W1', 'b1', 'W2', 'b2', 'W3', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list_three_70.append(train_acc)
        test_acc_list_three_70.append(test_acc)
        print(f"{i}th iter - train accuracy: {train_acc:.3f}%, test_accuracy: {test_acc:.3f}%")
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]
# 0th iter - train accuracy: 0.102%, test_accuracy: 0.103%
# 600th iter - train accuracy: 0.778%, test_accuracy: 0.787%
# 1200th iter - train accuracy: 0.895%, test_accuracy: 0.897%
# 1800th iter - train accuracy: 0.929%, test_accuracy: 0.929%
# 2400th iter - train accuracy: 0.950%, test_accuracy: 0.947%
# 3000th iter - train accuracy: 0.959%, test_accuracy: 0.953%
# 3600th iter - train accuracy: 0.965%, test_accuracy: 0.961%
# 4200th iter - train accuracy: 0.972%, test_accuracy: 0.965%
# 4800th iter - train accuracy: 0.973%, test_accuracy: 0.966%
# 5400th iter - train accuracy: 0.977%, test_accuracy: 0.969%
# 6000th iter - train accuracy: 0.977%, test_accuracy: 0.967%
# 6600th iter - train accuracy: 0.982%, test_accuracy: 0.971%
# 7200th iter - train accuracy: 0.984%, test_accuracy: 0.972%
# 7800th iter - train accuracy: 0.985%, test_accuracy: 0.971%
# 8400th iter - train accuracy: 0.986%, test_accuracy: 0.972%
# 9000th iter - train accuracy: 0.988%, test_accuracy: 0.973%
# 9600th iter - train accuracy: 0.988%, test_accuracy: 0.974%
# 10200th iter - train accuracy: 0.991%, test_accuracy: 0.976%
# 10800th iter - train accuracy: 0.990%, test_accuracy: 0.975%
# 11400th iter - train accuracy: 0.989%, test_accuracy: 0.974%
# 12000th iter - train accuracy: 0.991%, test_accuracy: 0.974%
# 12600th iter - train accuracy: 0.992%, test_accuracy: 0.976%
# 13200th iter - train accuracy: 0.993%, test_accuracy: 0.977%
# 13800th iter - train accuracy: 0.994%, test_accuracy: 0.975%
# 14400th iter - train accuracy: 0.993%, test_accuracy: 0.976%
# 15000th iter - train accuracy: 0.995%, test_accuracy: 0.977%
# 15600th iter - train accuracy: 0.995%, test_accuracy: 0.976%
# 16200th iter - train accuracy: 0.996%, test_accuracy: 0.978%
# 16800th iter - train accuracy: 0.993%, test_accuracy: 0.974%
# 17400th iter - train accuracy: 0.996%, test_accuracy: 0.976%
# 18000th iter - train accuracy: 0.997%, test_accuracy: 0.977%
# 18600th iter - train accuracy: 0.998%, test_accuracy: 0.978%
# 19200th iter - train accuracy: 0.998%, test_accuracy: 0.978%
# 19800th iter - train accuracy: 0.998%, test_accuracy: 0.977%
# 20400th iter - train accuracy: 0.997%, test_accuracy: 0.978%
# 21000th iter - train accuracy: 0.999%, test_accuracy: 0.978%
# 21600th iter - train accuracy: 0.999%, test_accuracy: 0.979%
# 22200th iter - train accuracy: 0.999%, test_accuracy: 0.977%
# 22800th iter - train accuracy: 0.999%, test_accuracy: 0.976%
# 23400th iter - train accuracy: 0.999%, test_accuracy: 0.977%
# 24000th iter - train accuracy: 0.999%, test_accuracy: 0.978%
# 24600th iter - train accuracy: 0.999%, test_accuracy: 0.978%

# %%
import matplotlib.pyplot as plt

plt.plot(np.arange(0, 20000, 600), test_acc_list, color='blue')
plt.plot(np.arange(0, 20000, 600), test_acc_list_70, color='red')
plt.plot(np.arange(0, 20000, 600), test_acc_list_100, color='green')
plt.plot(np.arange(0, 20000, 600), test_acc_list_three_50, color='black')
plt.plot(np.arange(0, 20000, 600), test_acc_list_three_70, color='yellow')
plt.ylim(0.965, 0.979, 0.001)
plt.yticks(np.arange(0.965, 0.979, 0.001))


plt.show()
# Out:
# /var/folders/hn/nrs0d2b91f1f7jdk9wdd8yfc0000gn/T/ipykernel_1140/3642857488.py:8: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(0.965, 0.979, 0.001)

# %%
from dataset.mnist import load_mnist
from tqdm.auto import tqdm
## 학습 시간이 무척 짧은 것을 알 수 있다.

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

network = ThreeLayerNet(input_size=784, hidden_size=100, output_size=10)

iter_nums = 25000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
train_acc_list_three_100 = []
test_acc_list_three_100 = []

iter_per_epoch = max(train_size/batch_size, 1)

for i in tqdm(range(iter_nums)):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grad = network.gradient(x_batch, t_batch)

    for key in ('W1', 'b1', 'W2', 'b2', 'W3', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list_three_100.append(train_acc)
        test_acc_list_three_100.append(test_acc)
        print(f"{i}th iter - train accuracy: {train_acc:.3f}%, test_accuracy: {test_acc:.3f}%")
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]
# 0th iter - train accuracy: 0.097%, test_accuracy: 0.097%
# 600th iter - train accuracy: 0.812%, test_accuracy: 0.815%
# 1200th iter - train accuracy: 0.911%, test_accuracy: 0.910%
# 1800th iter - train accuracy: 0.938%, test_accuracy: 0.936%
# 2400th iter - train accuracy: 0.955%, test_accuracy: 0.952%
# 3000th iter - train accuracy: 0.965%, test_accuracy: 0.961%
# 3600th iter - train accuracy: 0.970%, test_accuracy: 0.964%
# 4200th iter - train accuracy: 0.974%, test_accuracy: 0.967%
# 4800th iter - train accuracy: 0.978%, test_accuracy: 0.969%
# 5400th iter - train accuracy: 0.979%, test_accuracy: 0.970%
# 6000th iter - train accuracy: 0.982%, test_accuracy: 0.971%
# 6600th iter - train accuracy: 0.984%, test_accuracy: 0.973%
# 7200th iter - train accuracy: 0.984%, test_accuracy: 0.973%
# 7800th iter - train accuracy: 0.987%, test_accuracy: 0.975%
# 8400th iter - train accuracy: 0.989%, test_accuracy: 0.975%
# 9000th iter - train accuracy: 0.990%, test_accuracy: 0.975%
# 9600th iter - train accuracy: 0.990%, test_accuracy: 0.974%
# 10200th iter - train accuracy: 0.992%, test_accuracy: 0.977%
# 10800th iter - train accuracy: 0.993%, test_accuracy: 0.977%
# 11400th iter - train accuracy: 0.993%, test_accuracy: 0.976%
# 12000th iter - train accuracy: 0.994%, test_accuracy: 0.978%
# 12600th iter - train accuracy: 0.995%, test_accuracy: 0.977%
# 13200th iter - train accuracy: 0.996%, test_accuracy: 0.978%
# 13800th iter - train accuracy: 0.996%, test_accuracy: 0.977%
# 14400th iter - train accuracy: 0.996%, test_accuracy: 0.977%
# 15000th iter - train accuracy: 0.996%, test_accuracy: 0.978%
# 15600th iter - train accuracy: 0.997%, test_accuracy: 0.977%
# 16200th iter - train accuracy: 0.998%, test_accuracy: 0.978%
# 16800th iter - train accuracy: 0.998%, test_accuracy: 0.977%
# 17400th iter - train accuracy: 0.999%, test_accuracy: 0.979%
# 18000th iter - train accuracy: 0.998%, test_accuracy: 0.979%
# 18600th iter - train accuracy: 0.999%, test_accuracy: 0.979%
# 19200th iter - train accuracy: 0.999%, test_accuracy: 0.977%
# 19800th iter - train accuracy: 0.999%, test_accuracy: 0.979%
# 20400th iter - train accuracy: 0.998%, test_accuracy: 0.977%
# 21000th iter - train accuracy: 0.998%, test_accuracy: 0.976%
# 21600th iter - train accuracy: 1.000%, test_accuracy: 0.978%
# 22200th iter - train accuracy: 1.000%, test_accuracy: 0.978%
# 22800th iter - train accuracy: 1.000%, test_accuracy: 0.979%
# 23400th iter - train accuracy: 1.000%, test_accuracy: 0.979%
# 24000th iter - train accuracy: 1.000%, test_accuracy: 0.978%
# 24600th iter - train accuracy: 1.000%, test_accuracy: 0.978%

# %%
import matplotlib.pyplot as plt

plt.plot(np.arange(0, 25000, 600), test_acc_list, color='blue')
# plt.plot(np.arange(0, 25000, 600), test_acc_list_70, color='red')
# plt.plot(np.arange(0, 25000, 600), test_acc_list_100, color='green')
plt.plot(np.arange(0, 25000, 600), test_acc_list_three_50, color='blue', linestyle='--')
# plt.plot(np.arange(0, 25000, 600), test_acc_list_three_70, color='red', linestyle='--')
# plt.plot(np.arange(0, 25000, 600), test_acc_list_three_100, color='green', linestyle='--')

plt.ylim(0.965, 0.981, 0.001)
plt.yticks(np.arange(0.965, 0.981, 0.001))


plt.show()
# Out:
# /var/folders/hn/nrs0d2b91f1f7jdk9wdd8yfc0000gn/T/ipykernel_1140/1816060976.py:10: MatplotlibDeprecationWarning: Passing the emit parameter of set_ylim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.ylim(0.965, 0.981, 0.001)
