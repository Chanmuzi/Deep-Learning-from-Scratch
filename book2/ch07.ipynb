# %% [markdown]
# # RNN을 사용한 문장 생성
# ## 언어 모델을 사용한 문장 생성
# 문장 생성 구현

# %%
import numpy as np
from common.functions import softmax
import nbimporter
from ch06 import BetterRnnlm
from ch06 import Rnnlm

# %%
class RnnlmGen(Rnnlm):
    def generate(self, start_id, skip_ids=None, sample_size=100):
        word_ids = [start_id]

        x = start_id
        while len(word_ids) < sample_size:
            x = np.array(x).reshape(1, 1)
            score = self.predict(x)
            p = softmax(score.flatten())

            sampled = np.random.choice(len(p), size=1, p=p)
            if (skip_ids is None) or (sampled not in skip_ids):
                x = sampled
                word_ids.append(int(x))
            
        return word_ids

# %%
from dataset import ptb

corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)
corpus_size = len(corpus)

## 가중치 없는 경우
model = RnnlmGen()

start_word = 'you'
start_id = word_to_id[start_word]
skip_words = ['N', '<unk>', '$']
skip_ids = [word_to_id[w] for w in skip_words]

word_ids = model.generate(start_id, skip_ids)
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print(txt)
# Out:
# you frustrating kennedy asserted scottish measurements involve training eurodollars skinner highways novels ethnic fears reed hinted edgar unveiled honesty diplomats occur sponsor selling flamboyant beer missile repaid plane wishes jacobson practicing californians prepayment pfeiffer inside agents workout proper u.s. trim class thomson marlin fundamentals restructuring own ivory comptroller pain shakespeare responsive deloitte becoming luis cornell truth develop cray-3 republicans meantime millions credentials kick incumbent craze fossil displays stand serious me laurence death nov. soil poll mass-market productive plants ual brand clifford figured yielded belli compaq compelling breaks resolved performers undersecretary lay dynamics impose hong alvin beach deposits ranks quotations shelter

# %%
from dataset import ptb

corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)
corpus_size = len(corpus)

## 직접 학습한 가중치 불러오기
model = RnnlmGen()
model.load_params('Rnnlm.pkl')

start_word = 'you'
start_id = word_to_id[start_word]
skip_words = ['N', '<unk>', '$']
skip_ids = [word_to_id[w] for w in skip_words]

word_ids = model.generate(start_id, skip_ids)
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print(txt)
# Out:
# you pat personal beef fame loral yen palmer likelihood jeopardy businessland chasing indications kept explained concord annuities fans rarely stock bacteria dubbed four-year toxic searched afford adapted news straszheim guards relationship warsaw closes buy section approach reynolds leaped reception overall offsetting powerful impressed administrative minister relied external equitec founder treasury cray teachers fulfill dominion pan subscribe clearing desk grace supervision broadway sports removal gridlock pencils dominion incest columbus courter armco senate backlash officials historically alone notable revamping loud australia interests weaken detailed vickers ignorance bonus technique education mae hypothetical acknowledged derived indexing marginally fast-food northern cs exceeded newport manner roads

# %%
from dataset import ptb

corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)
corpus_size = len(corpus)

## 교재 가중치 불러오기
model = RnnlmGen()
model.load_params('Rnnlm_origin.pkl')

start_word = 'you'
start_id = word_to_id[start_word]
skip_words = ['N', '<unk>', '$']
skip_ids = [word_to_id[w] for w in skip_words]

word_ids = model.generate(start_id, skip_ids)
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print(txt)
# Out:
# you banknote stevenson notably colony patterns forward hired at&t aides roth australia decliners caterpillar abuse superior deployed calendar carolina failure rome balls rules largest booming advertised underlying rebuild volunteer billed cowboys variety economics columnist copy kkr towel boy norway 19th stephen exotic draft seoul nebraska civil consensus seniority privacy diplomatic probing undo developers out battered arbitragers examined cautious households psychological frustration publishers vetoed tomorrow recover recognized rage nfl steelmaker collar oy g. adjacent haul kenneth epa blocked al acts measurements story won debenture imminent beam taylor citizen revamping circuits bosses slump balls abandoned sea unfair solicitation brouwer corners transfers debates

# %% [markdown]
# 더 좋은 문장으로

# %%
class BetterRnnlmGen(BetterRnnlm):
    def generate(self, start_id, skip_ids=None, sample_size=100):
        word_ids = [start_id]

        x = start_id
        while len(word_ids) < sample_size:
            x = np.array(x).reshape(1, 1)
            score = self.predict(x).flatten()
            p = softmax(score).flatten()

            sampled = np.random.choice(len(p), size=1, p=p)
            if (skip_ids is None) or (sampled not in skip_ids):
                x = sampled
                word_ids.append(int(x))

        return word_ids

    def get_state(self):
        states = []
        for layer in self.lstm_layers:
            states.append((layer.h, layer.c))
        return states

    def set_state(self, states):
        for layer, state in zip(self.lstm_layers, states):
            layer.set_state(*state)

# %%
import sys
sys.path.append('..')
from common.np import *
from dataset import ptb


corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)
corpus_size = len(corpus)


model = BetterRnnlmGen()
model.load_params('./BetterRnnlm.pkl')

# start 문자와 skip 문자 설정
start_word = 'you'
start_id = word_to_id[start_word]
skip_words = ['N', '<unk>', '$']
skip_ids = [word_to_id[w] for w in skip_words]
# 문장 생성
word_ids = model.generate(start_id, skip_ids)
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')

print(txt)


model.reset_state()

start_words = 'the meaning of life is'
start_ids = [word_to_id[w] for w in start_words.split(' ')]

for x in start_ids[:-1]:
    x = np.array(x).reshape(1, 1)
    model.predict(x)

word_ids = model.generate(start_ids[-1], skip_ids)
word_ids = start_ids[:-1] + word_ids
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print('-' * 50)
print(txt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 13
#       9 corpus_size = len(corpus)
#      12 model = BetterRnnlmGen()
# ---> 13 model.load_params('./BetterRnnlm.pkl')
#      15 # start 문자와 skip 문자 설정
#      16 start_word = 'you'
#
# File ~/coding/workspace/Study/Deep-Learning-from-Scratch/2권/common/base_model.py:49, in BaseModel.load_params(self, file_name)
#      46     params = [to_gpu(p) for p in params]
#      48 for i, param in enumerate(self.params):
# ---> 49     param[...] = params[i]
#
# ValueError: could not broadcast input array from shape (9991,650) into shape (10000,640)

# %% [markdown]
# ## seq2seq
#
# 덧셈 데이터셋

# %%
from dataset import sequence

(x_train, t_train), (x_test, t_test) = sequence.load_data('./addition.txt', seed=1984)
char_to_id, id_to_char = sequence.get_vocab()

print(x_train.shape, t_train.shape)
print(x_test.shape, t_test.shape)
print()

print(x_train[0])
print(t_train[0])
print()

print(''.join([id_to_char[c] for c in x_train[0]]))
print(''.join([id_to_char[c] for c in t_train[0]]))
# Out:
# (45000, 7) (45000, 5)
# (5000, 7) (5000, 5)
#
# [ 3  0  2  0  0 11  5]
# [ 6  0 11  7  5]
#
# 71+118
# _189

# %% [markdown]
# ## seq2seq 구현
# Encoder 클래스

# %%
from common.time_layers import *

class Encoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4*H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4*H) / np.sqrt(H)).astype('f')
        lstm_b = (rn(4*H)).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=False)

        self.params = self.embed.params + self.lstm.params
        self.grads = self.embed.grads + self.lstm.grads
        self.hs = None
    
    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.lstm.forward(xs)
        self.hs = hs
        return hs[:, -1, :]
    
    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh

        dout = self.lstm.backward(dhs)
        dout = self.embed.backward(dout)
        return dout

# %% [markdown]
# Decoder 클래스

# %%
class Decoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4*H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4*H) / np.sqrt(H)).astype('f')
        lstm_b = (rn(4*H)).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads
    
    def forward(self, xs, h):
        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        out = self.lstm.forward(out)
        score = self.affine.forward(out)
        return score
    
    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.lstm.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.lstm.dh
        return dh
    
    def generate(self, h, start_id, sample_size): ## decoder의 학습과 생성이 다른 이유? 학습은 probabilistic vs 생성은 deterministic
        sampled = []
        sample_id = start_id
        self.lstm.set_state(h)

        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1,1))
            out = self.embed.forward(x)
            out = self.lstm.forward(out)
            score = self.affine.forward(out) 

            ## score -> (1, 1, V)
            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))
        
        return sampled

# %% [markdown]
# Seq2seq 클래스

# %%
from common.base_model import BaseModel

class Seq2seq(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = Decoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads
    
    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]
        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout
    
    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

# %% [markdown]
# seq2seq 평가

# %%
class PeekyDecoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(H + D, 4 * H) / np.sqrt(H + D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H + H, V) / np.sqrt(H + H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads
        self.cache = None

    def forward(self, xs, h):
        N, T = xs.shape
        N, H = h.shape

        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        hs = np.repeat(h, T, axis=0).reshape(N, T, H)
        out = np.concatenate((hs, out), axis=2)

        out = self.lstm.forward(out)
        out = np.concatenate((hs, out), axis=2)

        score = self.affine.forward(out)
        self.cache = H
        return score

    def backward(self, dscore):
        H = self.cache

        dout = self.affine.backward(dscore)
        dout, dhs0 = dout[:, :, H:], dout[:, :, :H]
        dout = self.lstm.backward(dout)
        dembed, dhs1 = dout[:, :, H:], dout[:, :, :H]
        self.embed.backward(dembed)

        dhs = dhs0 + dhs1
        dh = self.lstm.dh + np.sum(dhs, axis=1)
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        char_id = start_id
        self.lstm.set_state(h)

        H = h.shape[1]
        peeky_h = h.reshape(1, 1, H)
        for _ in range(sample_size):
            x = np.array([char_id]).reshape((1, 1))
            out = self.embed.forward(x)

            out = np.concatenate((peeky_h, out), axis=2)
            out = self.lstm.forward(out)
            out = np.concatenate((peeky_h, out), axis=2)
            score = self.affine.forward(out)

            char_id = np.argmax(score.flatten())
            sampled.append(char_id)

        return sampled


class PeekySeq2seq(Seq2seq):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = PeekyDecoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq

(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

model = Seq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.60
# | 에폭 1 |  반복 21 / 351 | 시간 1[s] | 손실 2.34
# | 에폭 1 |  반복 41 / 351 | 시간 2[s] | 손실 2.06
# | 에폭 1 |  반복 61 / 351 | 시간 2[s] | 손실 1.94
# | 에폭 1 |  반복 81 / 351 | 시간 3[s] | 손실 1.90
# | 에폭 1 |  반복 101 / 351 | 시간 4[s] | 손실 1.86
# | 에폭 1 |  반복 121 / 351 | 시간 5[s] | 손실 1.85
# | 에폭 1 |  반복 141 / 351 | 시간 6[s] | 손실 1.84
# | 에폭 1 |  반복 161 / 351 | 시간 7[s] | 손실 1.82
# | 에폭 1 |  반복 181 / 351 | 시간 8[s] | 손실 1.78
# | 에폭 1 |  반복 201 / 351 | 시간 9[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 11[s] | 손실 1.77
# | 에폭 1 |  반복 241 / 351 | 시간 12[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 13[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 14[s] | 손실 1.74
# | 에폭 1 |  반복 301 / 351 | 시간 15[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 16[s] | 손실 1.73
# | 에폭 1 |  반복 341 / 351 | 시간 18[s] | 손실 1.73
# Q 77+85
# T 162
# ☒ 1001
# ---
# Q 975+164
# T 1139
# ☒ 1022
# ---
# Q 582+84
# T 666
# ☒ 1002
# ---
# Q 8+155
# T 163
# ☒ 102
# ---
# Q 367+55
# T 422
# ☒ 1001
# ---
# Q 600+257
# T 857
# ☒ 1022
# ---
# Q 761+292
# T 1053
# ☒ 1022
# ---
# Q 830+597
# T 1427
# ☒ 1022
# ---
# Q 26+838
# T 864
# ☒ 1001
# ---
# Q 143+93
# T 236
# ☒ 100
# ---
# 검증 정확도 0.280%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.72
# | 에폭 2 |  반복 21 / 351 | 시간 1[s] | 손실 1.71
# | 에폭 2 |  반복 41 / 351 | 시간 2[s] | 손실 1.69
# | 에폭 2 |  반복 61 / 351 | 시간 3[s] | 손실 1.68
# | 에폭 2 |  반복 81 / 351 | 시간 4[s] | 손실 1.68
# | 에폭 2 |  반복 101 / 351 | 시간 5[s] | 손실 1.66
# | 에폭 2 |  반복 121 / 351 | 시간 6[s] | 손실 1.65
# | 에폭 2 |  반복 141 / 351 | 시간 7[s] | 손실 1.64
# | 에폭 2 |  반복 161 / 351 | 시간 9[s] | 손실 1.63
# | 에폭 2 |  반복 181 / 351 | 시간 10[s] | 손실 1.62
# | 에폭 2 |  반복 201 / 351 | 시간 11[s] | 손실 1.61
# | 에폭 2 |  반복 221 / 351 | 시간 12[s] | 손실 1.59
# | 에폭 2 |  반복 241 / 351 | 시간 13[s] | 손실 1.58
# | 에폭 2 |  반복 261 / 351 | 시간 15[s] | 손실 1.56
# | 에폭 2 |  반복 281 / 351 | 시간 16[s] | 손실 1.56
# | 에폭 2 |  반복 301 / 351 | 시간 17[s] | 손실 1.54
# | 에폭 2 |  반복 321 / 351 | 시간 18[s] | 손실 1.52
# | 에폭 2 |  반복 341 / 351 | 시간 19[s] | 손실 1.51
# Q 77+85
# T 162
# ☒ 101
# ---
# Q 975+164
# T 1139
# ☒ 1598
# ---
# Q 582+84
# T 666
# ☒ 638
# ---
# Q 8+155
# T 163
# ☒ 211
# ---
# Q 367+55
# T 422
# ☒ 390
# ---
# Q 600+257
# T 857
# ☒ 1001
# ---
# Q 761+292
# T 1053
# ☒ 1009
# ---
# Q 830+597
# T 1427
# ☒ 1599
# ---
# Q 26+838
# T 864
# ☒ 900
# ---
# Q 143+93
# T 236
# ☒ 311
# ---
# 검증 정확도 0.500%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.48
# | 에폭 3 |  반복 21 / 351 | 시간 1[s] | 손실 1.48
# | 에폭 3 |  반복 41 / 351 | 시간 2[s] | 손실 1.47
# | 에폭 3 |  반복 61 / 351 | 시간 3[s] | 손실 1.46
# | 에폭 3 |  반복 81 / 351 | 시간 4[s] | 손실 1.44
# | 에폭 3 |  반복 101 / 351 | 시간 5[s] | 손실 1.43
# | 에폭 3 |  반복 121 / 351 | 시간 6[s] | 손실 1.42
# | 에폭 3 |  반복 141 / 351 | 시간 7[s] | 손실 1.40
# | 에폭 3 |  반복 161 / 351 | 시간 8[s] | 손실 1.40
# | 에폭 3 |  반복 181 / 351 | 시간 11[s] | 손실 1.39
# | 에폭 3 |  반복 201 / 351 | 시간 12[s] | 손실 1.38
# | 에폭 3 |  반복 221 / 351 | 시간 13[s] | 손실 1.36
# | 에폭 3 |  반복 241 / 351 | 시간 15[s] | 손실 1.35
# | 에폭 3 |  반복 261 / 351 | 시간 16[s] | 손실 1.34
# | 에폭 3 |  반복 281 / 351 | 시간 17[s] | 손실 1.34
# | 에폭 3 |  반복 301 / 351 | 시간 19[s] | 손실 1.35
# | 에폭 3 |  반복 321 / 351 | 시간 20[s] | 손실 1.33
# | 에폭 3 |  반복 341 / 351 | 시간 21[s] | 손실 1.32
# Q 77+85
# T 162
# ☒ 165
# ---
# Q 975+164
# T 1139
# ☒ 1271
# ---
# Q 582+84
# T 666
# ☒ 671
# ---
# Q 8+155
# T 163
# ☒ 177
# ---
# Q 367+55
# T 422
# ☒ 471
# ---
# Q 600+257
# T 857
# ☒ 891
# ---
# Q 761+292
# T 1053
# ☒ 1129
# ---
# Q 830+597
# T 1427
# ☒ 1491
# ---
# Q 26+838
# T 864
# ☒ 871
# ---
# Q 143+93
# T 236
# ☒ 271
# ---
# 검증 정확도 1.320%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.28
# | 에폭 4 |  반복 21 / 351 | 시간 1[s] | 손실 1.30
# | 에폭 4 |  반복 41 / 351 | 시간 2[s] | 손실 1.30
# | 에폭 4 |  반복 61 / 351 | 시간 3[s] | 손실 1.29
# | 에폭 4 |  반복 81 / 351 | 시간 4[s] | 손실 1.28
# | 에폭 4 |  반복 101 / 351 | 시간 5[s] | 손실 1.27
# | 에폭 4 |  반복 121 / 351 | 시간 6[s] | 손실 1.26
# | 에폭 4 |  반복 141 / 351 | 시간 7[s] | 손실 1.25
# | 에폭 4 |  반복 161 / 351 | 시간 8[s] | 손실 1.24
# | 에폭 4 |  반복 181 / 351 | 시간 9[s] | 손실 1.24
# | 에폭 4 |  반복 201 / 351 | 시간 11[s] | 손실 1.22
# | 에폭 4 |  반복 221 / 351 | 시간 13[s] | 손실 1.22
# | 에폭 4 |  반복 241 / 351 | 시간 14[s] | 손실 1.22
# | 에폭 4 |  반복 261 / 351 | 시간 15[s] | 손실 1.23
# | 에폭 4 |  반복 281 / 351 | 시간 15[s] | 손실 1.22
# | 에폭 4 |  반복 301 / 351 | 시간 16[s] | 손실 1.21
# | 에폭 4 |  반복 321 / 351 | 시간 18[s] | 손실 1.21
# | 에폭 4 |  반복 341 / 351 | 시간 19[s] | 손실 1.19
# Q 77+85
# T 162
# ☒ 165
# ---
# Q 975+164
# T 1139
# ☒ 1235
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 195
# ---
# Q 367+55
# T 422
# ☒ 481
# ---
# Q 600+257
# T 857
# ☒ 895
# ---
# Q 761+292
# T 1053
# ☒ 1110
# ---
# Q 830+597
# T 1427
# ☒ 1491
# ---
# Q 26+838
# T 864
# ☒ 897
# ---
# Q 143+93
# T 236
# ☒ 210
# ---
# 검증 정확도 1.720%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.23
# | 에폭 5 |  반복 21 / 351 | 시간 1[s] | 손실 1.24
# | 에폭 5 |  반복 41 / 351 | 시간 2[s] | 손실 1.22
# | 에폭 5 |  반복 61 / 351 | 시간 3[s] | 손실 1.19
# | 에폭 5 |  반복 81 / 351 | 시간 4[s] | 손실 1.18
# | 에폭 5 |  반복 101 / 351 | 시간 6[s] | 손실 1.17
# | 에폭 5 |  반복 121 / 351 | 시간 8[s] | 손실 1.17
# | 에폭 5 |  반복 141 / 351 | 시간 9[s] | 손실 1.16
# | 에폭 5 |  반복 161 / 351 | 시간 11[s] | 손실 1.15
# | 에폭 5 |  반복 181 / 351 | 시간 13[s] | 손실 1.14
# | 에폭 5 |  반복 201 / 351 | 시간 14[s] | 손실 1.14
# | 에폭 5 |  반복 221 / 351 | 시간 16[s] | 손실 1.13
# | 에폭 5 |  반복 241 / 351 | 시간 17[s] | 손실 1.13
# | 에폭 5 |  반복 261 / 351 | 시간 18[s] | 손실 1.12
# | 에폭 5 |  반복 281 / 351 | 시간 20[s] | 손실 1.12
# | 에폭 5 |  반복 301 / 351 | 시간 21[s] | 손실 1.13
# | 에폭 5 |  반복 321 / 351 | 시간 22[s] | 손실 1.11
# | 에폭 5 |  반복 341 / 351 | 시간 23[s] | 손실 1.24
# Q 77+85
# T 162
# ☒ 151
# ---
# Q 975+164
# T 1139
# ☒ 1171
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 183
# ---
# Q 367+55
# T 422
# ☒ 431
# ---
# Q 600+257
# T 857
# ☒ 826
# ---
# Q 761+292
# T 1053
# ☒ 1007
# ---
# Q 830+597
# T 1427
# ☒ 1371
# ---
# Q 26+838
# T 864
# ☒ 838
# ---
# Q 143+93
# T 236
# ☒ 258
# ---
# 검증 정확도 2.300%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 1.12
# | 에폭 6 |  반복 21 / 351 | 시간 2[s] | 손실 1.11
# | 에폭 6 |  반복 41 / 351 | 시간 4[s] | 손실 1.11
# | 에폭 6 |  반복 61 / 351 | 시간 6[s] | 손실 1.12
# | 에폭 6 |  반복 81 / 351 | 시간 7[s] | 손실 1.11
# | 에폭 6 |  반복 101 / 351 | 시간 9[s] | 손실 1.10
# | 에폭 6 |  반복 121 / 351 | 시간 10[s] | 손실 1.13
# | 에폭 6 |  반복 141 / 351 | 시간 12[s] | 손실 1.09
# | 에폭 6 |  반복 161 / 351 | 시간 14[s] | 손실 1.08
# | 에폭 6 |  반복 181 / 351 | 시간 16[s] | 손실 1.09
# | 에폭 6 |  반복 201 / 351 | 시간 18[s] | 손실 1.08
# | 에폭 6 |  반복 221 / 351 | 시간 19[s] | 손실 1.07
# | 에폭 6 |  반복 241 / 351 | 시간 21[s] | 손실 1.08
# | 에폭 6 |  반복 261 / 351 | 시간 21[s] | 손실 1.08
# | 에폭 6 |  반복 281 / 351 | 시간 22[s] | 손실 1.12
# | 에폭 6 |  반복 301 / 351 | 시간 23[s] | 손실 1.12
# | 에폭 6 |  반복 321 / 351 | 시간 24[s] | 손실 1.11
# | 에폭 6 |  반복 341 / 351 | 시간 25[s] | 손실 1.08
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1165
# ---
# Q 582+84
# T 666
# ☒ 657
# ---
# Q 8+155
# T 163
# ☒ 183
# ---
# Q 367+55
# T 422
# ☒ 430
# ---
# Q 600+257
# T 857
# ☒ 839
# ---
# Q 761+292
# T 1053
# ☒ 1009
# ---
# Q 830+597
# T 1427
# ☒ 1413
# ---
# Q 26+838
# T 864
# ☒ 870
# ---
# Q 143+93
# T 236
# ☒ 209
# ---
# 검증 정확도 3.860%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 1.06
# | 에폭 7 |  반복 21 / 351 | 시간 1[s] | 손실 1.05
# | 에폭 7 |  반복 41 / 351 | 시간 3[s] | 손실 1.05
# | 에폭 7 |  반복 61 / 351 | 시간 4[s] | 손실 1.04
# | 에폭 7 |  반복 81 / 351 | 시간 5[s] | 손실 1.05
# | 에폭 7 |  반복 101 / 351 | 시간 8[s] | 손실 1.04
# | 에폭 7 |  반복 121 / 351 | 시간 10[s] | 손실 1.11
# | 에폭 7 |  반복 141 / 351 | 시간 11[s] | 손실 1.09
# | 에폭 7 |  반복 161 / 351 | 시간 12[s] | 손실 1.08
# | 에폭 7 |  반복 181 / 351 | 시간 13[s] | 손실 1.04
# | 에폭 7 |  반복 201 / 351 | 시간 14[s] | 손실 1.04
# | 에폭 7 |  반복 221 / 351 | 시간 16[s] | 손실 1.03
# | 에폭 7 |  반복 241 / 351 | 시간 17[s] | 손실 1.03
# | 에폭 7 |  반복 261 / 351 | 시간 18[s] | 손실 1.02
# | 에폭 7 |  반복 281 / 351 | 시간 19[s] | 손실 1.02
# | 에폭 7 |  반복 301 / 351 | 시간 21[s] | 손실 1.03
# | 에폭 7 |  반복 321 / 351 | 시간 24[s] | 손실 1.02
# | 에폭 7 |  반복 341 / 351 | 시간 25[s] | 손실 1.02
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1107
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 177
# ---
# Q 367+55
# T 422
# ☒ 431
# ---
# Q 600+257
# T 857
# ☒ 876
# ---
# Q 761+292
# T 1053
# ☒ 1038
# ---
# Q 830+597
# T 1427
# ☒ 1407
# ---
# Q 26+838
# T 864
# ☒ 871
# ---
# Q 143+93
# T 236
# ☒ 270
# ---
# 검증 정확도 4.140%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 1.03
# | 에폭 8 |  반복 21 / 351 | 시간 3[s] | 손실 1.06
# | 에폭 8 |  반복 41 / 351 | 시간 4[s] | 손실 1.06
# | 에폭 8 |  반복 61 / 351 | 시간 5[s] | 손실 1.02
# | 에폭 8 |  반복 81 / 351 | 시간 6[s] | 손실 1.03
# | 에폭 8 |  반복 101 / 351 | 시간 7[s] | 손실 1.05
# | 에폭 8 |  반복 121 / 351 | 시간 8[s] | 손실 1.05
# | 에폭 8 |  반복 141 / 351 | 시간 11[s] | 손실 1.05
# | 에폭 8 |  반복 161 / 351 | 시간 14[s] | 손실 1.05
# | 에폭 8 |  반복 181 / 351 | 시간 15[s] | 손실 1.01
# | 에폭 8 |  반복 201 / 351 | 시간 16[s] | 손실 1.00
# | 에폭 8 |  반복 221 / 351 | 시간 18[s] | 손실 0.99
# | 에폭 8 |  반복 241 / 351 | 시간 19[s] | 손실 0.99
# | 에폭 8 |  반복 261 / 351 | 시간 20[s] | 손실 0.99
# | 에폭 8 |  반복 281 / 351 | 시간 21[s] | 손실 0.98
# | 에폭 8 |  반복 301 / 351 | 시간 22[s] | 손실 0.99
# | 에폭 8 |  반복 321 / 351 | 시간 23[s] | 손실 1.00
# | 에폭 8 |  반복 341 / 351 | 시간 25[s] | 손실 1.00
# Q 77+85
# T 162
# ☒ 158
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 656
# ---
# Q 8+155
# T 163
# ☒ 157
# ---
# Q 367+55
# T 422
# ☒ 417
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1038
# ---
# Q 830+597
# T 1427
# ☒ 1395
# ---
# Q 26+838
# T 864
# ☒ 851
# ---
# Q 143+93
# T 236
# ☒ 225
# ---
# 검증 정확도 2.420%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 1.03
# | 에폭 9 |  반복 41 / 351 | 시간 2[s] | 손실 1.02
# | 에폭 9 |  반복 61 / 351 | 시간 3[s] | 손실 0.99
# | 에폭 9 |  반복 81 / 351 | 시간 4[s] | 손실 0.98
# | 에폭 9 |  반복 101 / 351 | 시간 5[s] | 손실 0.99
# | 에폭 9 |  반복 121 / 351 | 시간 7[s] | 손실 1.00
# | 에폭 9 |  반복 141 / 351 | 시간 9[s] | 손실 1.00
# | 에폭 9 |  반복 161 / 351 | 시간 13[s] | 손실 0.97
# | 에폭 9 |  반복 181 / 351 | 시간 15[s] | 손실 1.00
# | 에폭 9 |  반복 201 / 351 | 시간 17[s] | 손실 1.01
# | 에폭 9 |  반복 221 / 351 | 시간 18[s] | 손실 1.00
# | 에폭 9 |  반복 241 / 351 | 시간 20[s] | 손실 1.00
# | 에폭 9 |  반복 261 / 351 | 시간 22[s] | 손실 0.97
# | 에폭 9 |  반복 281 / 351 | 시간 24[s] | 손실 0.95
# | 에폭 9 |  반복 301 / 351 | 시간 25[s] | 손실 0.96
# | 에폭 9 |  반복 321 / 351 | 시간 28[s] | 손실 0.95
# | 에폭 9 |  반복 341 / 351 | 시간 29[s] | 손실 0.96
# Q 77+85
# T 162
# ☒ 156
# ---
# Q 975+164
# T 1139
# ☒ 1107
# ---
# Q 582+84
# T 666
# ☒ 646
# ---
# Q 8+155
# T 163
# ☒ 156
# ---
# Q 367+55
# T 422
# ☒ 407
# ---
# Q 600+257
# T 857
# ☒ 846
# ---
# Q 761+292
# T 1053
# ☒ 1059
# ---
# Q 830+597
# T 1427
# ☒ 1420
# ---
# Q 26+838
# T 864
# ☒ 848
# ---
# Q 143+93
# T 236
# ☒ 232
# ---
# 검증 정확도 3.540%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.99
# | 에폭 10 |  반복 21 / 351 | 시간 1[s] | 손실 0.97
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 1.00
# | 에폭 10 |  반복 61 / 351 | 시간 3[s] | 손실 0.98
# | 에폭 10 |  반복 81 / 351 | 시간 4[s] | 손실 0.95
# | 에폭 10 |  반복 101 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 10 |  반복 121 / 351 | 시간 7[s] | 손실 0.95
# | 에폭 10 |  반복 141 / 351 | 시간 9[s] | 손실 0.99
# | 에폭 10 |  반복 161 / 351 | 시간 13[s] | 손실 1.01
# | 에폭 10 |  반복 181 / 351 | 시간 16[s] | 손실 0.98
# | 에폭 10 |  반복 201 / 351 | 시간 17[s] | 손실 0.99
# | 에폭 10 |  반복 221 / 351 | 시간 18[s] | 손실 0.97
# | 에폭 10 |  반복 241 / 351 | 시간 22[s] | 손실 0.98
# | 에폭 10 |  반복 261 / 351 | 시간 23[s] | 손실 0.98
# | 에폭 10 |  반복 281 / 351 | 시간 24[s] | 손실 0.98
# | 에폭 10 |  반복 301 / 351 | 시간 25[s] | 손실 0.97
# | 에폭 10 |  반복 321 / 351 | 시간 27[s] | 손실 0.94
# | 에폭 10 |  반복 341 / 351 | 시간 28[s] | 손실 0.94
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1166
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 167
# ---
# Q 367+55
# T 422
# ☒ 441
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1065
# ---
# Q 830+597
# T 1427
# ☒ 1441
# ---
# Q 26+838
# T 864
# ☒ 872
# ---
# Q 143+93
# T 236
# ☒ 246
# ---
# 검증 정확도 3.420%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.97
# | 에폭 11 |  반복 21 / 351 | 시간 1[s] | 손실 1.00
# | 에폭 11 |  반복 41 / 351 | 시간 4[s] | 손실 0.94
# | 에폭 11 |  반복 61 / 351 | 시간 5[s] | 손실 0.93
# | 에폭 11 |  반복 81 / 351 | 시간 6[s] | 손실 0.93
# | 에폭 11 |  반복 101 / 351 | 시간 7[s] | 손실 0.93
# | 에폭 11 |  반복 121 / 351 | 시간 9[s] | 손실 0.93
# | 에폭 11 |  반복 141 / 351 | 시간 10[s] | 손실 0.94
# | 에폭 11 |  반복 161 / 351 | 시간 12[s] | 손실 0.95
# | 에폭 11 |  반복 181 / 351 | 시간 13[s] | 손실 0.92
# | 에폭 11 |  반복 201 / 351 | 시간 14[s] | 손실 0.93
# | 에폭 11 |  반복 221 / 351 | 시간 15[s] | 손실 0.94
# | 에폭 11 |  반복 241 / 351 | 시간 16[s] | 손실 0.94
# | 에폭 11 |  반복 261 / 351 | 시간 17[s] | 손실 0.93
# | 에폭 11 |  반복 281 / 351 | 시간 18[s] | 손실 0.92
# | 에폭 11 |  반복 301 / 351 | 시간 19[s] | 손실 0.92
# | 에폭 11 |  반복 321 / 351 | 시간 20[s] | 손실 0.91
# | 에폭 11 |  반복 341 / 351 | 시간 21[s] | 손실 0.90
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1129
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 159
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1070
# ---
# Q 830+597
# T 1427
# ☒ 1404
# ---
# Q 26+838
# T 864
# ☒ 859
# ---
# Q 143+93
# T 236
# ☒ 229
# ---
# 검증 정확도 7.440%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 12 |  반복 21 / 351 | 시간 1[s] | 손실 0.92
# | 에폭 12 |  반복 41 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 12 |  반복 61 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 12 |  반복 81 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 12 |  반복 101 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 12 |  반복 121 / 351 | 시간 6[s] | 손실 0.90
# | 에폭 12 |  반복 141 / 351 | 시간 7[s] | 손실 0.93
# | 에폭 12 |  반복 161 / 351 | 시간 8[s] | 손실 0.94
# | 에폭 12 |  반복 181 / 351 | 시간 9[s] | 손실 0.89
# | 에폭 12 |  반복 201 / 351 | 시간 10[s] | 손실 0.91
# | 에폭 12 |  반복 221 / 351 | 시간 11[s] | 손실 0.92
# | 에폭 12 |  반복 241 / 351 | 시간 12[s] | 손실 0.89
# | 에폭 12 |  반복 261 / 351 | 시간 13[s] | 손실 0.90
# | 에폭 12 |  반복 281 / 351 | 시간 14[s] | 손실 0.89
# | 에폭 12 |  반복 301 / 351 | 시간 16[s] | 손실 0.89
# | 에폭 12 |  반복 321 / 351 | 시간 17[s] | 손실 0.90
# | 에폭 12 |  반복 341 / 351 | 시간 19[s] | 손실 0.91
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1155
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 416
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1415
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 30
#      28     question, correct = x_test[[i]], t_test[[i]]
#      29     verbose = i < 10
# ---> 30     correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)
#      32 acc = float(correct_num) / len(x_test)
#      33 acc_list.append(acc)
#
# File ~/coding/workspace/Study/Deep-Learning-from-Scratch/2권/common/util.py:235, in eval_seq2seq(model, question, correct, id_to_char, verbos, is_reverse)
#     233 start_id = correct[0]
#     234 correct = correct[1:]
# --> 235 guess = model.generate(question, start_id, len(correct))
#     237 # 문자열로 변환
#     238 question = ''.join([id_to_char[int(c)] for c in question.flatten()])
#
# Cell In[11], line 27, in Seq2seq.generate(self, xs, start_id, sample_size)
#      26 def generate(self, xs, start_id, sample_size):
# ---> 27     h = self.encoder.forward(xs)
#      28     sampled = self.decoder.generate(h, start_id, sample_size)
#      29     return sampled
#
# Cell In[9], line 22, in Encoder.forward(self, xs)
#      20 def forward(self, xs):
#      21     xs = self.embed.forward(xs)
# ---> 22     hs = self.lstm.forward(xs)
#      23     self.hs = hs
#      24     return hs[:, -1, :]
#
# File ~/coding/workspace/Study/Deep-Learning-from-Scratch/2권/common/time_layers.py:193, in TimeLSTM.forward(self, xs)
#     191 for t in range(T):
#     192     layer = LSTM(*self.params)
# --> 193     self.h, self.c = layer.forward(xs[:, t, :], self.h, self.c)
#     194     hs[:, t, :] = self.h
#     196     self.layers.append(layer)
#
# File ~/coding/workspace/Study/Deep-Learning-from-Scratch/2권/common/time_layers.py:114, in LSTM.forward(self, x, h_prev, c_prev)
#     111 Wx, Wh, b = self.params
#     112 N, H = h_prev.shape
# --> 114 A = np.dot(x, Wx) + np.dot(h_prev, Wh) + b
#     116 f = A[:, :H]
#     117 g = A[:, H:2*H]
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
plt.plot(np.arange(1,max_epoch+1), acc_list, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %% [markdown]
# lstm을 rnn으로 교체

# %%
from common.time_layers import *

class EncoderRNN:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        lstm_b = (rn(H)).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.rnn = TimeRNN(lstm_Wx, lstm_Wh, lstm_b, stateful=False)

        self.params = self.embed.params + self.rnn.params
        self.grads = self.embed.grads + self.rnn.grads
        self.hs = None
    
    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.rnn.forward(xs)
        self.hs = hs
        return hs[:, -1, :]
    
    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh

        dout = self.rnn.backward(dhs)
        dout = self.embed.backward(dout)
        return dout

# %% [markdown]
# Decoder 클래스

# %%
class DecoderRNN:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        lstm_b = (rn(H)).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.rnn = TimeRNN(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.rnn, self.affine):
            self.params += layer.params
            self.grads += layer.grads
    
    def forward(self, xs, h):
        self.rnn.set_state(h)

        out = self.embed.forward(xs)
        out = self.rnn.forward(out)
        score = self.affine.forward(out)
        return score
    
    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.rnn.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.rnn.dh
        return dh
    
    def generate(self, h, start_id, sample_size): ## decoder의 학습과 생성이 다른 이유? 학습은 probabilistic vs 생성은 deterministic
        sampled = []
        sample_id = start_id
        self.rnn.set_state(h)

        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1,1))
            out = self.embed.forward(x)
            out = self.rnn.forward(out)
            score = self.affine.forward(out) 

            ## score -> (1, 1, V)
            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))
        
        return sampled

# %% [markdown]
# Seq2seq 클래스

# %%
from common.base_model import BaseModel

class Seq2seqRNN(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = EncoderRNN(V, D, H)
        self.decoder = DecoderRNN(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads
    
    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]
        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout
    
    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

# %% [markdown]
# seq2seq 평가

# %%
class PeekyDecoderRNN:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(H + D, H) / np.sqrt(H + D)).astype('f')
        lstm_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(H).astype('f')
        affine_W = (rn(H + H, V) / np.sqrt(H + H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.rnn = TimeRNN(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.rnn, self.affine):
            self.params += layer.params
            self.grads += layer.grads
        self.cache = None

    def forward(self, xs, h):
        N, T = xs.shape
        N, H = h.shape

        self.rnn.set_state(h)

        out = self.embed.forward(xs)
        hs = np.repeat(h, T, axis=0).reshape(N, T, H)
        out = np.concatenate((hs, out), axis=2)

        out = self.rnn.forward(out)
        out = np.concatenate((hs, out), axis=2)

        score = self.affine.forward(out)
        self.cache = H
        return score

    def backward(self, dscore):
        H = self.cache

        dout = self.affine.backward(dscore)
        dout, dhs0 = dout[:, :, H:], dout[:, :, :H]
        dout = self.rnn.backward(dout)
        dembed, dhs1 = dout[:, :, H:], dout[:, :, :H]
        self.embed.backward(dembed)

        dhs = dhs0 + dhs1
        dh = self.rnn.dh + np.sum(dhs, axis=1)
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        char_id = start_id
        self.rnn.set_state(h)

        H = h.shape[1]
        peeky_h = h.reshape(1, 1, H)
        for _ in range(sample_size):
            x = np.array([char_id]).reshape((1, 1))
            out = self.embed.forward(x)

            out = np.concatenate((peeky_h, out), axis=2)
            out = self.rnn.forward(out)
            out = np.concatenate((peeky_h, out), axis=2)
            score = self.affine.forward(out)

            char_id = np.argmax(score.flatten())
            sampled.append(char_id)

        return sampled


class PeekySeq2seqRNN(Seq2seq):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = EncoderRNN(V, D, H)
        self.decoder = PeekyDecoderRNN(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq

(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

model = Seq2seqRNN(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainerRNN = Trainer(model, optimizer)

acc_listRNN = []
for epoch in range(max_epoch):
    trainerRNN.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    acc_listRNN.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.82
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.10
# | 에폭 1 |  반복 41 / 351 | 시간 0[s] | 손실 1.94
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 1.92
# | 에폭 1 |  반복 81 / 351 | 시간 1[s] | 손실 1.90
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.85
# | 에폭 1 |  반복 121 / 351 | 시간 2[s] | 손실 1.80
# | 에폭 1 |  반복 141 / 351 | 시간 3[s] | 손실 1.77
# | 에폭 1 |  반복 161 / 351 | 시간 3[s] | 손실 1.75
# | 에폭 1 |  반복 181 / 351 | 시간 3[s] | 손실 1.73
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 1.72
# | 에폭 1 |  반복 221 / 351 | 시간 4[s] | 손실 1.72
# | 에폭 1 |  반복 241 / 351 | 시간 5[s] | 손실 1.71
# | 에폭 1 |  반복 261 / 351 | 시간 5[s] | 손실 1.68
# | 에폭 1 |  반복 281 / 351 | 시간 5[s] | 손실 1.66
# | 에폭 1 |  반복 301 / 351 | 시간 6[s] | 손실 1.63
# | 에폭 1 |  반복 321 / 351 | 시간 6[s] | 손실 1.61
# | 에폭 1 |  반복 341 / 351 | 시간 7[s] | 손실 1.58
# Q 77+85
# T 162
# ☒ 1002
# ---
# Q 975+164
# T 1139
# ☒ 1003
# ---
# Q 582+84
# T 666
# ☒ 699
# ---
# Q 8+155
# T 163
# ☒ 104
# ---
# Q 367+55
# T 422
# ☒ 367
# ---
# Q 600+257
# T 857
# ☒ 901
# ---
# Q 761+292
# T 1053
# ☒ 1033
# ---
# Q 830+597
# T 1427
# ☒ 1362
# ---
# Q 26+838
# T 864
# ☒ 909
# ---
# Q 143+93
# T 236
# ☒ 397
# ---
# 검증 정확도 0.400%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.54
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.54
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 1.51
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.49
# | 에폭 2 |  반복 81 / 351 | 시간 1[s] | 손실 1.47
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.45
# | 에폭 2 |  반복 121 / 351 | 시간 3[s] | 손실 1.43
# | 에폭 2 |  반복 141 / 351 | 시간 4[s] | 손실 1.41
# | 에폭 2 |  반복 161 / 351 | 시간 4[s] | 손실 1.40
# | 에폭 2 |  반복 181 / 351 | 시간 5[s] | 손실 1.38
# | 에폭 2 |  반복 201 / 351 | 시간 5[s] | 손실 1.36
# | 에폭 2 |  반복 221 / 351 | 시간 6[s] | 손실 1.36
# | 에폭 2 |  반복 241 / 351 | 시간 6[s] | 손실 1.34
# | 에폭 2 |  반복 261 / 351 | 시간 7[s] | 손실 1.33
# | 에폭 2 |  반복 281 / 351 | 시간 7[s] | 손실 1.32
# | 에폭 2 |  반복 301 / 351 | 시간 8[s] | 손실 1.31
# | 에폭 2 |  반복 321 / 351 | 시간 8[s] | 손실 1.30
# | 에폭 2 |  반복 341 / 351 | 시간 9[s] | 손실 1.29
# Q 77+85
# T 162
# ☒ 150
# ---
# Q 975+164
# T 1139
# ☒ 1100
# ---
# Q 582+84
# T 666
# ☒ 654
# ---
# Q 8+155
# T 163
# ☒ 110
# ---
# Q 367+55
# T 422
# ☒ 410
# ---
# Q 600+257
# T 857
# ☒ 853
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1642
# ---
# Q 26+838
# T 864
# ☒ 874
# ---
# Q 143+93
# T 236
# ☒ 200
# ---
# 검증 정확도 1.940%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.30
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.27
# | 에폭 3 |  반복 41 / 351 | 시간 0[s] | 손실 1.25
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.24
# | 에폭 3 |  반복 81 / 351 | 시간 1[s] | 손실 1.22
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 1.22
# | 에폭 3 |  반복 121 / 351 | 시간 2[s] | 손실 1.20
# | 에폭 3 |  반복 141 / 351 | 시간 3[s] | 손실 1.19
# | 에폭 3 |  반복 161 / 351 | 시간 3[s] | 손실 1.18
# | 에폭 3 |  반복 181 / 351 | 시간 4[s] | 손실 1.17
# | 에폭 3 |  반복 201 / 351 | 시간 4[s] | 손실 1.15
# | 에폭 3 |  반복 221 / 351 | 시간 5[s] | 손실 1.14
# | 에폭 3 |  반복 241 / 351 | 시간 5[s] | 손실 1.13
# | 에폭 3 |  반복 261 / 351 | 시간 5[s] | 손실 1.12
# | 에폭 3 |  반복 281 / 351 | 시간 6[s] | 손실 1.10
# | 에폭 3 |  반복 301 / 351 | 시간 6[s] | 손실 1.09
# | 에폭 3 |  반복 321 / 351 | 시간 7[s] | 손실 1.07
# | 에폭 3 |  반복 341 / 351 | 시간 7[s] | 손실 1.07
# Q 77+85
# T 162
# ☒ 150
# ---
# Q 975+164
# T 1139
# ☒ 1107
# ---
# Q 582+84
# T 666
# ☒ 657
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 414
# ---
# Q 600+257
# T 857
# ☒ 844
# ---
# Q 761+292
# T 1053
# ☒ 1001
# ---
# Q 830+597
# T 1427
# ☒ 1444
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 250
# ---
# 검증 정확도 3.740%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.04
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.05
# | 에폭 4 |  반복 41 / 351 | 시간 0[s] | 손실 1.04
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.02
# | 에폭 4 |  반복 81 / 351 | 시간 1[s] | 손실 1.01
# | 에폭 4 |  반복 101 / 351 | 시간 2[s] | 손실 1.00
# | 에폭 4 |  반복 121 / 351 | 시간 2[s] | 손실 0.99
# | 에폭 4 |  반복 141 / 351 | 시간 3[s] | 손실 0.98
# | 에폭 4 |  반복 161 / 351 | 시간 3[s] | 손실 0.99
# | 에폭 4 |  반복 181 / 351 | 시간 4[s] | 손실 0.98
# | 에폭 4 |  반복 201 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 4 |  반복 221 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 4 |  반복 241 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 4 |  반복 261 / 351 | 시간 6[s] | 손실 0.93
# | 에폭 4 |  반복 281 / 351 | 시간 6[s] | 손실 0.91
# | 에폭 4 |  반복 301 / 351 | 시간 7[s] | 손실 0.91
# | 에폭 4 |  반복 321 / 351 | 시간 7[s] | 손실 0.90
# | 에폭 4 |  반복 341 / 351 | 시간 7[s] | 손실 0.90
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1167
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 168
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 940
# ---
# Q 761+292
# T 1053
# ☒ 1040
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 231
# ---
# 검증 정확도 7.520%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 5 |  반복 41 / 351 | 시간 0[s] | 손실 0.87
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 5 |  반복 81 / 351 | 시간 1[s] | 손실 0.86
# | 에폭 5 |  반복 101 / 351 | 시간 2[s] | 손실 0.85
# | 에폭 5 |  반복 121 / 351 | 시간 2[s] | 손실 0.85
# | 에폭 5 |  반복 141 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 5 |  반복 161 / 351 | 시간 3[s] | 손실 0.84
# | 에폭 5 |  반복 181 / 351 | 시간 4[s] | 손실 0.83
# | 에폭 5 |  반복 201 / 351 | 시간 4[s] | 손실 0.82
# | 에폭 5 |  반복 221 / 351 | 시간 4[s] | 손실 0.82
# | 에폭 5 |  반복 241 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 5 |  반복 261 / 351 | 시간 5[s] | 손실 0.80
# | 에폭 5 |  반복 281 / 351 | 시간 6[s] | 손실 0.80
# | 에폭 5 |  반복 301 / 351 | 시간 6[s] | 손실 0.80
# | 에폭 5 |  반복 321 / 351 | 시간 7[s] | 손실 0.79
# | 에폭 5 |  반복 341 / 351 | 시간 7[s] | 손실 0.79
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1149
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1329
# ---
# Q 26+838
# T 864
# ☒ 869
# ---
# Q 143+93
# T 236
# ☒ 229
# ---
# 검증 정확도 9.560%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.76
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 0.78
# | 에폭 6 |  반복 41 / 351 | 시간 0[s] | 손실 0.77
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 0.78
# | 에폭 6 |  반복 81 / 351 | 시간 1[s] | 손실 0.75
# | 에폭 6 |  반복 101 / 351 | 시간 2[s] | 손실 0.74
# | 에폭 6 |  반복 121 / 351 | 시간 2[s] | 손실 0.74
# | 에폭 6 |  반복 141 / 351 | 시간 3[s] | 손실 0.74
# | 에폭 6 |  반복 161 / 351 | 시간 3[s] | 손실 0.73
# | 에폭 6 |  반복 181 / 351 | 시간 4[s] | 손실 0.74
# | 에폭 6 |  반복 201 / 351 | 시간 4[s] | 손실 0.74
# | 에폭 6 |  반복 221 / 351 | 시간 5[s] | 손실 0.73
# | 에폭 6 |  반복 241 / 351 | 시간 5[s] | 손실 0.72
# | 에폭 6 |  반복 261 / 351 | 시간 6[s] | 손실 0.72
# | 에폭 6 |  반복 281 / 351 | 시간 6[s] | 손실 0.72
# | 에폭 6 |  반복 301 / 351 | 시간 7[s] | 손실 0.70
# | 에폭 6 |  반복 321 / 351 | 시간 7[s] | 손실 0.70
# | 에폭 6 |  반복 341 / 351 | 시간 7[s] | 손실 0.70
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1150
# ---
# Q 582+84
# T 666
# ☒ 660
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 863
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 233
# ---
# 검증 정확도 12.440%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.69
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 0.70
# | 에폭 7 |  반복 41 / 351 | 시간 0[s] | 손실 0.68
# | 에폭 7 |  반복 61 / 351 | 시간 1[s] | 손실 0.68
# | 에폭 7 |  반복 81 / 351 | 시간 1[s] | 손실 0.69
# | 에폭 7 |  반복 101 / 351 | 시간 2[s] | 손실 0.68
# | 에폭 7 |  반복 121 / 351 | 시간 2[s] | 손실 0.67
# | 에폭 7 |  반복 141 / 351 | 시간 3[s] | 손실 0.67
# | 에폭 7 |  반복 161 / 351 | 시간 3[s] | 손실 0.67
# | 에폭 7 |  반복 181 / 351 | 시간 3[s] | 손실 0.67
# | 에폭 7 |  반복 201 / 351 | 시간 4[s] | 손실 0.67
# | 에폭 7 |  반복 221 / 351 | 시간 4[s] | 손실 0.65
# | 에폭 7 |  반복 241 / 351 | 시간 5[s] | 손실 0.65
# | 에폭 7 |  반복 261 / 351 | 시간 5[s] | 손실 0.65
# | 에폭 7 |  반복 281 / 351 | 시간 6[s] | 손실 0.65
# | 에폭 7 |  반복 301 / 351 | 시간 6[s] | 손실 0.65
# | 에폭 7 |  반복 321 / 351 | 시간 6[s] | 손실 0.64
# | 에폭 7 |  반복 341 / 351 | 시간 7[s] | 손실 0.63
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 233
# ---
# 검증 정확도 15.620%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.63
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 0.66
# | 에폭 8 |  반복 41 / 351 | 시간 0[s] | 손실 0.66
# | 에폭 8 |  반복 61 / 351 | 시간 1[s] | 손실 0.64
# | 에폭 8 |  반복 81 / 351 | 시간 1[s] | 손실 0.64
# | 에폭 8 |  반복 101 / 351 | 시간 2[s] | 손실 0.64
# | 에폭 8 |  반복 121 / 351 | 시간 2[s] | 손실 0.63
# | 에폭 8 |  반복 141 / 351 | 시간 3[s] | 손실 0.62
# | 에폭 8 |  반복 161 / 351 | 시간 3[s] | 손실 0.62
# | 에폭 8 |  반복 181 / 351 | 시간 4[s] | 손실 0.62
# | 에폭 8 |  반복 201 / 351 | 시간 4[s] | 손실 0.62
# | 에폭 8 |  반복 221 / 351 | 시간 5[s] | 손실 0.62
# | 에폭 8 |  반복 241 / 351 | 시간 5[s] | 손실 0.61
# | 에폭 8 |  반복 261 / 351 | 시간 6[s] | 손실 0.63
# | 에폭 8 |  반복 281 / 351 | 시간 6[s] | 손실 0.63
# | 에폭 8 |  반복 301 / 351 | 시간 6[s] | 손실 0.61
# | 에폭 8 |  반복 321 / 351 | 시간 7[s] | 손실 0.60
# | 에폭 8 |  반복 341 / 351 | 시간 7[s] | 손실 0.60
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 19.820%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.58
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 0.59
# | 에폭 9 |  반복 41 / 351 | 시간 0[s] | 손실 0.59
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 0.59
# | 에폭 9 |  반복 81 / 351 | 시간 1[s] | 손실 0.61
# | 에폭 9 |  반복 101 / 351 | 시간 2[s] | 손실 0.60
# | 에폭 9 |  반복 121 / 351 | 시간 2[s] | 손실 0.59
# | 에폭 9 |  반복 141 / 351 | 시간 3[s] | 손실 0.58
# | 에폭 9 |  반복 161 / 351 | 시간 3[s] | 손실 0.59
# | 에폭 9 |  반복 181 / 351 | 시간 3[s] | 손실 0.58
# | 에폭 9 |  반복 201 / 351 | 시간 4[s] | 손실 0.58
# | 에폭 9 |  반복 221 / 351 | 시간 4[s] | 손실 0.59
# | 에폭 9 |  반복 241 / 351 | 시간 5[s] | 손실 0.59
# | 에폭 9 |  반복 261 / 351 | 시간 5[s] | 손실 0.60
# | 에폭 9 |  반복 281 / 351 | 시간 6[s] | 손실 0.59
# | 에폭 9 |  반복 301 / 351 | 시간 6[s] | 손실 0.58
# | 에폭 9 |  반복 321 / 351 | 시간 7[s] | 손실 0.56
# | 에폭 9 |  반복 341 / 351 | 시간 7[s] | 손실 0.57
# Q 77+85
# T 162
# ☒ 165
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 161
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1051
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☒ 860
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 19.620%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.56
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.56
# | 에폭 10 |  반복 41 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 0.58
# | 에폭 10 |  반복 81 / 351 | 시간 1[s] | 손실 0.57
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 0.57
# | 에폭 10 |  반복 121 / 351 | 시간 2[s] | 손실 0.57
# | 에폭 10 |  반복 141 / 351 | 시간 3[s] | 손실 0.58
# | 에폭 10 |  반복 161 / 351 | 시간 3[s] | 손실 0.56
# | 에폭 10 |  반복 181 / 351 | 시간 4[s] | 손실 0.55
# | 에폭 10 |  반복 201 / 351 | 시간 4[s] | 손실 0.55
# | 에폭 10 |  반복 221 / 351 | 시간 4[s] | 손실 0.56
# | 에폭 10 |  반복 241 / 351 | 시간 5[s] | 손실 0.56
# | 에폭 10 |  반복 261 / 351 | 시간 5[s] | 손실 0.54
# | 에폭 10 |  반복 281 / 351 | 시간 6[s] | 손실 0.55
# | 에폭 10 |  반복 301 / 351 | 시간 6[s] | 손실 0.55
# | 에폭 10 |  반복 321 / 351 | 시간 7[s] | 손실 0.54
# | 에폭 10 |  반복 341 / 351 | 시간 7[s] | 손실 0.55
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1143
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1056
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☒ 863
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 19.540%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.53
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 11 |  반복 41 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 11 |  반복 61 / 351 | 시간 1[s] | 손실 0.54
# | 에폭 11 |  반복 81 / 351 | 시간 1[s] | 손실 0.58
# | 에폭 11 |  반복 101 / 351 | 시간 2[s] | 손실 0.55
# | 에폭 11 |  반복 121 / 351 | 시간 2[s] | 손실 0.53
# | 에폭 11 |  반복 141 / 351 | 시간 3[s] | 손실 0.54
# | 에폭 11 |  반복 161 / 351 | 시간 3[s] | 손실 0.56
# | 에폭 11 |  반복 181 / 351 | 시간 3[s] | 손실 0.53
# | 에폭 11 |  반복 201 / 351 | 시간 4[s] | 손실 0.54
# | 에폭 11 |  반복 221 / 351 | 시간 4[s] | 손실 0.54
# | 에폭 11 |  반복 241 / 351 | 시간 5[s] | 손실 0.55
# | 에폭 11 |  반복 261 / 351 | 시간 5[s] | 손실 0.54
# | 에폭 11 |  반복 281 / 351 | 시간 6[s] | 손실 0.57
# | 에폭 11 |  반복 301 / 351 | 시간 6[s] | 손실 0.59
# | 에폭 11 |  반복 321 / 351 | 시간 7[s] | 손실 0.58
# | 에폭 11 |  반복 341 / 351 | 시간 7[s] | 손실 0.57
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 20.360%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.52
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.54
# | 에폭 12 |  반복 41 / 351 | 시간 0[s] | 손실 0.52
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 0.52
# | 에폭 12 |  반복 81 / 351 | 시간 1[s] | 손실 0.52
# | 에폭 12 |  반복 101 / 351 | 시간 2[s] | 손실 0.52
# | 에폭 12 |  반복 121 / 351 | 시간 2[s] | 손실 0.53
# | 에폭 12 |  반복 141 / 351 | 시간 3[s] | 손실 0.51
# | 에폭 12 |  반복 161 / 351 | 시간 3[s] | 손실 0.53
# | 에폭 12 |  반복 181 / 351 | 시간 4[s] | 손실 0.52
# | 에폭 12 |  반복 201 / 351 | 시간 4[s] | 손실 0.53
# | 에폭 12 |  반복 221 / 351 | 시간 5[s] | 손실 0.53
# | 에폭 12 |  반복 241 / 351 | 시간 5[s] | 손실 0.51
# | 에폭 12 |  반복 261 / 351 | 시간 5[s] | 손실 0.51
# | 에폭 12 |  반복 281 / 351 | 시간 6[s] | 손실 0.51
# | 에폭 12 |  반복 301 / 351 | 시간 6[s] | 손실 0.51
# | 에폭 12 |  반복 321 / 351 | 시간 7[s] | 손실 0.52
# | 에폭 12 |  반복 341 / 351 | 시간 7[s] | 손실 0.52
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1143
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 862
# ---
# Q 761+292
# T 1053
# ☒ 1057
# ---
# Q 830+597
# T 1427
# ☒ 1429
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 21.480%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.52
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.52
# | 에폭 13 |  반복 41 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 13 |  반복 61 / 351 | 시간 1[s] | 손실 0.55
# | 에폭 13 |  반복 81 / 351 | 시간 1[s] | 손실 0.51
# | 에폭 13 |  반복 101 / 351 | 시간 2[s] | 손실 0.53
# | 에폭 13 |  반복 121 / 351 | 시간 2[s] | 손실 0.50
# | 에폭 13 |  반복 141 / 351 | 시간 3[s] | 손실 0.50
# | 에폭 13 |  반복 161 / 351 | 시간 3[s] | 손실 0.50
# | 에폭 13 |  반복 181 / 351 | 시간 4[s] | 손실 0.51
# | 에폭 13 |  반복 201 / 351 | 시간 4[s] | 손실 0.50
# | 에폭 13 |  반복 221 / 351 | 시간 5[s] | 손실 0.55
# | 에폭 13 |  반복 241 / 351 | 시간 5[s] | 손실 0.55
# | 에폭 13 |  반복 261 / 351 | 시간 6[s] | 손실 0.51
# | 에폭 13 |  반복 281 / 351 | 시간 6[s] | 손실 0.50
# | 에폭 13 |  반복 301 / 351 | 시간 7[s] | 손실 0.50
# | 에폭 13 |  반복 321 / 351 | 시간 7[s] | 손실 0.50
# | 에폭 13 |  반복 341 / 351 | 시간 8[s] | 손실 0.50
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 166
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 861
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1426
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 22.720%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.49
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.50
# | 에폭 14 |  반복 41 / 351 | 시간 0[s] | 손실 0.50
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 0.49
# | 에폭 14 |  반복 81 / 351 | 시간 1[s] | 손실 0.50
# | 에폭 14 |  반복 101 / 351 | 시간 2[s] | 손실 0.49
# | 에폭 14 |  반복 121 / 351 | 시간 2[s] | 손실 0.55
# | 에폭 14 |  반복 141 / 351 | 시간 3[s] | 손실 0.54
# | 에폭 14 |  반복 161 / 351 | 시간 3[s] | 손실 0.55
# | 에폭 14 |  반복 181 / 351 | 시간 4[s] | 손실 0.54
# | 에폭 14 |  반복 201 / 351 | 시간 4[s] | 손실 0.52
# | 에폭 14 |  반복 221 / 351 | 시간 5[s] | 손실 0.48
# | 에폭 14 |  반복 241 / 351 | 시간 5[s] | 손실 0.49
# | 에폭 14 |  반복 261 / 351 | 시간 5[s] | 손실 0.49
# | 에폭 14 |  반복 281 / 351 | 시간 6[s] | 손실 0.49
# | 에폭 14 |  반복 301 / 351 | 시간 6[s] | 손실 0.50
# | 에폭 14 |  반복 321 / 351 | 시간 7[s] | 손실 0.50
# | 에폭 14 |  반복 341 / 351 | 시간 7[s] | 손실 0.48
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1429
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 25.460%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 15 |  반복 41 / 351 | 시간 1[s] | 손실 0.50
# | 에폭 15 |  반복 61 / 351 | 시간 1[s] | 손실 0.53
# | 에폭 15 |  반복 81 / 351 | 시간 1[s] | 손실 0.51
# | 에폭 15 |  반복 101 / 351 | 시간 2[s] | 손실 0.49
# | 에폭 15 |  반복 121 / 351 | 시간 2[s] | 손실 0.49
# | 에폭 15 |  반복 141 / 351 | 시간 3[s] | 손실 0.52
# | 에폭 15 |  반복 161 / 351 | 시간 3[s] | 손실 0.48
# | 에폭 15 |  반복 181 / 351 | 시간 4[s] | 손실 0.48
# | 에폭 15 |  반복 201 / 351 | 시간 4[s] | 손실 0.52
# | 에폭 15 |  반복 221 / 351 | 시간 4[s] | 손실 0.53
# | 에폭 15 |  반복 241 / 351 | 시간 5[s] | 손실 0.53
# | 에폭 15 |  반복 261 / 351 | 시간 5[s] | 손실 0.52
# | 에폭 15 |  반복 281 / 351 | 시간 6[s] | 손실 0.53
# | 에폭 15 |  반복 301 / 351 | 시간 6[s] | 손실 0.53
# | 에폭 15 |  반복 321 / 351 | 시간 7[s] | 손실 0.52
# | 에폭 15 |  반복 341 / 351 | 시간 7[s] | 손실 0.52
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☒ 860
# ---
# Q 143+93
# T 236
# ☒ 233
# ---
# 검증 정확도 10.960%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.56
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 16 |  반복 41 / 351 | 시간 0[s] | 손실 0.52
# | 에폭 16 |  반복 61 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 16 |  반복 81 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 16 |  반복 101 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 16 |  반복 121 / 351 | 시간 2[s] | 손실 0.48
# | 에폭 16 |  반복 141 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 16 |  반복 161 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 16 |  반복 181 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 16 |  반복 201 / 351 | 시간 4[s] | 손실 0.48
# | 에폭 16 |  반복 221 / 351 | 시간 4[s] | 손실 0.49
# | 에폭 16 |  반복 241 / 351 | 시간 5[s] | 손실 0.48
# | 에폭 16 |  반복 261 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 16 |  반복 281 / 351 | 시간 6[s] | 손실 0.47
# | 에폭 16 |  반복 301 / 351 | 시간 6[s] | 손실 0.47
# | 에폭 16 |  반복 321 / 351 | 시간 7[s] | 손실 0.49
# | 에폭 16 |  반복 341 / 351 | 시간 7[s] | 손실 0.48
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 860
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# 검증 정확도 25.680%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.49
# | 에폭 17 |  반복 61 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 17 |  반복 81 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 17 |  반복 101 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 17 |  반복 121 / 351 | 시간 2[s] | 손실 0.49
# | 에폭 17 |  반복 141 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 17 |  반복 161 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 17 |  반복 181 / 351 | 시간 4[s] | 손실 0.45
# | 에폭 17 |  반복 201 / 351 | 시간 4[s] | 손실 0.46
# | 에폭 17 |  반복 221 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 17 |  반복 241 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 17 |  반복 261 / 351 | 시간 6[s] | 손실 0.47
# | 에폭 17 |  반복 281 / 351 | 시간 6[s] | 손실 0.48
# | 에폭 17 |  반복 301 / 351 | 시간 6[s] | 손실 0.46
# | 에폭 17 |  반복 321 / 351 | 시간 7[s] | 손실 0.47
# | 에폭 17 |  반복 341 / 351 | 시간 7[s] | 손실 0.46
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1143
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 861
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 26.680%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 18 |  반복 41 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 18 |  반복 61 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 18 |  반복 81 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 18 |  반복 101 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 18 |  반복 121 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 18 |  반복 141 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 18 |  반복 161 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 18 |  반복 181 / 351 | 시간 4[s] | 손실 0.47
# | 에폭 18 |  반복 201 / 351 | 시간 4[s] | 손실 0.46
# | 에폭 18 |  반복 221 / 351 | 시간 4[s] | 손실 0.46
# | 에폭 18 |  반복 241 / 351 | 시간 5[s] | 손실 0.44
# | 에폭 18 |  반복 261 / 351 | 시간 5[s] | 손실 0.44
# | 에폭 18 |  반복 281 / 351 | 시간 6[s] | 손실 0.47
# | 에폭 18 |  반복 301 / 351 | 시간 6[s] | 손실 0.48
# | 에폭 18 |  반복 321 / 351 | 시간 7[s] | 손실 0.50
# | 에폭 18 |  반복 341 / 351 | 시간 7[s] | 손실 0.46
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# 검증 정확도 27.580%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 19 |  반복 41 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 19 |  반복 61 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 19 |  반복 81 / 351 | 시간 1[s] | 손실 0.44
# | 에폭 19 |  반복 101 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 19 |  반복 121 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 19 |  반복 141 / 351 | 시간 3[s] | 손실 0.43
# | 에폭 19 |  반복 161 / 351 | 시간 3[s] | 손실 0.49
# | 에폭 19 |  반복 181 / 351 | 시간 4[s] | 손실 0.51
# | 에폭 19 |  반복 201 / 351 | 시간 4[s] | 손실 0.50
# | 에폭 19 |  반복 221 / 351 | 시간 5[s] | 손실 0.49
# | 에폭 19 |  반복 241 / 351 | 시간 5[s] | 손실 0.49
# | 에폭 19 |  반복 261 / 351 | 시간 6[s] | 손실 0.52
# | 에폭 19 |  반복 281 / 351 | 시간 6[s] | 손실 0.49
# | 에폭 19 |  반복 301 / 351 | 시간 7[s] | 손실 0.47
# | 에폭 19 |  반복 321 / 351 | 시간 7[s] | 손실 0.45
# | 에폭 19 |  반복 341 / 351 | 시간 7[s] | 손실 0.47
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 423
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 30.200%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 20 |  반복 41 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 20 |  반복 81 / 351 | 시간 1[s] | 손실 0.44
# | 에폭 20 |  반복 101 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 20 |  반복 121 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 20 |  반복 141 / 351 | 시간 3[s] | 손실 0.45
# | 에폭 20 |  반복 161 / 351 | 시간 3[s] | 손실 0.44
# | 에폭 20 |  반복 181 / 351 | 시간 4[s] | 손실 0.44
# | 에폭 20 |  반복 201 / 351 | 시간 4[s] | 손실 0.44
# | 에폭 20 |  반복 221 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 20 |  반복 241 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 20 |  반복 261 / 351 | 시간 6[s] | 손실 0.42
# | 에폭 20 |  반복 281 / 351 | 시간 6[s] | 손실 0.44
# | 에폭 20 |  반복 301 / 351 | 시간 7[s] | 손실 0.44
# | 에폭 20 |  반복 321 / 351 | 시간 7[s] | 손실 0.45
# | 에폭 20 |  반복 341 / 351 | 시간 8[s] | 손실 0.43
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1140
# ---
# Q 582+84
# T 666
# ☒ 669
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1426
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 27.000%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 21 |  반복 41 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 21 |  반복 61 / 351 | 시간 1[s] | 손실 0.44
# | 에폭 21 |  반복 81 / 351 | 시간 2[s] | 손실 0.44
# | 에폭 21 |  반복 101 / 351 | 시간 2[s] | 손실 0.43
# | 에폭 21 |  반복 121 / 351 | 시간 3[s] | 손실 0.42
# | 에폭 21 |  반복 141 / 351 | 시간 3[s] | 손실 0.42
# | 에폭 21 |  반복 161 / 351 | 시간 3[s] | 손실 0.44
# | 에폭 21 |  반복 181 / 351 | 시간 4[s] | 손실 0.43
# | 에폭 21 |  반복 201 / 351 | 시간 4[s] | 손실 0.43
# | 에폭 21 |  반복 221 / 351 | 시간 5[s] | 손실 0.44
# | 에폭 21 |  반복 241 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 21 |  반복 261 / 351 | 시간 6[s] | 손실 0.47
# | 에폭 21 |  반복 281 / 351 | 시간 6[s] | 손실 0.43
# | 에폭 21 |  반복 301 / 351 | 시간 7[s] | 손실 0.49
# | 에폭 21 |  반복 321 / 351 | 시간 7[s] | 손실 0.49
# | 에폭 21 |  반복 341 / 351 | 시간 9[s] | 손실 0.48
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☒ 860
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 25.120%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 22 |  반복 61 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 22 |  반복 81 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 22 |  반복 101 / 351 | 시간 3[s] | 손실 0.48
# | 에폭 22 |  반복 121 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 22 |  반복 141 / 351 | 시간 3[s] | 손실 0.42
# | 에폭 22 |  반복 161 / 351 | 시간 4[s] | 손실 0.43
# | 에폭 22 |  반복 181 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 22 |  반복 201 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 22 |  반복 221 / 351 | 시간 5[s] | 손실 0.42
# | 에폭 22 |  반복 241 / 351 | 시간 6[s] | 손실 0.44
# | 에폭 22 |  반복 261 / 351 | 시간 6[s] | 손실 0.44
# | 에폭 22 |  반복 281 / 351 | 시간 7[s] | 손실 0.43
# | 에폭 22 |  반복 301 / 351 | 시간 7[s] | 손실 0.44
# | 에폭 22 |  반복 321 / 351 | 시간 7[s] | 손실 0.48
# | 에폭 22 |  반복 341 / 351 | 시간 8[s] | 손실 0.46
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1143
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1430
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 26.640%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.43
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.42
# | 에폭 23 |  반복 41 / 351 | 시간 0[s] | 손실 0.49
# | 에폭 23 |  반복 61 / 351 | 시간 1[s] | 손실 0.47
# | 에폭 23 |  반복 81 / 351 | 시간 1[s] | 손실 0.47
# | 에폭 23 |  반복 101 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 23 |  반복 121 / 351 | 시간 2[s] | 손실 0.43
# | 에폭 23 |  반복 141 / 351 | 시간 3[s] | 손실 0.41
# | 에폭 23 |  반복 161 / 351 | 시간 3[s] | 손실 0.41
# | 에폭 23 |  반복 181 / 351 | 시간 4[s] | 손실 0.43
# | 에폭 23 |  반복 201 / 351 | 시간 5[s] | 손실 0.43
# | 에폭 23 |  반복 221 / 351 | 시간 5[s] | 손실 0.48
# | 에폭 23 |  반복 241 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 23 |  반복 261 / 351 | 시간 6[s] | 손실 0.43
# | 에폭 23 |  반복 281 / 351 | 시간 6[s] | 손실 0.42
# | 에폭 23 |  반복 301 / 351 | 시간 7[s] | 손실 0.44
# | 에폭 23 |  반복 321 / 351 | 시간 7[s] | 손실 0.43
# | 에폭 23 |  반복 341 / 351 | 시간 8[s] | 손실 0.42
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 232
# ---
# 검증 정확도 21.900%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.44
# | 에폭 24 |  반복 41 / 351 | 시간 0[s] | 손실 0.44
# | 에폭 24 |  반복 61 / 351 | 시간 1[s] | 손실 0.42
# | 에폭 24 |  반복 81 / 351 | 시간 1[s] | 손실 0.43
# | 에폭 24 |  반복 101 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 24 |  반복 121 / 351 | 시간 3[s] | 손실 0.43
# | 에폭 24 |  반복 141 / 351 | 시간 4[s] | 손실 0.43
# | 에폭 24 |  반복 161 / 351 | 시간 4[s] | 손실 0.48
# | 에폭 24 |  반복 181 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 24 |  반복 201 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 24 |  반복 221 / 351 | 시간 6[s] | 손실 0.46
# | 에폭 24 |  반복 241 / 351 | 시간 6[s] | 손실 0.46
# | 에폭 24 |  반복 261 / 351 | 시간 7[s] | 손실 0.47
# | 에폭 24 |  반복 281 / 351 | 시간 7[s] | 손실 0.45
# | 에폭 24 |  반복 301 / 351 | 시간 8[s] | 손실 0.42
# | 에폭 24 |  반복 321 / 351 | 시간 8[s] | 손실 0.42
# | 에폭 24 |  반복 341 / 351 | 시간 9[s] | 손실 0.43
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 854
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 26.980%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.48
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 25 |  반복 41 / 351 | 시간 1[s] | 손실 0.43
# | 에폭 25 |  반복 61 / 351 | 시간 1[s] | 손실 0.44
# | 에폭 25 |  반복 81 / 351 | 시간 2[s] | 손실 0.42
# | 에폭 25 |  반복 101 / 351 | 시간 2[s] | 손실 0.43
# | 에폭 25 |  반복 121 / 351 | 시간 2[s] | 손실 0.42
# | 에폭 25 |  반복 141 / 351 | 시간 3[s] | 손실 0.42
# | 에폭 25 |  반복 161 / 351 | 시간 3[s] | 손실 0.41
# | 에폭 25 |  반복 181 / 351 | 시간 4[s] | 손실 0.41
# | 에폭 25 |  반복 201 / 351 | 시간 5[s] | 손실 0.49
# | 에폭 25 |  반복 221 / 351 | 시간 5[s] | 손실 0.46
# | 에폭 25 |  반복 241 / 351 | 시간 6[s] | 손실 0.42
# | 에폭 25 |  반복 261 / 351 | 시간 6[s] | 손실 0.41
# | 에폭 25 |  반복 281 / 351 | 시간 7[s] | 손실 0.41
# | 에폭 25 |  반복 301 / 351 | 시간 7[s] | 손실 0.45
# | 에폭 25 |  반복 321 / 351 | 시간 8[s] | 손실 0.49
# | 에폭 25 |  반복 341 / 351 | 시간 8[s] | 손실 0.47
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 166
# ---
# Q 367+55
# T 422
# ☒ 425
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1426
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 15.800%

# %%
len(x_test)
# Out:
# 5000

# %%
plt.plot(np.arange(1,max_epoch+1), acc_listRNN, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %% [markdown]
# rnn relu

# %%
def relu(x):
    return np.max(x)

# %%
class RNNrelu:
    def __init__(self, Wx, Wh, b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None

    def forward(self, x, h_prev):
        Wx, Wh, b = self.params
        t = np.dot(h_prev, Wh) + np.dot(x, Wx) + b
        h_next = relu(t)

        self.cache = (x, h_prev, h_next)
        return h_next

    def backward(self, dh_next):
        Wx, Wh, b = self.params
        x, h_prev, h_next = self.cache

        dt = dh_next * (h_next > 0)
        db = np.sum(dt, axis=0)
        dWh = np.dot(h_prev.T, dt)
        dh_prev = np.dot(dt, Wh.T)
        dWx = np.dot(x.T, dt)
        dx = np.dot(dt, Wx.T)

        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db

        return dx, dh_prev

# %%
class TimeRNNrelu:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None

        self.h, self.dh = None, None
        self.stateful = stateful

    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        D, H = Wx.shape

        self.layers = []
        hs = np.empty((N, T, H), dtype='f')

        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')

        for t in range(T):
            layer = RNNrelu(*self.params)
            self.h = layer.forward(xs[:, t, :], self.h)
            hs[:, t, :] = self.h
            self.layers.append(layer)

        return hs

    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D, H = Wx.shape

        dxs = np.empty((N, T, D), dtype='f')
        dh = 0
        grads = [0, 0, 0]
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh = layer.backward(dhs[:, t, :] + dh)
            dxs[:, t, :] = dx

            for i, grad in enumerate(layer.grads):
                grads[i] += grad

        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
        self.dh = dh

        return dxs

    def set_state(self, h):
        self.h = h

    def reset_state(self):
        self.h = None

# %%
from common.time_layers import *

class EncoderRNNrelu:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        lstm_b = (rn(H)).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.rnn = TimeRNNrelu(lstm_Wx, lstm_Wh, lstm_b, stateful=False)

        self.params = self.embed.params + self.rnn.params
        self.grads = self.embed.grads + self.rnn.grads
        self.hs = None
    
    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.rnn.forward(xs)
        self.hs = hs
        return hs[:, -1, :]
    
    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh

        dout = self.rnn.backward(dhs)
        dout = self.embed.backward(dout)
        return dout

# %% [markdown]
# Decoder 클래스

# %%
class DecoderRNNrelu:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        lstm_b = (rn(H)).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.rnn = TimeRNNrelu(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.rnn, self.affine):
            self.params += layer.params
            self.grads += layer.grads
    
    def forward(self, xs, h):
        self.rnn.set_state(h)

        out = self.embed.forward(xs)
        out = self.rnn.forward(out)
        score = self.affine.forward(out)
        return score
    
    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.rnn.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.rnn.dh
        return dh
    
    def generate(self, h, start_id, sample_size): ## decoder의 학습과 생성이 다른 이유? 학습은 probabilistic vs 생성은 deterministic
        sampled = []
        sample_id = start_id
        self.rnn.set_state(h)

        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1,1))
            out = self.embed.forward(x)
            out = self.rnn.forward(out)
            score = self.affine.forward(out) 

            ## score -> (1, 1, V)
            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))
        
        return sampled

# %% [markdown]
# Seq2seq 클래스

# %%
from common.base_model import BaseModel

class Seq2seqRNNrelu(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = EncoderRNNrelu(V, D, H)
        self.decoder = DecoderRNNrelu(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads
    
    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]
        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout
    
    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

# %% [markdown]
# seq2seq 평가

# %%
class PeekyDecoderRNNrelu:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(H + D, H) / np.sqrt(H + D)).astype('f')
        lstm_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(H).astype('f')
        affine_W = (rn(H + H, V) / np.sqrt(H + H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.rnn = TimeRNNrelu(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.rnn, self.affine):
            self.params += layer.params
            self.grads += layer.grads
        self.cache = None

    def forward(self, xs, h):
        N, T = xs.shape
        N, H = h.shape

        self.rnn.set_state(h)

        out = self.embed.forward(xs)
        hs = np.repeat(h, T, axis=0).reshape(N, T, H)
        out = np.concatenate((hs, out), axis=2)

        out = self.rnn.forward(out)
        out = np.concatenate((hs, out), axis=2)

        score = self.affine.forward(out)
        self.cache = H
        return score

    def backward(self, dscore):
        H = self.cache

        dout = self.affine.backward(dscore)
        dout, dhs0 = dout[:, :, H:], dout[:, :, :H]
        dout = self.rnn.backward(dout)
        dembed, dhs1 = dout[:, :, H:], dout[:, :, :H]
        self.embed.backward(dembed)

        dhs = dhs0 + dhs1
        dh = self.rnn.dh + np.sum(dhs, axis=1)
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        char_id = start_id
        self.rnn.set_state(h)

        H = h.shape[1]
        peeky_h = h.reshape(1, 1, H)
        for _ in range(sample_size):
            x = np.array([char_id]).reshape((1, 1))
            out = self.embed.forward(x)

            out = np.concatenate((peeky_h, out), axis=2)
            out = self.rnn.forward(out)
            out = np.concatenate((peeky_h, out), axis=2)
            score = self.affine.forward(out)

            char_id = np.argmax(score.flatten())
            sampled.append(char_id)

        return sampled


class PeekySeq2seqRNNrelu(Seq2seq):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = EncoderRNNrelu(V, D, H)
        self.decoder = PeekyDecoderRNNrelu(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq

(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

model = Seq2seqRNNrelu(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainerRNNrelu = Trainer(model, optimizer)

acc_listRNNrelu = []
for epoch in range(max_epoch):
    trainerRNNrelu.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    acc_listRNNrelu.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 13.07
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 5.51
# | 에폭 1 |  반복 41 / 351 | 시간 1[s] | 손실 2.71
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 2.90
# | 에폭 1 |  반복 81 / 351 | 시간 2[s] | 손실 2.98
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 2.96
# | 에폭 1 |  반복 121 / 351 | 시간 3[s] | 손실 3.00
# | 에폭 1 |  반복 141 / 351 | 시간 3[s] | 손실 3.04
# | 에폭 1 |  반복 161 / 351 | 시간 4[s] | 손실 3.06
# | 에폭 1 |  반복 181 / 351 | 시간 4[s] | 손실 3.13
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 3.13
# | 에폭 1 |  반복 221 / 351 | 시간 5[s] | 손실 3.22
# | 에폭 1 |  반복 241 / 351 | 시간 5[s] | 손실 3.28
# | 에폭 1 |  반복 261 / 351 | 시간 5[s] | 손실 3.42
# | 에폭 1 |  반복 281 / 351 | 시간 6[s] | 손실 3.46
# | 에폭 1 |  반복 301 / 351 | 시간 6[s] | 손실 3.63
# | 에폭 1 |  반복 321 / 351 | 시간 7[s] | 손실 3.68
# | 에폭 1 |  반복 341 / 351 | 시간 7[s] | 손실 3.83
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 3.86
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 3.99
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 4.13
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 4.23
# | 에폭 2 |  반복 81 / 351 | 시간 1[s] | 손실 4.37
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 4.65
# | 에폭 2 |  반복 121 / 351 | 시간 2[s] | 손실 4.70
# | 에폭 2 |  반복 141 / 351 | 시간 2[s] | 손실 4.87
# | 에폭 2 |  반복 161 / 351 | 시간 3[s] | 손실 5.06
# | 에폭 2 |  반복 181 / 351 | 시간 3[s] | 손실 5.37
# | 에폭 2 |  반복 201 / 351 | 시간 4[s] | 손실 5.58
# | 에폭 2 |  반복 221 / 351 | 시간 4[s] | 손실 5.84
# | 에폭 2 |  반복 241 / 351 | 시간 4[s] | 손실 6.03
# | 에폭 2 |  반복 261 / 351 | 시간 5[s] | 손실 6.20
# | 에폭 2 |  반복 281 / 351 | 시간 5[s] | 손실 6.49
# | 에폭 2 |  반복 301 / 351 | 시간 6[s] | 손실 6.88
# | 에폭 2 |  반복 321 / 351 | 시간 6[s] | 손실 7.14
# | 에폭 2 |  반복 341 / 351 | 시간 7[s] | 손실 7.46
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 7.39
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 8.07
# | 에폭 3 |  반복 41 / 351 | 시간 1[s] | 손실 8.29
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 8.77
# | 에폭 3 |  반복 81 / 351 | 시간 1[s] | 손실 9.33
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 9.58
# | 에폭 3 |  반복 121 / 351 | 시간 2[s] | 손실 10.24
# | 에폭 3 |  반복 141 / 351 | 시간 3[s] | 손실 10.46
# | 에폭 3 |  반복 161 / 351 | 시간 3[s] | 손실 11.19
# | 에폭 3 |  반복 181 / 351 | 시간 4[s] | 손실 12.19
# | 에폭 3 |  반복 201 / 351 | 시간 4[s] | 손실 12.69
# /Users/chanmuzi/coding/workspace/Study/Deep-Learning-from-Scratch/2권/common/time_layers.py:316: RuntimeWarning: divide by zero encountered in log
#   ls = np.log(ys[np.arange(N * T), ts])
# | 에폭 3 |  반복 221 / 351 | 시간 5[s] | 손실 inf
# | 에폭 3 |  반복 241 / 351 | 시간 5[s] | 손실 inf
# | 에폭 3 |  반복 261 / 351 | 시간 6[s] | 손실 inf
# | 에폭 3 |  반복 281 / 351 | 시간 6[s] | 손실 inf
# | 에폭 3 |  반복 301 / 351 | 시간 7[s] | 손실 inf
# | 에폭 3 |  반복 321 / 351 | 시간 7[s] | 손실 inf
# | 에폭 3 |  반복 341 / 351 | 시간 7[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 4 |  반복 41 / 351 | 시간 0[s] | 손실 inf
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 4 |  반복 81 / 351 | 시간 1[s] | 손실 inf
# | 에폭 4 |  반복 101 / 351 | 시간 1[s] | 손실 inf
# | 에폭 4 |  반복 121 / 351 | 시간 2[s] | 손실 inf
# | 에폭 4 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 4 |  반복 161 / 351 | 시간 3[s] | 손실 inf
# | 에폭 4 |  반복 181 / 351 | 시간 3[s] | 손실 inf
# | 에폭 4 |  반복 201 / 351 | 시간 4[s] | 손실 inf
# | 에폭 4 |  반복 221 / 351 | 시간 4[s] | 손실 inf
# | 에폭 4 |  반복 241 / 351 | 시간 5[s] | 손실 inf
# | 에폭 4 |  반복 261 / 351 | 시간 5[s] | 손실 inf
# | 에폭 4 |  반복 281 / 351 | 시간 6[s] | 손실 inf
# | 에폭 4 |  반복 301 / 351 | 시간 6[s] | 손실 inf
# | 에폭 4 |  반복 321 / 351 | 시간 6[s] | 손실 inf
# | 에폭 4 |  반복 341 / 351 | 시간 7[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 5 |  반복 41 / 351 | 시간 0[s] | 손실 inf
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 5 |  반복 81 / 351 | 시간 1[s] | 손실 inf
# | 에폭 5 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 5 |  반복 121 / 351 | 시간 2[s] | 손실 inf
# | 에폭 5 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 5 |  반복 161 / 351 | 시간 3[s] | 손실 inf
# | 에폭 5 |  반복 181 / 351 | 시간 3[s] | 손실 inf
# | 에폭 5 |  반복 201 / 351 | 시간 4[s] | 손실 inf
# | 에폭 5 |  반복 221 / 351 | 시간 4[s] | 손실 inf
# | 에폭 5 |  반복 241 / 351 | 시간 5[s] | 손실 inf
# | 에폭 5 |  반복 261 / 351 | 시간 6[s] | 손실 inf
# | 에폭 5 |  반복 281 / 351 | 시간 7[s] | 손실 inf
# | 에폭 5 |  반복 301 / 351 | 시간 7[s] | 손실 inf
# | 에폭 5 |  반복 321 / 351 | 시간 8[s] | 손실 inf
# | 에폭 5 |  반복 341 / 351 | 시간 8[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 6 |  반복 41 / 351 | 시간 0[s] | 손실 inf
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 6 |  반복 81 / 351 | 시간 1[s] | 손실 inf
# | 에폭 6 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 6 |  반복 121 / 351 | 시간 2[s] | 손실 inf
# | 에폭 6 |  반복 141 / 351 | 시간 2[s] | 손실 inf
# | 에폭 6 |  반복 161 / 351 | 시간 3[s] | 손실 inf
# | 에폭 6 |  반복 181 / 351 | 시간 4[s] | 손실 inf
# | 에폭 6 |  반복 201 / 351 | 시간 4[s] | 손실 inf
# | 에폭 6 |  반복 221 / 351 | 시간 5[s] | 손실 inf
# | 에폭 6 |  반복 241 / 351 | 시간 5[s] | 손실 inf
# | 에폭 6 |  반복 261 / 351 | 시간 6[s] | 손실 inf
# | 에폭 6 |  반복 281 / 351 | 시간 7[s] | 손실 inf
# | 에폭 6 |  반복 301 / 351 | 시간 7[s] | 손실 inf
# | 에폭 6 |  반복 321 / 351 | 시간 8[s] | 손실 inf
# | 에폭 6 |  반복 341 / 351 | 시간 9[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 7 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 7 |  반복 81 / 351 | 시간 2[s] | 손실 inf
# | 에폭 7 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 7 |  반복 121 / 351 | 시간 3[s] | 손실 inf
# | 에폭 7 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 7 |  반복 161 / 351 | 시간 4[s] | 손실 inf
# | 에폭 7 |  반복 181 / 351 | 시간 4[s] | 손실 inf
# | 에폭 7 |  반복 201 / 351 | 시간 5[s] | 손실 inf
# | 에폭 7 |  반복 221 / 351 | 시간 6[s] | 손실 inf
# | 에폭 7 |  반복 241 / 351 | 시간 6[s] | 손실 inf
# | 에폭 7 |  반복 261 / 351 | 시간 7[s] | 손실 inf
# | 에폭 7 |  반복 281 / 351 | 시간 7[s] | 손실 inf
# | 에폭 7 |  반복 301 / 351 | 시간 8[s] | 손실 inf
# | 에폭 7 |  반복 321 / 351 | 시간 8[s] | 손실 inf
# | 에폭 7 |  반복 341 / 351 | 시간 9[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 8 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 8 |  반복 61 / 351 | 시간 2[s] | 손실 inf
# | 에폭 8 |  반복 81 / 351 | 시간 3[s] | 손실 inf
# | 에폭 8 |  반복 101 / 351 | 시간 4[s] | 손실 inf
# | 에폭 8 |  반복 121 / 351 | 시간 4[s] | 손실 inf
# | 에폭 8 |  반복 141 / 351 | 시간 5[s] | 손실 inf
# | 에폭 8 |  반복 161 / 351 | 시간 5[s] | 손실 inf
# | 에폭 8 |  반복 181 / 351 | 시간 6[s] | 손실 inf
# | 에폭 8 |  반복 201 / 351 | 시간 7[s] | 손실 inf
# | 에폭 8 |  반복 221 / 351 | 시간 8[s] | 손실 inf
# | 에폭 8 |  반복 241 / 351 | 시간 8[s] | 손실 inf
# | 에폭 8 |  반복 261 / 351 | 시간 9[s] | 손실 inf
# | 에폭 8 |  반복 281 / 351 | 시간 10[s] | 손실 inf
# | 에폭 8 |  반복 301 / 351 | 시간 11[s] | 손실 inf
# | 에폭 8 |  반복 321 / 351 | 시간 12[s] | 손실 inf
# | 에폭 8 |  반복 341 / 351 | 시간 12[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 9 |  반복 41 / 351 | 시간 0[s] | 손실 inf
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 9 |  반복 81 / 351 | 시간 1[s] | 손실 inf
# | 에폭 9 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 9 |  반복 121 / 351 | 시간 2[s] | 손실 inf
# | 에폭 9 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 9 |  반복 161 / 351 | 시간 4[s] | 손실 inf
# | 에폭 9 |  반복 181 / 351 | 시간 4[s] | 손실 inf
# | 에폭 9 |  반복 201 / 351 | 시간 5[s] | 손실 inf
# | 에폭 9 |  반복 221 / 351 | 시간 5[s] | 손실 inf
# | 에폭 9 |  반복 241 / 351 | 시간 6[s] | 손실 inf
# | 에폭 9 |  반복 261 / 351 | 시간 6[s] | 손실 inf
# | 에폭 9 |  반복 281 / 351 | 시간 7[s] | 손실 inf
# | 에폭 9 |  반복 301 / 351 | 시간 7[s] | 손실 inf
# | 에폭 9 |  반복 321 / 351 | 시간 8[s] | 손실 inf
# | 에폭 9 |  반복 341 / 351 | 시간 8[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 inf
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 10 |  반복 121 / 351 | 시간 3[s] | 손실 inf
# | 에폭 10 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 10 |  반복 161 / 351 | 시간 4[s] | 손실 inf
# | 에폭 10 |  반복 181 / 351 | 시간 4[s] | 손실 inf
# | 에폭 10 |  반복 201 / 351 | 시간 5[s] | 손실 inf
# | 에폭 10 |  반복 221 / 351 | 시간 5[s] | 손실 inf
# | 에폭 10 |  반복 241 / 351 | 시간 6[s] | 손실 inf
# | 에폭 10 |  반복 261 / 351 | 시간 6[s] | 손실 inf
# | 에폭 10 |  반복 281 / 351 | 시간 7[s] | 손실 inf
# | 에폭 10 |  반복 301 / 351 | 시간 7[s] | 손실 inf
# | 에폭 10 |  반복 321 / 351 | 시간 8[s] | 손실 inf
# | 에폭 10 |  반복 341 / 351 | 시간 8[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 11 |  반복 41 / 351 | 시간 0[s] | 손실 inf
# | 에폭 11 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 11 |  반복 81 / 351 | 시간 1[s] | 손실 inf
# | 에폭 11 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 11 |  반복 121 / 351 | 시간 2[s] | 손실 inf
# | 에폭 11 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 11 |  반복 161 / 351 | 시간 3[s] | 손실 inf
# | 에폭 11 |  반복 181 / 351 | 시간 3[s] | 손실 inf
# | 에폭 11 |  반복 201 / 351 | 시간 4[s] | 손실 inf
# | 에폭 11 |  반복 221 / 351 | 시간 4[s] | 손실 inf
# | 에폭 11 |  반복 241 / 351 | 시간 5[s] | 손실 inf
# | 에폭 11 |  반복 261 / 351 | 시간 5[s] | 손실 inf
# | 에폭 11 |  반복 281 / 351 | 시간 6[s] | 손실 inf
# | 에폭 11 |  반복 301 / 351 | 시간 6[s] | 손실 inf
# | 에폭 11 |  반복 321 / 351 | 시간 6[s] | 손실 inf
# | 에폭 11 |  반복 341 / 351 | 시간 7[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 inf
# | 에폭 12 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 12 |  반복 121 / 351 | 시간 3[s] | 손실 inf
# | 에폭 12 |  반복 141 / 351 | 시간 4[s] | 손실 inf
# | 에폭 12 |  반복 161 / 351 | 시간 4[s] | 손실 inf
# | 에폭 12 |  반복 181 / 351 | 시간 5[s] | 손실 inf
# | 에폭 12 |  반복 201 / 351 | 시간 6[s] | 손실 inf
# | 에폭 12 |  반복 221 / 351 | 시간 6[s] | 손실 inf
# | 에폭 12 |  반복 241 / 351 | 시간 7[s] | 손실 inf
# | 에폭 12 |  반복 261 / 351 | 시간 7[s] | 손실 inf
# | 에폭 12 |  반복 281 / 351 | 시간 8[s] | 손실 inf
# | 에폭 12 |  반복 301 / 351 | 시간 8[s] | 손실 inf
# | 에폭 12 |  반복 321 / 351 | 시간 9[s] | 손실 inf
# | 에폭 12 |  반복 341 / 351 | 시간 9[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 13 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 inf
# | 에폭 13 |  반복 101 / 351 | 시간 3[s] | 손실 inf
# | 에폭 13 |  반복 121 / 351 | 시간 3[s] | 손실 inf
# | 에폭 13 |  반복 141 / 351 | 시간 4[s] | 손실 inf
# | 에폭 13 |  반복 161 / 351 | 시간 4[s] | 손실 inf
# | 에폭 13 |  반복 181 / 351 | 시간 5[s] | 손실 inf
# | 에폭 13 |  반복 201 / 351 | 시간 5[s] | 손실 inf
# | 에폭 13 |  반복 221 / 351 | 시간 6[s] | 손실 inf
# | 에폭 13 |  반복 241 / 351 | 시간 6[s] | 손실 inf
# | 에폭 13 |  반복 261 / 351 | 시간 7[s] | 손실 inf
# | 에폭 13 |  반복 281 / 351 | 시간 8[s] | 손실 inf
# | 에폭 13 |  반복 301 / 351 | 시간 8[s] | 손실 inf
# | 에폭 13 |  반복 321 / 351 | 시간 9[s] | 손실 inf
# | 에폭 13 |  반복 341 / 351 | 시간 9[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 14 |  반복 41 / 351 | 시간 0[s] | 손실 inf
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 14 |  반복 81 / 351 | 시간 1[s] | 손실 inf
# | 에폭 14 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 14 |  반복 121 / 351 | 시간 2[s] | 손실 inf
# | 에폭 14 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 14 |  반복 161 / 351 | 시간 3[s] | 손실 inf
# | 에폭 14 |  반복 181 / 351 | 시간 3[s] | 손실 inf
# | 에폭 14 |  반복 201 / 351 | 시간 4[s] | 손실 inf
# | 에폭 14 |  반복 221 / 351 | 시간 4[s] | 손실 inf
# | 에폭 14 |  반복 241 / 351 | 시간 5[s] | 손실 inf
# | 에폭 14 |  반복 261 / 351 | 시간 5[s] | 손실 inf
# | 에폭 14 |  반복 281 / 351 | 시간 5[s] | 손실 inf
# | 에폭 14 |  반복 301 / 351 | 시간 6[s] | 손실 inf
# | 에폭 14 |  반복 321 / 351 | 시간 6[s] | 손실 inf
# | 에폭 14 |  반복 341 / 351 | 시간 7[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 15 |  반복 41 / 351 | 시간 0[s] | 손실 inf
# | 에폭 15 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 15 |  반복 81 / 351 | 시간 1[s] | 손실 inf
# | 에폭 15 |  반복 101 / 351 | 시간 1[s] | 손실 inf
# | 에폭 15 |  반복 121 / 351 | 시간 2[s] | 손실 inf
# | 에폭 15 |  반복 141 / 351 | 시간 2[s] | 손실 inf
# | 에폭 15 |  반복 161 / 351 | 시간 2[s] | 손실 inf
# | 에폭 15 |  반복 181 / 351 | 시간 3[s] | 손실 inf
# | 에폭 15 |  반복 201 / 351 | 시간 3[s] | 손실 inf
# | 에폭 15 |  반복 221 / 351 | 시간 3[s] | 손실 inf
# | 에폭 15 |  반복 241 / 351 | 시간 4[s] | 손실 inf
# | 에폭 15 |  반복 261 / 351 | 시간 4[s] | 손실 inf
# | 에폭 15 |  반복 281 / 351 | 시간 4[s] | 손실 inf
# | 에폭 15 |  반복 301 / 351 | 시간 5[s] | 손실 inf
# | 에폭 15 |  반복 321 / 351 | 시간 5[s] | 손실 inf
# | 에폭 15 |  반복 341 / 351 | 시간 5[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 16 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 inf
# | 에폭 16 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 16 |  반복 121 / 351 | 시간 3[s] | 손실 inf
# | 에폭 16 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 16 |  반복 161 / 351 | 시간 4[s] | 손실 inf
# | 에폭 16 |  반복 181 / 351 | 시간 4[s] | 손실 inf
# | 에폭 16 |  반복 201 / 351 | 시간 5[s] | 손실 inf
# | 에폭 16 |  반복 221 / 351 | 시간 5[s] | 손실 inf
# | 에폭 16 |  반복 241 / 351 | 시간 6[s] | 손실 inf
# | 에폭 16 |  반복 261 / 351 | 시간 6[s] | 손실 inf
# | 에폭 16 |  반복 281 / 351 | 시간 7[s] | 손실 inf
# | 에폭 16 |  반복 301 / 351 | 시간 7[s] | 손실 inf
# | 에폭 16 |  반복 321 / 351 | 시간 7[s] | 손실 inf
# | 에폭 16 |  반복 341 / 351 | 시간 8[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 17 |  반복 41 / 351 | 시간 0[s] | 손실 inf
# | 에폭 17 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 17 |  반복 81 / 351 | 시간 1[s] | 손실 inf
# | 에폭 17 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 17 |  반복 121 / 351 | 시간 2[s] | 손실 inf
# | 에폭 17 |  반복 141 / 351 | 시간 2[s] | 손실 inf
# | 에폭 17 |  반복 161 / 351 | 시간 3[s] | 손실 inf
# | 에폭 17 |  반복 181 / 351 | 시간 3[s] | 손실 inf
# | 에폭 17 |  반복 201 / 351 | 시간 3[s] | 손실 inf
# | 에폭 17 |  반복 221 / 351 | 시간 4[s] | 손실 inf
# | 에폭 17 |  반복 241 / 351 | 시간 4[s] | 손실 inf
# | 에폭 17 |  반복 261 / 351 | 시간 5[s] | 손실 inf
# | 에폭 17 |  반복 281 / 351 | 시간 5[s] | 손실 inf
# | 에폭 17 |  반복 301 / 351 | 시간 5[s] | 손실 inf
# | 에폭 17 |  반복 321 / 351 | 시간 6[s] | 손실 inf
# | 에폭 17 |  반복 341 / 351 | 시간 6[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 18 |  반복 41 / 351 | 시간 0[s] | 손실 inf
# | 에폭 18 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 18 |  반복 81 / 351 | 시간 1[s] | 손실 inf
# | 에폭 18 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 18 |  반복 121 / 351 | 시간 2[s] | 손실 inf
# | 에폭 18 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 18 |  반복 161 / 351 | 시간 3[s] | 손실 inf
# | 에폭 18 |  반복 181 / 351 | 시간 4[s] | 손실 inf
# | 에폭 18 |  반복 201 / 351 | 시간 4[s] | 손실 inf
# | 에폭 18 |  반복 221 / 351 | 시간 5[s] | 손실 inf
# | 에폭 18 |  반복 241 / 351 | 시간 5[s] | 손실 inf
# | 에폭 18 |  반복 261 / 351 | 시간 6[s] | 손실 inf
# | 에폭 18 |  반복 281 / 351 | 시간 6[s] | 손실 inf
# | 에폭 18 |  반복 301 / 351 | 시간 7[s] | 손실 inf
# | 에폭 18 |  반복 321 / 351 | 시간 7[s] | 손실 inf
# | 에폭 18 |  반복 341 / 351 | 시간 8[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 19 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 19 |  반복 81 / 351 | 시간 2[s] | 손실 inf
# | 에폭 19 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 19 |  반복 121 / 351 | 시간 3[s] | 손실 inf
# | 에폭 19 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 19 |  반복 161 / 351 | 시간 3[s] | 손실 inf
# | 에폭 19 |  반복 181 / 351 | 시간 4[s] | 손실 inf
# | 에폭 19 |  반복 201 / 351 | 시간 4[s] | 손실 inf
# | 에폭 19 |  반복 221 / 351 | 시간 5[s] | 손실 inf
# | 에폭 19 |  반복 241 / 351 | 시간 5[s] | 손실 inf
# | 에폭 19 |  반복 261 / 351 | 시간 6[s] | 손실 inf
# | 에폭 19 |  반복 281 / 351 | 시간 7[s] | 손실 inf
# | 에폭 19 |  반복 301 / 351 | 시간 8[s] | 손실 inf
# | 에폭 19 |  반복 321 / 351 | 시간 9[s] | 손실 inf
# | 에폭 19 |  반복 341 / 351 | 시간 10[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 20 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 20 |  반복 81 / 351 | 시간 2[s] | 손실 inf
# | 에폭 20 |  반복 101 / 351 | 시간 3[s] | 손실 inf
# | 에폭 20 |  반복 121 / 351 | 시간 4[s] | 손실 inf
# | 에폭 20 |  반복 141 / 351 | 시간 5[s] | 손실 inf
# | 에폭 20 |  반복 161 / 351 | 시간 6[s] | 손실 inf
# | 에폭 20 |  반복 181 / 351 | 시간 6[s] | 손실 inf
# | 에폭 20 |  반복 201 / 351 | 시간 7[s] | 손실 inf
# | 에폭 20 |  반복 221 / 351 | 시간 8[s] | 손실 inf
# | 에폭 20 |  반복 241 / 351 | 시간 8[s] | 손실 inf
# | 에폭 20 |  반복 261 / 351 | 시간 9[s] | 손실 inf
# | 에폭 20 |  반복 281 / 351 | 시간 9[s] | 손실 inf
# | 에폭 20 |  반복 301 / 351 | 시간 10[s] | 손실 inf
# | 에폭 20 |  반복 321 / 351 | 시간 10[s] | 손실 inf
# | 에폭 20 |  반복 341 / 351 | 시간 13[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 21 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 21 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 21 |  반복 81 / 351 | 시간 2[s] | 손실 inf
# | 에폭 21 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 21 |  반복 121 / 351 | 시간 3[s] | 손실 inf
# | 에폭 21 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 21 |  반복 161 / 351 | 시간 4[s] | 손실 inf
# | 에폭 21 |  반복 181 / 351 | 시간 4[s] | 손실 inf
# | 에폭 21 |  반복 201 / 351 | 시간 5[s] | 손실 inf
# | 에폭 21 |  반복 221 / 351 | 시간 5[s] | 손실 inf
# | 에폭 21 |  반복 241 / 351 | 시간 5[s] | 손실 inf
# | 에폭 21 |  반복 261 / 351 | 시간 6[s] | 손실 inf
# | 에폭 21 |  반복 281 / 351 | 시간 6[s] | 손실 inf
# | 에폭 21 |  반복 301 / 351 | 시간 7[s] | 손실 inf
# | 에폭 21 |  반복 321 / 351 | 시간 8[s] | 손실 inf
# | 에폭 21 |  반복 341 / 351 | 시간 8[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 22 |  반복 21 / 351 | 시간 1[s] | 손실 inf
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 22 |  반복 61 / 351 | 시간 3[s] | 손실 inf
# | 에폭 22 |  반복 81 / 351 | 시간 6[s] | 손실 inf
# | 에폭 22 |  반복 101 / 351 | 시간 6[s] | 손실 inf
# | 에폭 22 |  반복 121 / 351 | 시간 7[s] | 손실 inf
# | 에폭 22 |  반복 141 / 351 | 시간 7[s] | 손실 inf
# | 에폭 22 |  반복 161 / 351 | 시간 8[s] | 손실 inf
# | 에폭 22 |  반복 181 / 351 | 시간 8[s] | 손실 inf
# | 에폭 22 |  반복 201 / 351 | 시간 8[s] | 손실 inf
# | 에폭 22 |  반복 221 / 351 | 시간 9[s] | 손실 inf
# | 에폭 22 |  반복 241 / 351 | 시간 9[s] | 손실 inf
# | 에폭 22 |  반복 261 / 351 | 시간 10[s] | 손실 inf
# | 에폭 22 |  반복 281 / 351 | 시간 10[s] | 손실 inf
# | 에폭 22 |  반복 301 / 351 | 시간 10[s] | 손실 inf
# | 에폭 22 |  반복 321 / 351 | 시간 11[s] | 손실 inf
# | 에폭 22 |  반복 341 / 351 | 시간 11[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 23 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 23 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 23 |  반복 81 / 351 | 시간 2[s] | 손실 inf
# | 에폭 23 |  반복 101 / 351 | 시간 3[s] | 손실 inf
# | 에폭 23 |  반복 121 / 351 | 시간 4[s] | 손실 inf
# | 에폭 23 |  반복 141 / 351 | 시간 4[s] | 손실 inf
# | 에폭 23 |  반복 161 / 351 | 시간 5[s] | 손실 inf
# | 에폭 23 |  반복 181 / 351 | 시간 6[s] | 손실 inf
# | 에폭 23 |  반복 201 / 351 | 시간 7[s] | 손실 inf
# | 에폭 23 |  반복 221 / 351 | 시간 8[s] | 손실 inf
# | 에폭 23 |  반복 241 / 351 | 시간 9[s] | 손실 inf
# | 에폭 23 |  반복 261 / 351 | 시간 9[s] | 손실 inf
# | 에폭 23 |  반복 281 / 351 | 시간 10[s] | 손실 inf
# | 에폭 23 |  반복 301 / 351 | 시간 10[s] | 손실 inf
# | 에폭 23 |  반복 321 / 351 | 시간 11[s] | 손실 inf
# | 에폭 23 |  반복 341 / 351 | 시간 12[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 24 |  반복 21 / 351 | 시간 1[s] | 손실 inf
# | 에폭 24 |  반복 41 / 351 | 시간 2[s] | 손실 inf
# | 에폭 24 |  반복 61 / 351 | 시간 3[s] | 손실 inf
# | 에폭 24 |  반복 81 / 351 | 시간 4[s] | 손실 inf
# | 에폭 24 |  반복 101 / 351 | 시간 5[s] | 손실 inf
# | 에폭 24 |  반복 121 / 351 | 시간 6[s] | 손실 inf
# | 에폭 24 |  반복 141 / 351 | 시간 7[s] | 손실 inf
# | 에폭 24 |  반복 161 / 351 | 시간 8[s] | 손실 inf
# | 에폭 24 |  반복 181 / 351 | 시간 9[s] | 손실 inf
# | 에폭 24 |  반복 201 / 351 | 시간 10[s] | 손실 inf
# | 에폭 24 |  반복 221 / 351 | 시간 11[s] | 손실 inf
# | 에폭 24 |  반복 241 / 351 | 시간 11[s] | 손실 inf
# | 에폭 24 |  반복 261 / 351 | 시간 12[s] | 손실 inf
# | 에폭 24 |  반복 281 / 351 | 시간 12[s] | 손실 inf
# | 에폭 24 |  반복 301 / 351 | 시간 13[s] | 손실 inf
# | 에폭 24 |  반복 321 / 351 | 시간 14[s] | 손실 inf
# | 에폭 24 |  반복 341 / 351 | 시간 15[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 inf
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 inf
# | 에폭 25 |  반복 41 / 351 | 시간 1[s] | 손실 inf
# | 에폭 25 |  반복 61 / 351 | 시간 1[s] | 손실 inf
# | 에폭 25 |  반복 81 / 351 | 시간 1[s] | 손실 inf
# | 에폭 25 |  반복 101 / 351 | 시간 2[s] | 손실 inf
# | 에폭 25 |  반복 121 / 351 | 시간 2[s] | 손실 inf
# | 에폭 25 |  반복 141 / 351 | 시간 3[s] | 손실 inf
# | 에폭 25 |  반복 161 / 351 | 시간 3[s] | 손실 inf
# | 에폭 25 |  반복 181 / 351 | 시간 4[s] | 손실 inf
# | 에폭 25 |  반복 201 / 351 | 시간 5[s] | 손실 inf
# | 에폭 25 |  반복 221 / 351 | 시간 8[s] | 손실 inf
# | 에폭 25 |  반복 241 / 351 | 시간 9[s] | 손실 inf
# | 에폭 25 |  반복 261 / 351 | 시간 10[s] | 손실 inf
# | 에폭 25 |  반복 281 / 351 | 시간 10[s] | 손실 inf
# | 에폭 25 |  반복 301 / 351 | 시간 11[s] | 손실 inf
# | 에폭 25 |  반복 321 / 351 | 시간 11[s] | 손실 inf
# | 에폭 25 |  반복 341 / 351 | 시간 12[s] | 손실 inf
# Q 77+85
# T 162
# ☒ 9999
# ---
# Q 975+164
# T 1139
# ☒ 9999
# ---
# Q 582+84
# T 666
# ☒ 9999
# ---
# Q 8+155
# T 163
# ☒ 9999
# ---
# Q 367+55
# T 422
# ☒ 9999
# ---
# Q 600+257
# T 857
# ☒ 9999
# ---
# Q 761+292
# T 1053
# ☒ 9999
# ---
# Q 830+597
# T 1427
# ☒ 9999
# ---
# Q 26+838
# T 864
# ☒ 9999
# ---
# Q 143+93
# T 236
# ☒ 9999
# ---
# 검증 정확도 0.000%

# %%
for idx,grad in enumerate(model.grads):
    print(f"mean grad of {idx+1}'s layer: {grad.mean()}")
# Out:
# mean grad of 1's layer: 0.06596656888723373
# mean grad of 2's layer: 0.006557966582477093
# mean grad of 3's layer: -4.8457281081937253e-05
# mean grad of 4's layer: -0.003033112734556198
# mean grad of 5's layer: 7.738301388595479e-22
# mean grad of 6's layer: 8.139319145308942e-23
# mean grad of 7's layer: -4.700915763426738e-13
# mean grad of 8's layer: 9.813224077486599e-21
# mean grad of 9's layer: 9.244908842763171e-18
# mean grad of 10's layer: -4.971037520239824e-28

# %%
plt.plot(np.arange(1,len(acc_listRNNrelu)+1), acc_listRNNrelu, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %% [markdown]
# leaky relu

# %%
def leaky_relu(x, alpha=0.01):
    """
    Implement the Leaky ReLU function.
    
    Parameters:
    x (array_like): An array-like object containing the input data.
    alpha (float): Slope of the function for x < 0. Default is 0.01.
    
    Returns:
    ndarray: An array where each element is the Leaky ReLU of the corresponding element in x.
    """
    return np.where(x > 0, x, x * alpha)

# %% [markdown]
# ---------------

# %%
class RNNrelul:
    def __init__(self, Wx, Wh, b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None

    def forward(self, x, h_prev, alpha=0.01):
        Wx, Wh, b = self.params
        t = np.dot(h_prev, Wh) + np.dot(x, Wx) + b
        h_next = leaky_relu(t, alpha)

        self.cache = (x, h_prev, h_next, alpha)
        return h_next

    def backward(self, dh_next):
        Wx, Wh, b = self.params
        x, h_prev, h_next, alpha = self.cache

        dt = dh_next * np.where(h_next > 0, 1, alpha)
        db = np.sum(dt, axis=0)
        dWh = np.dot(h_prev.T, dt)
        dh_prev = np.dot(dt, Wh.T)
        dWx = np.dot(x.T, dt)
        dx = np.dot(dt, Wx.T)

        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db

        return dx, dh_prev

# %%
class TimeRNNrelul:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None

        self.h, self.dh = None, None
        self.stateful = stateful

    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        D, H = Wx.shape

        self.layers = []
        hs = np.empty((N, T, H), dtype='f')

        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')

        for t in range(T):
            layer = RNNrelul(*self.params)
            self.h = layer.forward(xs[:, t, :], self.h)
            hs[:, t, :] = self.h
            self.layers.append(layer)

        return hs

    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D, H = Wx.shape

        dxs = np.empty((N, T, D), dtype='f')
        dh = 0
        grads = [0, 0, 0]
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh = layer.backward(dhs[:, t, :] + dh)
            dxs[:, t, :] = dx

            for i, grad in enumerate(layer.grads):
                grads[i] += grad

        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
        self.dh = dh

        return dxs

    def set_state(self, h):
        self.h = h

    def reset_state(self):
        self.h = None

# %%
from common.time_layers import *

class EncoderRNNrelul:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        lstm_b = (rn(H)).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.rnn = TimeRNNrelul(lstm_Wx, lstm_Wh, lstm_b, stateful=False)

        self.params = self.embed.params + self.rnn.params
        self.grads = self.embed.grads + self.rnn.grads
        self.hs = None
    
    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.rnn.forward(xs)
        self.hs = hs
        return hs[:, -1, :]
    
    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh

        dout = self.rnn.backward(dhs)
        dout = self.embed.backward(dout)
        return dout

# %% [markdown]
# Decoder 클래스

# %%
class DecoderRNNrelul:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        lstm_b = (rn(H)).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.rnn = TimeRNNrelul(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.rnn, self.affine):
            self.params += layer.params
            self.grads += layer.grads
    
    def forward(self, xs, h):
        self.rnn.set_state(h)

        out = self.embed.forward(xs)
        out = self.rnn.forward(out)
        score = self.affine.forward(out)
        return score
    
    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.rnn.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.rnn.dh
        return dh
    
    def generate(self, h, start_id, sample_size): ## decoder의 학습과 생성이 다른 이유? 학습은 probabilistic vs 생성은 deterministic
        sampled = []
        sample_id = start_id
        self.rnn.set_state(h)

        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1,1))
            out = self.embed.forward(x)
            out = self.rnn.forward(out)
            score = self.affine.forward(out) 

            ## score -> (1, 1, V)
            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))
        
        return sampled

# %% [markdown]
# Seq2seq 클래스

# %%
from common.base_model import BaseModel

class Seq2seqRNNrelul(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = EncoderRNNrelul(V, D, H)
        self.decoder = DecoderRNNrelul(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads
    
    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]
        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout
    
    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

# %% [markdown]
# seq2seq 평가

# %%
class PeekyDecoderRNNrelul:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(H + D, H) / np.sqrt(H + D)).astype('f')
        lstm_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(H).astype('f')
        affine_W = (rn(H + H, V) / np.sqrt(H + H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.rnn = TimeRNNrelul(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.rnn, self.affine):
            self.params += layer.params
            self.grads += layer.grads
        self.cache = None

    def forward(self, xs, h):
        N, T = xs.shape
        N, H = h.shape

        self.rnn.set_state(h)

        out = self.embed.forward(xs)
        hs = np.repeat(h, T, axis=0).reshape(N, T, H)
        out = np.concatenate((hs, out), axis=2)

        out = self.rnn.forward(out)
        out = np.concatenate((hs, out), axis=2)

        score = self.affine.forward(out)
        self.cache = H
        return score

    def backward(self, dscore):
        H = self.cache

        dout = self.affine.backward(dscore)
        dout, dhs0 = dout[:, :, H:], dout[:, :, :H]
        dout = self.rnn.backward(dout)
        dembed, dhs1 = dout[:, :, H:], dout[:, :, :H]
        self.embed.backward(dembed)

        dhs = dhs0 + dhs1
        dh = self.rnn.dh + np.sum(dhs, axis=1)
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        char_id = start_id
        self.rnn.set_state(h)

        H = h.shape[1]
        peeky_h = h.reshape(1, 1, H)
        for _ in range(sample_size):
            x = np.array([char_id]).reshape((1, 1))
            out = self.embed.forward(x)

            out = np.concatenate((peeky_h, out), axis=2)
            out = self.rnn.forward(out)
            out = np.concatenate((peeky_h, out), axis=2)
            score = self.affine.forward(out)

            char_id = np.argmax(score.flatten())
            sampled.append(char_id)

        return sampled


class PeekySeq2seqRNNrelul(Seq2seq):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = EncoderRNNrelul(V, D, H)
        self.decoder = PeekyDecoderRNNrelul(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

# %%
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq

(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

modell = Seq2seqRNNrelul(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainerRNNrelul = Trainer(modell, optimizer)

acc_listRNNrelul = []
for epoch in range(max_epoch):
    trainerRNNrelul.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(modell, question, correct, id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    acc_listRNNrelul.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 3.56
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.32
# | 에폭 1 |  반복 41 / 351 | 시간 1[s] | 손실 1.96
# | 에폭 1 |  반복 61 / 351 | 시간 2[s] | 손실 1.92
# | 에폭 1 |  반복 81 / 351 | 시간 2[s] | 손실 1.92
# | 에폭 1 |  반복 101 / 351 | 시간 3[s] | 손실 1.89
# | 에폭 1 |  반복 121 / 351 | 시간 4[s] | 손실 1.88
# | 에폭 1 |  반복 141 / 351 | 시간 4[s] | 손실 1.82
# | 에폭 1 |  반복 161 / 351 | 시간 5[s] | 손실 1.79
# | 에폭 1 |  반복 181 / 351 | 시간 6[s] | 손실 1.77
# | 에폭 1 |  반복 201 / 351 | 시간 6[s] | 손실 1.76
# | 에폭 1 |  반복 221 / 351 | 시간 7[s] | 손실 1.75
# | 에폭 1 |  반복 241 / 351 | 시간 8[s] | 손실 1.74
# | 에폭 1 |  반복 261 / 351 | 시간 8[s] | 손실 1.73
# | 에폭 1 |  반복 281 / 351 | 시간 9[s] | 손실 1.71
# | 에폭 1 |  반복 301 / 351 | 시간 10[s] | 손실 1.69
# | 에폭 1 |  반복 321 / 351 | 시간 11[s] | 손실 1.68
# | 에폭 1 |  반복 341 / 351 | 시간 11[s] | 손실 1.66
# Q 77+85
# T 162
# ☒ 104
# ---
# Q 975+164
# T 1139
# ☒ 1010
# ---
# Q 582+84
# T 666
# ☒ 531
# ---
# Q 8+155
# T 163
# ☒ 325
# ---
# Q 367+55
# T 422
# ☒ 301
# ---
# Q 600+257
# T 857
# ☒ 1033
# ---
# Q 761+292
# T 1053
# ☒ 1010
# ---
# Q 830+597
# T 1427
# ☒ 1310
# ---
# Q 26+838
# T 864
# ☒ 601
# ---
# Q 143+93
# T 236
# ☒ 333
# ---
# 검증 정확도 0.240%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.61
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.62
# | 에폭 2 |  반복 41 / 351 | 시간 1[s] | 손실 1.58
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.55
# | 에폭 2 |  반복 81 / 351 | 시간 2[s] | 손실 1.52
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.48
# | 에폭 2 |  반복 121 / 351 | 시간 3[s] | 손실 1.45
# | 에폭 2 |  반복 141 / 351 | 시간 4[s] | 손실 1.43
# | 에폭 2 |  반복 161 / 351 | 시간 4[s] | 손실 1.41
# | 에폭 2 |  반복 181 / 351 | 시간 5[s] | 손실 1.38
# | 에폭 2 |  반복 201 / 351 | 시간 6[s] | 손실 1.37
# | 에폭 2 |  반복 221 / 351 | 시간 7[s] | 손실 1.36
# | 에폭 2 |  반복 241 / 351 | 시간 8[s] | 손실 1.34
# | 에폭 2 |  반복 261 / 351 | 시간 8[s] | 손실 1.33
# | 에폭 2 |  반복 281 / 351 | 시간 9[s] | 손실 1.33
# | 에폭 2 |  반복 301 / 351 | 시간 10[s] | 손실 1.31
# | 에폭 2 |  반복 321 / 351 | 시간 11[s] | 손실 1.30
# | 에폭 2 |  반복 341 / 351 | 시간 11[s] | 손실 1.30
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1101
# ---
# Q 582+84
# T 666
# ☒ 644
# ---
# Q 8+155
# T 163
# ☒ 170
# ---
# Q 367+55
# T 422
# ☒ 489
# ---
# Q 600+257
# T 857
# ☒ 829
# ---
# Q 761+292
# T 1053
# ☒ 1004
# ---
# Q 830+597
# T 1427
# ☒ 1400
# ---
# Q 26+838
# T 864
# ☒ 876
# ---
# Q 143+93
# T 236
# ☒ 282
# ---
# 검증 정확도 1.200%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.30
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.28
# | 에폭 3 |  반복 41 / 351 | 시간 1[s] | 손실 1.28
# | 에폭 3 |  반복 61 / 351 | 시간 2[s] | 손실 1.27
# | 에폭 3 |  반복 81 / 351 | 시간 3[s] | 손실 1.24
# | 에폭 3 |  반복 101 / 351 | 시간 4[s] | 손실 1.25
# | 에폭 3 |  반복 121 / 351 | 시간 5[s] | 손실 1.25
# | 에폭 3 |  반복 141 / 351 | 시간 5[s] | 손실 1.25
# | 에폭 3 |  반복 161 / 351 | 시간 6[s] | 손실 1.23
# | 에폭 3 |  반복 181 / 351 | 시간 7[s] | 손실 1.23
# | 에폭 3 |  반복 201 / 351 | 시간 9[s] | 손실 1.22
# | 에폭 3 |  반복 221 / 351 | 시간 10[s] | 손실 1.21
# | 에폭 3 |  반복 241 / 351 | 시간 10[s] | 손실 1.20
# | 에폭 3 |  반복 261 / 351 | 시간 11[s] | 손실 1.19
# | 에폭 3 |  반복 281 / 351 | 시간 12[s] | 손실 1.20
# | 에폭 3 |  반복 301 / 351 | 시간 13[s] | 손실 1.18
# | 에폭 3 |  반복 321 / 351 | 시간 14[s] | 손실 1.17
# | 에폭 3 |  반복 341 / 351 | 시간 14[s] | 손실 1.17
# Q 77+85
# T 162
# ☒ 159
# ---
# Q 975+164
# T 1139
# ☒ 1108
# ---
# Q 582+84
# T 666
# ☒ 641
# ---
# Q 8+155
# T 163
# ☒ 179
# ---
# Q 367+55
# T 422
# ☒ 442
# ---
# Q 600+257
# T 857
# ☒ 839
# ---
# Q 761+292
# T 1053
# ☒ 1001
# ---
# Q 830+597
# T 1427
# ☒ 1483
# ---
# Q 26+838
# T 864
# ☒ 849
# ---
# Q 143+93
# T 236
# ☒ 289
# ---
# 검증 정확도 2.480%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.15
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.16
# | 에폭 4 |  반복 41 / 351 | 시간 1[s] | 손실 1.16
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.13
# | 에폭 4 |  반복 81 / 351 | 시간 2[s] | 손실 1.13
# | 에폭 4 |  반복 101 / 351 | 시간 3[s] | 손실 1.12
# | 에폭 4 |  반복 121 / 351 | 시간 3[s] | 손실 1.10
# | 에폭 4 |  반복 141 / 351 | 시간 4[s] | 손실 1.11
# | 에폭 4 |  반복 161 / 351 | 시간 5[s] | 손실 1.10
# | 에폭 4 |  반복 181 / 351 | 시간 5[s] | 손실 1.10
# | 에폭 4 |  반복 201 / 351 | 시간 6[s] | 손실 1.08
# | 에폭 4 |  반복 221 / 351 | 시간 6[s] | 손실 1.07
# | 에폭 4 |  반복 241 / 351 | 시간 7[s] | 손실 1.06
# | 에폭 4 |  반복 261 / 351 | 시간 8[s] | 손실 1.04
# | 에폭 4 |  반복 281 / 351 | 시간 8[s] | 손실 1.05
# | 에폭 4 |  반복 301 / 351 | 시간 9[s] | 손실 1.06
# | 에폭 4 |  반복 321 / 351 | 시간 10[s] | 손실 1.05
# | 에폭 4 |  반복 341 / 351 | 시간 10[s] | 손실 1.04
# Q 77+85
# T 162
# ☒ 154
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 167
# ---
# Q 367+55
# T 422
# ☒ 417
# ---
# Q 600+257
# T 857
# ☒ 834
# ---
# Q 761+292
# T 1053
# ☒ 1007
# ---
# Q 830+597
# T 1427
# ☒ 1477
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 4.760%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.04
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 5 |  반복 41 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 0.98
# | 에폭 5 |  반복 81 / 351 | 시간 2[s] | 손실 0.98
# | 에폭 5 |  반복 101 / 351 | 시간 3[s] | 손실 0.96
# | 에폭 5 |  반복 121 / 351 | 시간 3[s] | 손실 0.97
# | 에폭 5 |  반복 141 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 5 |  반복 161 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 5 |  반복 181 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 5 |  반복 201 / 351 | 시간 7[s] | 손실 0.93
# | 에폭 5 |  반복 221 / 351 | 시간 7[s] | 손실 0.94
# | 에폭 5 |  반복 241 / 351 | 시간 8[s] | 손실 0.93
# | 에폭 5 |  반복 261 / 351 | 시간 9[s] | 손실 0.91
# | 에폭 5 |  반복 281 / 351 | 시간 9[s] | 손실 0.92
# | 에폭 5 |  반복 301 / 351 | 시간 10[s] | 손실 0.91
# | 에폭 5 |  반복 321 / 351 | 시간 11[s] | 손실 0.92
# | 에폭 5 |  반복 341 / 351 | 시간 11[s] | 손실 0.89
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1167
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 169
# ---
# Q 367+55
# T 422
# ☒ 429
# ---
# Q 600+257
# T 857
# ☒ 846
# ---
# Q 761+292
# T 1053
# ☒ 1032
# ---
# Q 830+597
# T 1427
# ☒ 1420
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 6.940%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 0.88
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 6 |  반복 101 / 351 | 시간 3[s] | 손실 0.86
# | 에폭 6 |  반복 121 / 351 | 시간 3[s] | 손실 0.86
# | 에폭 6 |  반복 141 / 351 | 시간 4[s] | 손실 0.87
# | 에폭 6 |  반복 161 / 351 | 시간 5[s] | 손실 0.86
# | 에폭 6 |  반복 181 / 351 | 시간 5[s] | 손실 0.86
# | 에폭 6 |  반복 201 / 351 | 시간 6[s] | 손실 0.85
# | 에폭 6 |  반복 221 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 6 |  반복 241 / 351 | 시간 7[s] | 손실 0.83
# | 에폭 6 |  반복 261 / 351 | 시간 8[s] | 손실 0.84
# | 에폭 6 |  반복 281 / 351 | 시간 8[s] | 손실 0.83
# | 에폭 6 |  반복 301 / 351 | 시간 9[s] | 손실 0.81
# | 에폭 6 |  반복 321 / 351 | 시간 10[s] | 손실 0.82
# | 에폭 6 |  반복 341 / 351 | 시간 10[s] | 손실 0.81
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1147
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 428
# ---
# Q 600+257
# T 857
# ☒ 864
# ---
# Q 761+292
# T 1053
# ☒ 1047
# ---
# Q 830+597
# T 1427
# ☒ 1371
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 243
# ---
# 검증 정확도 8.060%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.81
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 0.78
# | 에폭 7 |  반복 61 / 351 | 시간 2[s] | 손실 0.78
# | 에폭 7 |  반복 81 / 351 | 시간 3[s] | 손실 0.81
# | 에폭 7 |  반복 101 / 351 | 시간 4[s] | 손실 0.78
# | 에폭 7 |  반복 121 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 7 |  반복 141 / 351 | 시간 6[s] | 손실 0.78
# | 에폭 7 |  반복 161 / 351 | 시간 7[s] | 손실 0.78
# | 에폭 7 |  반복 181 / 351 | 시간 8[s] | 손실 0.79
# | 에폭 7 |  반복 201 / 351 | 시간 9[s] | 손실 0.78
# | 에폭 7 |  반복 221 / 351 | 시간 10[s] | 손실 0.76
# | 에폭 7 |  반복 241 / 351 | 시간 11[s] | 손실 0.76
# | 에폭 7 |  반복 261 / 351 | 시간 11[s] | 손실 0.75
# | 에폭 7 |  반복 281 / 351 | 시간 12[s] | 손실 0.80
# | 에폭 7 |  반복 301 / 351 | 시간 13[s] | 손실 0.79
# | 에폭 7 |  반복 321 / 351 | 시간 13[s] | 손실 0.78
# | 에폭 7 |  반복 341 / 351 | 시간 14[s] | 손실 0.74
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 663
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 863
# ---
# Q 761+292
# T 1053
# ☒ 1057
# ---
# Q 830+597
# T 1427
# ☒ 1420
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 10.760%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.74
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 0.74
# | 에폭 8 |  반복 41 / 351 | 시간 1[s] | 손실 0.73
# | 에폭 8 |  반복 61 / 351 | 시간 2[s] | 손실 0.73
# | 에폭 8 |  반복 81 / 351 | 시간 4[s] | 손실 0.72
# | 에폭 8 |  반복 101 / 351 | 시간 4[s] | 손실 0.72
# | 에폭 8 |  반복 121 / 351 | 시간 5[s] | 손실 0.73
# | 에폭 8 |  반복 141 / 351 | 시간 6[s] | 손실 0.73
# | 에폭 8 |  반복 161 / 351 | 시간 7[s] | 손실 0.71
# | 에폭 8 |  반복 181 / 351 | 시간 8[s] | 손실 0.73
# | 에폭 8 |  반복 201 / 351 | 시간 8[s] | 손실 0.71
# | 에폭 8 |  반복 221 / 351 | 시간 9[s] | 손실 0.73
# | 에폭 8 |  반복 241 / 351 | 시간 10[s] | 손실 0.70
# | 에폭 8 |  반복 261 / 351 | 시간 11[s] | 손실 0.71
# | 에폭 8 |  반복 281 / 351 | 시간 11[s] | 손실 0.71
# | 에폭 8 |  반복 301 / 351 | 시간 12[s] | 손실 0.70
# | 에폭 8 |  반복 321 / 351 | 시간 13[s] | 손실 0.70
# | 에폭 8 |  반복 341 / 351 | 시간 14[s] | 손실 0.69
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1046
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 860
# ---
# Q 143+93
# T 236
# ☒ 232
# ---
# 검증 정확도 10.900%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.71
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 0.67
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 0.68
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 0.69
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 0.72
# | 에폭 9 |  반복 101 / 351 | 시간 2[s] | 손실 0.70
# | 에폭 9 |  반복 121 / 351 | 시간 3[s] | 손실 0.67
# | 에폭 9 |  반복 141 / 351 | 시간 3[s] | 손실 0.66
# | 에폭 9 |  반복 161 / 351 | 시간 4[s] | 손실 0.66
# | 에폭 9 |  반복 181 / 351 | 시간 5[s] | 손실 0.66
# | 에폭 9 |  반복 201 / 351 | 시간 5[s] | 손실 0.66
# | 에폭 9 |  반복 221 / 351 | 시간 6[s] | 손실 0.65
# | 에폭 9 |  반복 241 / 351 | 시간 7[s] | 손실 0.66
# | 에폭 9 |  반복 261 / 351 | 시간 8[s] | 손실 0.65
# | 에폭 9 |  반복 281 / 351 | 시간 11[s] | 손실 0.64
# | 에폭 9 |  반복 301 / 351 | 시간 12[s] | 손실 0.67
# | 에폭 9 |  반복 321 / 351 | 시간 15[s] | 손실 0.69
# | 에폭 9 |  반복 341 / 351 | 시간 16[s] | 손실 0.65
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1147
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 865
# ---
# Q 761+292
# T 1053
# ☒ 1051
# ---
# Q 830+597
# T 1427
# ☒ 1435
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 14.700%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.62
# | 에폭 10 |  반복 21 / 351 | 시간 1[s] | 손실 0.63
# | 에폭 10 |  반복 41 / 351 | 시간 2[s] | 손실 0.63
# | 에폭 10 |  반복 61 / 351 | 시간 3[s] | 손실 0.65
# | 에폭 10 |  반복 81 / 351 | 시간 4[s] | 손실 0.66
# | 에폭 10 |  반복 101 / 351 | 시간 5[s] | 손실 0.65
# | 에폭 10 |  반복 121 / 351 | 시간 6[s] | 손실 0.61
# | 에폭 10 |  반복 141 / 351 | 시간 7[s] | 손실 0.65
# | 에폭 10 |  반복 161 / 351 | 시간 8[s] | 손실 0.67
# | 에폭 10 |  반복 181 / 351 | 시간 9[s] | 손실 0.62
# | 에폭 10 |  반복 201 / 351 | 시간 10[s] | 손실 0.62
# | 에폭 10 |  반복 221 / 351 | 시간 10[s] | 손실 0.64
# | 에폭 10 |  반복 241 / 351 | 시간 11[s] | 손실 0.61
# | 에폭 10 |  반복 261 / 351 | 시간 11[s] | 손실 0.61
# | 에폭 10 |  반복 281 / 351 | 시간 12[s] | 손실 0.61
# | 에폭 10 |  반복 301 / 351 | 시간 13[s] | 손실 0.63
# | 에폭 10 |  반복 321 / 351 | 시간 13[s] | 손실 0.62
# | 에폭 10 |  반복 341 / 351 | 시간 14[s] | 손실 0.60
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1045
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 16.100%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.60
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.60
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.60
# | 에폭 11 |  반복 61 / 351 | 시간 2[s] | 손실 0.59
# | 에폭 11 |  반복 81 / 351 | 시간 2[s] | 손실 0.59
# | 에폭 11 |  반복 101 / 351 | 시간 3[s] | 손실 0.60
# | 에폭 11 |  반복 121 / 351 | 시간 4[s] | 손실 0.61
# | 에폭 11 |  반복 141 / 351 | 시간 5[s] | 손실 0.58
# | 에폭 11 |  반복 161 / 351 | 시간 6[s] | 손실 0.60
# | 에폭 11 |  반복 181 / 351 | 시간 7[s] | 손실 0.60
# | 에폭 11 |  반복 201 / 351 | 시간 8[s] | 손실 0.60
# | 에폭 11 |  반복 221 / 351 | 시간 9[s] | 손실 0.58
# | 에폭 11 |  반복 241 / 351 | 시간 10[s] | 손실 0.59
# | 에폭 11 |  반복 261 / 351 | 시간 11[s] | 손실 0.66
# | 에폭 11 |  반복 281 / 351 | 시간 11[s] | 손실 0.58
# | 에폭 11 |  반복 301 / 351 | 시간 12[s] | 손실 0.58
# | 에폭 11 |  반복 321 / 351 | 시간 13[s] | 손실 0.59
# | 에폭 11 |  반복 341 / 351 | 시간 13[s] | 손실 0.58
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 161
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 864
# ---
# Q 761+292
# T 1053
# ☒ 1051
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 18.180%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.57
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.58
# | 에폭 12 |  반복 61 / 351 | 시간 2[s] | 손실 0.62
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.58
# | 에폭 12 |  반복 101 / 351 | 시간 3[s] | 손실 0.59
# | 에폭 12 |  반복 121 / 351 | 시간 3[s] | 손실 0.60
# | 에폭 12 |  반복 141 / 351 | 시간 4[s] | 손실 0.58
# | 에폭 12 |  반복 161 / 351 | 시간 5[s] | 손실 0.61
# | 에폭 12 |  반복 181 / 351 | 시간 6[s] | 손실 0.57
# | 에폭 12 |  반복 201 / 351 | 시간 7[s] | 손실 0.59
# | 에폭 12 |  반복 221 / 351 | 시간 7[s] | 손실 0.57
# | 에폭 12 |  반복 241 / 351 | 시간 8[s] | 손실 0.58
# | 에폭 12 |  반복 261 / 351 | 시간 9[s] | 손실 0.59
# | 에폭 12 |  반복 281 / 351 | 시간 10[s] | 손실 0.55
# | 에폭 12 |  반복 301 / 351 | 시간 11[s] | 손실 0.57
# | 에폭 12 |  반복 321 / 351 | 시간 12[s] | 손실 0.57
# | 에폭 12 |  반복 341 / 351 | 시간 13[s] | 손실 0.58
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1131
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 165
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1047
# ---
# Q 830+597
# T 1427
# ☒ 1431
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 19.360%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.54
# | 에폭 13 |  반복 21 / 351 | 시간 1[s] | 손실 0.54
# | 에폭 13 |  반복 41 / 351 | 시간 2[s] | 손실 0.55
# | 에폭 13 |  반복 61 / 351 | 시간 3[s] | 손실 0.54
# | 에폭 13 |  반복 81 / 351 | 시간 3[s] | 손실 0.55
# | 에폭 13 |  반복 101 / 351 | 시간 4[s] | 손실 0.54
# | 에폭 13 |  반복 121 / 351 | 시간 5[s] | 손실 0.54
# | 에폭 13 |  반복 141 / 351 | 시간 6[s] | 손실 0.55
# | 에폭 13 |  반복 161 / 351 | 시간 7[s] | 손실 0.54
# | 에폭 13 |  반복 181 / 351 | 시간 7[s] | 손실 0.57
# | 에폭 13 |  반복 201 / 351 | 시간 8[s] | 손실 0.55
# | 에폭 13 |  반복 221 / 351 | 시간 9[s] | 손실 0.55
# | 에폭 13 |  반복 241 / 351 | 시간 9[s] | 손실 0.54
# | 에폭 13 |  반복 261 / 351 | 시간 10[s] | 손실 0.59
# | 에폭 13 |  반복 281 / 351 | 시간 11[s] | 손실 0.55
# | 에폭 13 |  반복 301 / 351 | 시간 12[s] | 손실 0.54
# | 에폭 13 |  반복 321 / 351 | 시간 13[s] | 손실 0.55
# | 에폭 13 |  반복 341 / 351 | 시간 14[s] | 손실 0.52
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 669
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1051
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 18.960%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.57
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.54
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.53
# | 에폭 14 |  반복 61 / 351 | 시간 2[s] | 손실 0.54
# | 에폭 14 |  반복 81 / 351 | 시간 3[s] | 손실 0.53
# | 에폭 14 |  반복 101 / 351 | 시간 4[s] | 손실 0.58
# | 에폭 14 |  반복 121 / 351 | 시간 5[s] | 손실 0.57
# | 에폭 14 |  반복 141 / 351 | 시간 5[s] | 손실 0.57
# | 에폭 14 |  반복 161 / 351 | 시간 6[s] | 손실 0.55
# | 에폭 14 |  반복 181 / 351 | 시간 7[s] | 손실 0.57
# | 에폭 14 |  반복 201 / 351 | 시간 7[s] | 손실 0.55
# | 에폭 14 |  반복 221 / 351 | 시간 8[s] | 손실 0.56
# | 에폭 14 |  반복 241 / 351 | 시간 9[s] | 손실 0.54
# | 에폭 14 |  반복 261 / 351 | 시간 10[s] | 손실 0.57
# | 에폭 14 |  반복 281 / 351 | 시간 11[s] | 손실 0.56
# | 에폭 14 |  반복 301 / 351 | 시간 12[s] | 손실 0.55
# | 에폭 14 |  반복 321 / 351 | 시간 12[s] | 손실 0.55
# | 에폭 14 |  반복 341 / 351 | 시간 13[s] | 손실 0.56
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☒ 669
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 425
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1431
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 16.300%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.56
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 15 |  반복 41 / 351 | 시간 1[s] | 손실 0.54
# | 에폭 15 |  반복 61 / 351 | 시간 2[s] | 손실 0.50
# | 에폭 15 |  반복 81 / 351 | 시간 3[s] | 손실 0.53
# | 에폭 15 |  반복 101 / 351 | 시간 4[s] | 손실 0.56
# | 에폭 15 |  반복 121 / 351 | 시간 4[s] | 손실 0.52
# | 에폭 15 |  반복 141 / 351 | 시간 5[s] | 손실 0.51
# | 에폭 15 |  반복 161 / 351 | 시간 7[s] | 손실 0.52
# | 에폭 15 |  반복 181 / 351 | 시간 7[s] | 손실 0.53
# | 에폭 15 |  반복 201 / 351 | 시간 8[s] | 손실 0.52
# | 에폭 15 |  반복 221 / 351 | 시간 9[s] | 손실 0.53
# | 에폭 15 |  반복 241 / 351 | 시간 10[s] | 손실 0.51
# | 에폭 15 |  반복 261 / 351 | 시간 10[s] | 손실 0.50
# | 에폭 15 |  반복 281 / 351 | 시간 11[s] | 손실 0.51
# | 에폭 15 |  반복 301 / 351 | 시간 12[s] | 손실 0.53
# | 에폭 15 |  반복 321 / 351 | 시간 12[s] | 손실 0.51
# | 에폭 15 |  반복 341 / 351 | 시간 13[s] | 손실 0.51
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 423
# ---
# Q 600+257
# T 857
# ☒ 860
# ---
# Q 761+292
# T 1053
# ☒ 1051
# ---
# Q 830+597
# T 1427
# ☒ 1429
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 18.280%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.58
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.53
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.53
# | 에폭 16 |  반복 61 / 351 | 시간 2[s] | 손실 0.50
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 0.51
# | 에폭 16 |  반복 101 / 351 | 시간 3[s] | 손실 0.54
# | 에폭 16 |  반복 121 / 351 | 시간 4[s] | 손실 0.50
# | 에폭 16 |  반복 141 / 351 | 시간 4[s] | 손실 0.52
# | 에폭 16 |  반복 161 / 351 | 시간 5[s] | 손실 0.54
# | 에폭 16 |  반복 181 / 351 | 시간 6[s] | 손실 0.53
# | 에폭 16 |  반복 201 / 351 | 시간 7[s] | 손실 0.54
# | 에폭 16 |  반복 221 / 351 | 시간 8[s] | 손실 0.54
# | 에폭 16 |  반복 241 / 351 | 시간 9[s] | 손실 0.54
# | 에폭 16 |  반복 261 / 351 | 시간 10[s] | 손실 0.54
# | 에폭 16 |  반복 281 / 351 | 시간 11[s] | 손실 0.49
# | 에폭 16 |  반복 301 / 351 | 시간 12[s] | 손실 0.50
# | 에폭 16 |  반복 321 / 351 | 시간 13[s] | 손실 0.49
# | 에폭 16 |  반복 341 / 351 | 시간 14[s] | 손실 0.49
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 860
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1429
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 23.440%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.49
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.50
# | 에폭 17 |  반복 61 / 351 | 시간 2[s] | 손실 0.50
# | 에폭 17 |  반복 81 / 351 | 시간 3[s] | 손실 0.50
# | 에폭 17 |  반복 101 / 351 | 시간 4[s] | 손실 0.49
# | 에폭 17 |  반복 121 / 351 | 시간 5[s] | 손실 0.51
# | 에폭 17 |  반복 141 / 351 | 시간 5[s] | 손실 0.50
# | 에폭 17 |  반복 161 / 351 | 시간 6[s] | 손실 0.50
# | 에폭 17 |  반복 181 / 351 | 시간 7[s] | 손실 0.49
# | 에폭 17 |  반복 201 / 351 | 시간 8[s] | 손실 0.49
# | 에폭 17 |  반복 221 / 351 | 시간 8[s] | 손실 0.48
# | 에폭 17 |  반복 241 / 351 | 시간 9[s] | 손실 0.50
# | 에폭 17 |  반복 261 / 351 | 시간 10[s] | 손실 0.49
# | 에폭 17 |  반복 281 / 351 | 시간 10[s] | 손실 0.50
# | 에폭 17 |  반복 301 / 351 | 시간 11[s] | 손실 0.52
# | 에폭 17 |  반복 321 / 351 | 시간 12[s] | 손실 0.49
# | 에폭 17 |  반복 341 / 351 | 시간 13[s] | 손실 0.53
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 669
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 423
# ---
# Q 600+257
# T 857
# ☒ 863
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1431
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 12.580%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.62
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 18 |  반복 41 / 351 | 시간 1[s] | 손실 0.51
# | 에폭 18 |  반복 61 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 18 |  반복 81 / 351 | 시간 3[s] | 손실 0.48
# | 에폭 18 |  반복 101 / 351 | 시간 4[s] | 손실 0.48
# | 에폭 18 |  반복 121 / 351 | 시간 5[s] | 손실 0.48
# | 에폭 18 |  반복 141 / 351 | 시간 6[s] | 손실 0.47
# | 에폭 18 |  반복 161 / 351 | 시간 7[s] | 손실 0.50
# | 에폭 18 |  반복 181 / 351 | 시간 9[s] | 손실 0.48
# | 에폭 18 |  반복 201 / 351 | 시간 10[s] | 손실 0.50
# | 에폭 18 |  반복 221 / 351 | 시간 11[s] | 손실 0.50
# | 에폭 18 |  반복 241 / 351 | 시간 12[s] | 손실 0.46
# | 에폭 18 |  반복 261 / 351 | 시간 13[s] | 손실 0.47
# | 에폭 18 |  반복 281 / 351 | 시간 14[s] | 손실 0.48
# | 에폭 18 |  반복 301 / 351 | 시간 16[s] | 손실 0.48
# | 에폭 18 |  반복 321 / 351 | 시간 18[s] | 손실 0.48
# | 에폭 18 |  반복 341 / 351 | 시간 18[s] | 손실 0.49
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 26.580%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 19 |  반복 61 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 19 |  반복 81 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 19 |  반복 101 / 351 | 시간 4[s] | 손실 0.46
# | 에폭 19 |  반복 121 / 351 | 시간 5[s] | 손실 0.46
# | 에폭 19 |  반복 141 / 351 | 시간 6[s] | 손실 0.46
# | 에폭 19 |  반복 161 / 351 | 시간 7[s] | 손실 0.47
# | 에폭 19 |  반복 181 / 351 | 시간 8[s] | 손실 0.47
# | 에폭 19 |  반복 201 / 351 | 시간 9[s] | 손실 0.49
# | 에폭 19 |  반복 221 / 351 | 시간 9[s] | 손실 0.46
# | 에폭 19 |  반복 241 / 351 | 시간 10[s] | 손실 0.47
# | 에폭 19 |  반복 261 / 351 | 시간 11[s] | 손실 0.48
# | 에폭 19 |  반복 281 / 351 | 시간 11[s] | 손실 0.47
# | 에폭 19 |  반복 301 / 351 | 시간 12[s] | 손실 0.48
# | 에폭 19 |  반복 321 / 351 | 시간 13[s] | 손실 0.50
# | 에폭 19 |  반복 341 / 351 | 시간 13[s] | 손실 0.48
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 423
# ---
# Q 600+257
# T 857
# ☒ 860
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1429
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 28.400%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.44
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 20 |  반복 41 / 351 | 시간 1[s] | 손실 0.45
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 20 |  반복 81 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 20 |  반복 101 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 20 |  반복 121 / 351 | 시간 4[s] | 손실 0.45
# | 에폭 20 |  반복 141 / 351 | 시간 5[s] | 손실 0.46
# | 에폭 20 |  반복 161 / 351 | 시간 6[s] | 손실 0.45
# | 에폭 20 |  반복 181 / 351 | 시간 7[s] | 손실 0.46
# | 에폭 20 |  반복 201 / 351 | 시간 8[s] | 손실 0.46
# | 에폭 20 |  반복 221 / 351 | 시간 9[s] | 손실 0.47
# | 에폭 20 |  반복 241 / 351 | 시간 9[s] | 손실 0.51
# | 에폭 20 |  반복 261 / 351 | 시간 10[s] | 손실 0.47
# | 에폭 20 |  반복 281 / 351 | 시간 12[s] | 손실 0.47
# | 에폭 20 |  반복 301 / 351 | 시간 13[s] | 손실 0.47
# | 에폭 20 |  반복 321 / 351 | 시간 14[s] | 손실 0.45
# | 에폭 20 |  반복 341 / 351 | 시간 15[s] | 손실 0.44
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1143
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 861
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1431
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 13.800%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.54
# | 에폭 21 |  반복 21 / 351 | 시간 1[s] | 손실 0.51
# | 에폭 21 |  반복 41 / 351 | 시간 3[s] | 손실 0.50
# | 에폭 21 |  반복 61 / 351 | 시간 4[s] | 손실 0.49
# | 에폭 21 |  반복 81 / 351 | 시간 5[s] | 손실 0.48
# | 에폭 21 |  반복 101 / 351 | 시간 6[s] | 손실 0.49
# | 에폭 21 |  반복 121 / 351 | 시간 8[s] | 손실 0.49
# | 에폭 21 |  반복 141 / 351 | 시간 9[s] | 손실 0.48
# | 에폭 21 |  반복 161 / 351 | 시간 10[s] | 손실 0.49
# | 에폭 21 |  반복 181 / 351 | 시간 11[s] | 손실 0.49
# | 에폭 21 |  반복 201 / 351 | 시간 12[s] | 손실 0.48
# | 에폭 21 |  반복 221 / 351 | 시간 13[s] | 손실 0.48
# | 에폭 21 |  반복 241 / 351 | 시간 14[s] | 손실 0.49
# | 에폭 21 |  반복 261 / 351 | 시간 14[s] | 손실 0.48
# | 에폭 21 |  반복 281 / 351 | 시간 15[s] | 손실 0.48
# | 에폭 21 |  반복 301 / 351 | 시간 16[s] | 손실 0.49
# | 에폭 21 |  반복 321 / 351 | 시간 17[s] | 손실 0.48
# | 에폭 21 |  반복 341 / 351 | 시간 18[s] | 손실 0.48
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1134
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 854
# ---
# Q 761+292
# T 1053
# ☒ 1051
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 15.020%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.53
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.48
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 0.47
# | 에폭 22 |  반복 61 / 351 | 시간 2[s] | 손실 0.48
# | 에폭 22 |  반복 81 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 22 |  반복 101 / 351 | 시간 3[s] | 손실 0.45
# | 에폭 22 |  반복 121 / 351 | 시간 4[s] | 손실 0.47
# | 에폭 22 |  반복 141 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 22 |  반복 161 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 22 |  반복 181 / 351 | 시간 6[s] | 손실 0.46
# | 에폭 22 |  반복 201 / 351 | 시간 7[s] | 손실 0.45
# | 에폭 22 |  반복 221 / 351 | 시간 8[s] | 손실 0.46
# | 에폭 22 |  반복 241 / 351 | 시간 9[s] | 손실 0.54
# | 에폭 22 |  반복 261 / 351 | 시간 10[s] | 손실 0.49
# | 에폭 22 |  반복 281 / 351 | 시간 11[s] | 손실 0.46
# | 에폭 22 |  반복 301 / 351 | 시간 11[s] | 손실 0.45
# | 에폭 22 |  반복 321 / 351 | 시간 13[s] | 손실 0.46
# | 에폭 22 |  반복 341 / 351 | 시간 15[s] | 손실 0.45
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1134
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1426
# ---
# Q 26+838
# T 864
# ☒ 863
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 30.100%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.42
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 23 |  반복 41 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 23 |  반복 61 / 351 | 시간 3[s] | 손실 0.45
# | 에폭 23 |  반복 81 / 351 | 시간 4[s] | 손실 0.44
# | 에폭 23 |  반복 101 / 351 | 시간 4[s] | 손실 0.45
# | 에폭 23 |  반복 121 / 351 | 시간 6[s] | 손실 0.46
# | 에폭 23 |  반복 141 / 351 | 시간 6[s] | 손실 0.45
# | 에폭 23 |  반복 161 / 351 | 시간 7[s] | 손실 0.44
# | 에폭 23 |  반복 181 / 351 | 시간 8[s] | 손실 0.44
# | 에폭 23 |  반복 201 / 351 | 시간 9[s] | 손실 0.47
# | 에폭 23 |  반복 221 / 351 | 시간 10[s] | 손실 0.48
# | 에폭 23 |  반복 241 / 351 | 시간 10[s] | 손실 0.47
# | 에폭 23 |  반복 261 / 351 | 시간 12[s] | 손실 0.47
# | 에폭 23 |  반복 281 / 351 | 시간 13[s] | 손실 0.48
# | 에폭 23 |  반복 301 / 351 | 시간 14[s] | 손실 0.43
# | 에폭 23 |  반복 321 / 351 | 시간 15[s] | 손실 0.44
# | 에폭 23 |  반복 341 / 351 | 시간 16[s] | 손실 0.45
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1050
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# 검증 정확도 28.020%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.40
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 24 |  반복 41 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 24 |  반복 61 / 351 | 시간 2[s] | 손실 0.44
# | 에폭 24 |  반복 81 / 351 | 시간 3[s] | 손실 0.44
# | 에폭 24 |  반복 101 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 24 |  반복 121 / 351 | 시간 4[s] | 손실 0.45
# | 에폭 24 |  반복 141 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 24 |  반복 161 / 351 | 시간 5[s] | 손실 0.43
# | 에폭 24 |  반복 181 / 351 | 시간 6[s] | 손실 0.45
# | 에폭 24 |  반복 201 / 351 | 시간 7[s] | 손실 0.44
# | 에폭 24 |  반복 221 / 351 | 시간 8[s] | 손실 0.43
# | 에폭 24 |  반복 241 / 351 | 시간 9[s] | 손실 0.43
# | 에폭 24 |  반복 261 / 351 | 시간 9[s] | 손실 0.44
# | 에폭 24 |  반복 281 / 351 | 시간 10[s] | 손실 0.43
# | 에폭 24 |  반복 301 / 351 | 시간 11[s] | 손실 0.42
# | 에폭 24 |  반복 321 / 351 | 시간 12[s] | 손실 0.42
# | 에폭 24 |  반복 341 / 351 | 시간 13[s] | 손실 0.43
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1230
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1047
# ---
# Q 830+597
# T 1427
# ☒ 1423
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 25.000%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 25 |  반복 21 / 351 | 시간 1[s] | 손실 0.44
# | 에폭 25 |  반복 41 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 25 |  반복 61 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 25 |  반복 81 / 351 | 시간 3[s] | 손실 0.43
# | 에폭 25 |  반복 101 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 25 |  반복 121 / 351 | 시간 5[s] | 손실 0.41
# | 에폭 25 |  반복 141 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 25 |  반복 161 / 351 | 시간 6[s] | 손실 0.50
# | 에폭 25 |  반복 181 / 351 | 시간 7[s] | 손실 0.49
# | 에폭 25 |  반복 201 / 351 | 시간 8[s] | 손실 0.46
# | 에폭 25 |  반복 221 / 351 | 시간 9[s] | 손실 0.47
# | 에폭 25 |  반복 241 / 351 | 시간 10[s] | 손실 0.45
# | 에폭 25 |  반복 261 / 351 | 시간 11[s] | 손실 0.46
# | 에폭 25 |  반복 281 / 351 | 시간 12[s] | 손실 0.47
# | 에폭 25 |  반복 301 / 351 | 시간 14[s] | 손실 0.46
# | 에폭 25 |  반복 321 / 351 | 시간 16[s] | 손실 0.43
# | 에폭 25 |  반복 341 / 351 | 시간 16[s] | 손실 0.45
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 165
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 25.720%

# %% [markdown]
# leaky reverse

# %%
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
char_to_id, id_to_char = sequence.get_vocab()

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

model = Seq2seqRNNrelul(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

reversed_acc_list_RNN_reverse = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    reversed_acc_list_RNN_reverse.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 3.56
# | 에폭 1 |  반복 21 / 351 | 시간 1[s] | 손실 2.32
# | 에폭 1 |  반복 41 / 351 | 시간 1[s] | 손실 1.96
# | 에폭 1 |  반복 61 / 351 | 시간 2[s] | 손실 1.92
# | 에폭 1 |  반복 81 / 351 | 시간 3[s] | 손실 1.92
# | 에폭 1 |  반복 101 / 351 | 시간 4[s] | 손실 1.89
# | 에폭 1 |  반복 121 / 351 | 시간 5[s] | 손실 1.89
# | 에폭 1 |  반복 141 / 351 | 시간 5[s] | 손실 1.84
# | 에폭 1 |  반복 161 / 351 | 시간 6[s] | 손실 1.81
# | 에폭 1 |  반복 181 / 351 | 시간 7[s] | 손실 1.76
# | 에폭 1 |  반복 201 / 351 | 시간 8[s] | 손실 1.72
# | 에폭 1 |  반복 221 / 351 | 시간 8[s] | 손실 1.70
# | 에폭 1 |  반복 241 / 351 | 시간 9[s] | 손실 1.68
# | 에폭 1 |  반복 261 / 351 | 시간 10[s] | 손실 1.64
# | 에폭 1 |  반복 281 / 351 | 시간 10[s] | 손실 1.61
# | 에폭 1 |  반복 301 / 351 | 시간 11[s] | 손실 1.59
# | 에폭 1 |  반복 321 / 351 | 시간 12[s] | 손실 1.58
# | 에폭 1 |  반복 341 / 351 | 시간 12[s] | 손실 1.55
# Q   58+77
# T 162
# ☒ 108
# ---
# Q 461+579
# T 1139
# ☒ 1014
# ---
# Q  48+285
# T 666
# ☒ 631
# ---
# Q   551+8
# T 163
# ☒ 104
# ---
# Q  55+763
# T 422
# ☒ 304
# ---
# Q 752+006
# T 857
# ☒ 1010
# ---
# Q 292+167
# T 1053
# ☒ 1044
# ---
# Q 795+038
# T 1427
# ☒ 1310
# ---
# Q  838+62
# T 864
# ☒ 901
# ---
# Q  39+341
# T 236
# ☒ 201
# ---
# 검증 정확도 0.440%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.52
# | 에폭 2 |  반복 21 / 351 | 시간 1[s] | 손실 1.51
# | 에폭 2 |  반복 41 / 351 | 시간 2[s] | 손실 1.49
# | 에폭 2 |  반복 61 / 351 | 시간 3[s] | 손실 1.47
# | 에폭 2 |  반복 81 / 351 | 시간 4[s] | 손실 1.44
# | 에폭 2 |  반복 101 / 351 | 시간 4[s] | 손실 1.42
# | 에폭 2 |  반복 121 / 351 | 시간 5[s] | 손실 1.41
# | 에폭 2 |  반복 141 / 351 | 시간 6[s] | 손실 1.38
# | 에폭 2 |  반복 161 / 351 | 시간 7[s] | 손실 1.36
# | 에폭 2 |  반복 181 / 351 | 시간 7[s] | 손실 1.34
# | 에폭 2 |  반복 201 / 351 | 시간 8[s] | 손실 1.31
# | 에폭 2 |  반복 221 / 351 | 시간 9[s] | 손실 1.31
# | 에폭 2 |  반복 241 / 351 | 시간 10[s] | 손실 1.30
# | 에폭 2 |  반복 261 / 351 | 시간 11[s] | 손실 1.28
# | 에폭 2 |  반복 281 / 351 | 시간 12[s] | 손실 1.27
# | 에폭 2 |  반복 301 / 351 | 시간 12[s] | 손실 1.25
# | 에폭 2 |  반복 321 / 351 | 시간 13[s] | 손실 1.23
# | 에폭 2 |  반복 341 / 351 | 시간 13[s] | 손실 1.23
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1111
# ---
# Q  48+285
# T 666
# ☒ 654
# ---
# Q   551+8
# T 163
# ☒ 172
# ---
# Q  55+763
# T 422
# ☒ 419
# ---
# Q 752+006
# T 857
# ☒ 810
# ---
# Q 292+167
# T 1053
# ☒ 1019
# ---
# Q 795+038
# T 1427
# ☒ 1376
# ---
# Q  838+62
# T 864
# ☒ 881
# ---
# Q  39+341
# T 236
# ☒ 229
# ---
# 검증 정확도 2.000%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.20
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.19
# | 에폭 3 |  반복 41 / 351 | 시간 1[s] | 손실 1.18
# | 에폭 3 |  반복 61 / 351 | 시간 2[s] | 손실 1.18
# | 에폭 3 |  반복 81 / 351 | 시간 3[s] | 손실 1.16
# | 에폭 3 |  반복 101 / 351 | 시간 4[s] | 손실 1.15
# | 에폭 3 |  반복 121 / 351 | 시간 5[s] | 손실 1.14
# | 에폭 3 |  반복 141 / 351 | 시간 6[s] | 손실 1.14
# | 에폭 3 |  반복 161 / 351 | 시간 7[s] | 손실 1.12
# | 에폭 3 |  반복 181 / 351 | 시간 8[s] | 손실 1.10
# | 에폭 3 |  반복 201 / 351 | 시간 8[s] | 손실 1.09
# | 에폭 3 |  반복 221 / 351 | 시간 9[s] | 손실 1.08
# | 에폭 3 |  반복 241 / 351 | 시간 10[s] | 손실 1.08
# | 에폭 3 |  반복 261 / 351 | 시간 11[s] | 손실 1.06
# | 에폭 3 |  반복 281 / 351 | 시간 12[s] | 손실 1.04
# | 에폭 3 |  반복 301 / 351 | 시간 13[s] | 손실 1.06
# | 에폭 3 |  반복 321 / 351 | 시간 13[s] | 손실 1.05
# | 에폭 3 |  반복 341 / 351 | 시간 14[s] | 손실 1.04
# Q   58+77
# T 162
# ☒ 164
# ---
# Q 461+579
# T 1139
# ☒ 1148
# ---
# Q  48+285
# T 666
# ☒ 669
# ---
# Q   551+8
# T 163
# ☒ 160
# ---
# Q  55+763
# T 422
# ☒ 427
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☒ 1041
# ---
# Q 795+038
# T 1427
# ☒ 1431
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☒ 230
# ---
# 검증 정확도 3.860%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.02
# | 에폭 4 |  반복 21 / 351 | 시간 1[s] | 손실 1.02
# | 에폭 4 |  반복 41 / 351 | 시간 1[s] | 손실 1.01
# | 에폭 4 |  반복 61 / 351 | 시간 2[s] | 손실 0.99
# | 에폭 4 |  반복 81 / 351 | 시간 3[s] | 손실 1.00
# | 에폭 4 |  반복 101 / 351 | 시간 4[s] | 손실 1.00
# | 에폭 4 |  반복 121 / 351 | 시간 5[s] | 손실 0.98
# | 에폭 4 |  반복 141 / 351 | 시간 6[s] | 손실 0.98
# | 에폭 4 |  반복 161 / 351 | 시간 7[s] | 손실 0.99
# | 에폭 4 |  반복 181 / 351 | 시간 8[s] | 손실 0.98
# | 에폭 4 |  반복 201 / 351 | 시간 8[s] | 손실 0.96
# | 에폭 4 |  반복 221 / 351 | 시간 9[s] | 손실 0.96
# | 에폭 4 |  반복 241 / 351 | 시간 10[s] | 손실 0.96
# | 에폭 4 |  반복 261 / 351 | 시간 11[s] | 손실 0.95
# | 에폭 4 |  반복 281 / 351 | 시간 11[s] | 손실 0.94
# | 에폭 4 |  반복 301 / 351 | 시간 12[s] | 손실 0.93
# | 에폭 4 |  반복 321 / 351 | 시간 13[s] | 손실 0.94
# | 에폭 4 |  반복 341 / 351 | 시간 14[s] | 손실 0.93
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1168
# ---
# Q  48+285
# T 666
# ☒ 664
# ---
# Q   551+8
# T 163
# ☒ 169
# ---
# Q  55+763
# T 422
# ☒ 427
# ---
# Q 752+006
# T 857
# ☒ 860
# ---
# Q 292+167
# T 1053
# ☒ 1062
# ---
# Q 795+038
# T 1427
# ☒ 1407
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☒ 248
# ---
# 검증 정확도 5.720%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 0.93
# | 에폭 5 |  반복 21 / 351 | 시간 1[s] | 손실 0.91
# | 에폭 5 |  반복 41 / 351 | 시간 2[s] | 손실 0.91
# | 에폭 5 |  반복 61 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 5 |  반복 81 / 351 | 시간 4[s] | 손실 0.90
# | 에폭 5 |  반복 101 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 5 |  반복 121 / 351 | 시간 5[s] | 손실 0.91
# | 에폭 5 |  반복 141 / 351 | 시간 6[s] | 손실 0.90
# | 에폭 5 |  반복 161 / 351 | 시간 7[s] | 손실 0.88
# | 에폭 5 |  반복 181 / 351 | 시간 8[s] | 손실 0.89
# | 에폭 5 |  반복 201 / 351 | 시간 9[s] | 손실 0.86
# | 에폭 5 |  반복 221 / 351 | 시간 10[s] | 손실 0.88
# | 에폭 5 |  반복 241 / 351 | 시간 11[s] | 손실 0.87
# | 에폭 5 |  반복 261 / 351 | 시간 12[s] | 손실 0.86
# | 에폭 5 |  반복 281 / 351 | 시간 13[s] | 손실 0.87
# | 에폭 5 |  반복 301 / 351 | 시간 14[s] | 손실 0.87
# | 에폭 5 |  반복 321 / 351 | 시간 14[s] | 손실 0.86
# | 에폭 5 |  반복 341 / 351 | 시간 15[s] | 손실 0.85
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1168
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☒ 166
# ---
# Q  55+763
# T 422
# ☒ 426
# ---
# Q 752+006
# T 857
# ☒ 866
# ---
# Q 292+167
# T 1053
# ☒ 1062
# ---
# Q 795+038
# T 1427
# ☒ 1405
# ---
# Q  838+62
# T 864
# ☒ 866
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 7.640%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 6 |  반복 21 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 6 |  반복 41 / 351 | 시간 2[s] | 손실 0.82
# | 에폭 6 |  반복 61 / 351 | 시간 4[s] | 손실 0.82
# | 에폭 6 |  반복 81 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 6 |  반복 101 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 6 |  반복 121 / 351 | 시간 8[s] | 손실 0.81
# | 에폭 6 |  반복 141 / 351 | 시간 8[s] | 손실 0.82
# | 에폭 6 |  반복 161 / 351 | 시간 10[s] | 손실 0.80
# | 에폭 6 |  반복 181 / 351 | 시간 11[s] | 손실 0.82
# | 에폭 6 |  반복 201 / 351 | 시간 13[s] | 손실 0.81
# | 에폭 6 |  반복 221 / 351 | 시간 13[s] | 손실 0.80
# | 에폭 6 |  반복 241 / 351 | 시간 15[s] | 손실 0.78
# | 에폭 6 |  반복 261 / 351 | 시간 16[s] | 손실 0.79
# | 에폭 6 |  반복 281 / 351 | 시간 17[s] | 손실 0.77
# | 에폭 6 |  반복 301 / 351 | 시간 19[s] | 손실 0.78
# | 에폭 6 |  반복 321 / 351 | 시간 20[s] | 손실 0.77
# | 에폭 6 |  반복 341 / 351 | 시간 21[s] | 손실 0.77
# Q   58+77
# T 162
# ☒ 157
# ---
# Q 461+579
# T 1139
# ☒ 1243
# ---
# Q  48+285
# T 666
# ☒ 669
# ---
# Q   551+8
# T 163
# ☒ 160
# ---
# Q  55+763
# T 422
# ☒ 427
# ---
# Q 752+006
# T 857
# ☒ 760
# ---
# Q 292+167
# T 1053
# ☒ 1058
# ---
# Q 795+038
# T 1427
# ☒ 1408
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☒ 238
# ---
# 검증 정확도 9.340%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.77
# | 에폭 7 |  반복 21 / 351 | 시간 1[s] | 손실 0.75
# | 에폭 7 |  반복 41 / 351 | 시간 2[s] | 손실 0.74
# | 에폭 7 |  반복 61 / 351 | 시간 3[s] | 손실 0.75
# | 에폭 7 |  반복 81 / 351 | 시간 4[s] | 손실 0.75
# | 에폭 7 |  반복 101 / 351 | 시간 5[s] | 손실 0.73
# | 에폭 7 |  반복 121 / 351 | 시간 6[s] | 손실 0.73
# | 에폭 7 |  반복 141 / 351 | 시간 7[s] | 손실 0.74
# | 에폭 7 |  반복 161 / 351 | 시간 8[s] | 손실 0.73
# | 에폭 7 |  반복 181 / 351 | 시간 8[s] | 손실 0.73
# | 에폭 7 |  반복 201 / 351 | 시간 9[s] | 손실 0.74
# | 에폭 7 |  반복 221 / 351 | 시간 10[s] | 손실 0.72
# | 에폭 7 |  반복 241 / 351 | 시간 11[s] | 손실 0.71
# | 에폭 7 |  반복 261 / 351 | 시간 12[s] | 손실 0.71
# | 에폭 7 |  반복 281 / 351 | 시간 13[s] | 손실 0.70
# | 에폭 7 |  반복 301 / 351 | 시간 14[s] | 손실 0.70
# | 에폭 7 |  반복 321 / 351 | 시간 14[s] | 손실 0.69
# | 에폭 7 |  반복 341 / 351 | 시간 15[s] | 손실 0.70
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1233
# ---
# Q  48+285
# T 666
# ☒ 661
# ---
# Q   551+8
# T 163
# ☒ 160
# ---
# Q  55+763
# T 422
# ☒ 421
# ---
# Q 752+006
# T 857
# ☒ 751
# ---
# Q 292+167
# T 1053
# ☒ 1057
# ---
# Q 795+038
# T 1427
# ☒ 1420
# ---
# Q  838+62
# T 864
# ☒ 863
# ---
# Q  39+341
# T 236
# ☒ 238
# ---
# 검증 정확도 12.920%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.68
# | 에폭 8 |  반복 21 / 351 | 시간 2[s] | 손실 0.68
# | 에폭 8 |  반복 41 / 351 | 시간 3[s] | 손실 0.68
# | 에폭 8 |  반복 61 / 351 | 시간 4[s] | 손실 0.67
# | 에폭 8 |  반복 81 / 351 | 시간 5[s] | 손실 0.68
# | 에폭 8 |  반복 101 / 351 | 시간 7[s] | 손실 0.67
# | 에폭 8 |  반복 121 / 351 | 시간 7[s] | 손실 0.69
# | 에폭 8 |  반복 141 / 351 | 시간 8[s] | 손실 0.68
# | 에폭 8 |  반복 161 / 351 | 시간 9[s] | 손실 0.66
# | 에폭 8 |  반복 181 / 351 | 시간 10[s] | 손실 0.65
# | 에폭 8 |  반복 201 / 351 | 시간 12[s] | 손실 0.65
# | 에폭 8 |  반복 221 / 351 | 시간 13[s] | 손실 0.64
# | 에폭 8 |  반복 241 / 351 | 시간 14[s] | 손실 0.65
# | 에폭 8 |  반복 261 / 351 | 시간 15[s] | 손실 0.64
# | 에폭 8 |  반복 281 / 351 | 시간 16[s] | 손실 0.64
# | 에폭 8 |  반복 301 / 351 | 시간 17[s] | 손실 0.64
# | 에폭 8 |  반복 321 / 351 | 시간 18[s] | 손실 0.63
# | 에폭 8 |  반복 341 / 351 | 시간 19[s] | 손실 0.64
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1233
# ---
# Q  48+285
# T 666
# ☒ 660
# ---
# Q   551+8
# T 163
# ☒ 160
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☒ 1059
# ---
# Q 795+038
# T 1427
# ☒ 1424
# ---
# Q  838+62
# T 864
# ☒ 861
# ---
# Q  39+341
# T 236
# ☒ 231
# ---
# 검증 정확도 14.940%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.62
# | 에폭 9 |  반복 21 / 351 | 시간 1[s] | 손실 0.61
# | 에폭 9 |  반복 41 / 351 | 시간 2[s] | 손실 0.60
# | 에폭 9 |  반복 61 / 351 | 시간 3[s] | 손실 0.64
# | 에폭 9 |  반복 81 / 351 | 시간 4[s] | 손실 0.62
# | 에폭 9 |  반복 101 / 351 | 시간 5[s] | 손실 0.62
# | 에폭 9 |  반복 121 / 351 | 시간 5[s] | 손실 0.63
# | 에폭 9 |  반복 141 / 351 | 시간 6[s] | 손실 0.61
# | 에폭 9 |  반복 161 / 351 | 시간 7[s] | 손실 0.60
# | 에폭 9 |  반복 181 / 351 | 시간 8[s] | 손실 0.61
# | 에폭 9 |  반복 201 / 351 | 시간 9[s] | 손실 0.59
# | 에폭 9 |  반복 221 / 351 | 시간 10[s] | 손실 0.59
# | 에폭 9 |  반복 241 / 351 | 시간 11[s] | 손실 0.60
# | 에폭 9 |  반복 261 / 351 | 시간 11[s] | 손실 0.58
# | 에폭 9 |  반복 281 / 351 | 시간 12[s] | 손실 0.59
# | 에폭 9 |  반복 301 / 351 | 시간 13[s] | 손실 0.57
# | 에폭 9 |  반복 321 / 351 | 시간 13[s] | 손실 0.59
# | 에폭 9 |  반복 341 / 351 | 시간 14[s] | 손실 0.59
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1238
# ---
# Q  48+285
# T 666
# ☒ 665
# ---
# Q   551+8
# T 163
# ☒ 160
# ---
# Q  55+763
# T 422
# ☒ 424
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☒ 1050
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☒ 861
# ---
# Q  39+341
# T 236
# ☒ 234
# ---
# 검증 정확도 19.900%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.57
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.57
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.57
# | 에폭 10 |  반복 61 / 351 | 시간 2[s] | 손실 0.56
# | 에폭 10 |  반복 81 / 351 | 시간 3[s] | 손실 0.57
# | 에폭 10 |  반복 101 / 351 | 시간 3[s] | 손실 0.57
# | 에폭 10 |  반복 121 / 351 | 시간 4[s] | 손실 0.56
# | 에폭 10 |  반복 141 / 351 | 시간 5[s] | 손실 0.56
# | 에폭 10 |  반복 161 / 351 | 시간 6[s] | 손실 0.57
# | 에폭 10 |  반복 181 / 351 | 시간 7[s] | 손실 0.55
# | 에폭 10 |  반복 201 / 351 | 시간 8[s] | 손실 0.56
# | 에폭 10 |  반복 221 / 351 | 시간 9[s] | 손실 0.55
# | 에폭 10 |  반복 241 / 351 | 시간 10[s] | 손실 0.54
# | 에폭 10 |  반복 261 / 351 | 시간 10[s] | 손실 0.54
# | 에폭 10 |  반복 281 / 351 | 시간 11[s] | 손실 0.53
# | 에폭 10 |  반복 301 / 351 | 시간 12[s] | 손실 0.54
# | 에폭 10 |  반복 321 / 351 | 시간 13[s] | 손실 0.53
# | 에폭 10 |  반복 341 / 351 | 시간 14[s] | 손실 0.52
# Q   58+77
# T 162
# ☒ 163
# ---
# Q 461+579
# T 1139
# ☒ 1237
# ---
# Q  48+285
# T 666
# ☒ 665
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☒ 1050
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 861
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 21.240%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.53
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.54
# | 에폭 11 |  반복 61 / 351 | 시간 2[s] | 손실 0.51
# | 에폭 11 |  반복 81 / 351 | 시간 3[s] | 손실 0.52
# | 에폭 11 |  반복 101 / 351 | 시간 5[s] | 손실 0.53
# | 에폭 11 |  반복 121 / 351 | 시간 6[s] | 손실 0.53
# | 에폭 11 |  반복 141 / 351 | 시간 7[s] | 손실 0.51
# | 에폭 11 |  반복 161 / 351 | 시간 8[s] | 손실 0.52
# | 에폭 11 |  반복 181 / 351 | 시간 9[s] | 손실 0.54
# | 에폭 11 |  반복 201 / 351 | 시간 12[s] | 손실 0.52
# | 에폭 11 |  반복 221 / 351 | 시간 13[s] | 손실 0.51
# | 에폭 11 |  반복 241 / 351 | 시간 14[s] | 손실 0.51
# | 에폭 11 |  반복 261 / 351 | 시간 16[s] | 손실 0.50
# | 에폭 11 |  반복 281 / 351 | 시간 17[s] | 손실 0.50
# | 에폭 11 |  반복 301 / 351 | 시간 18[s] | 손실 0.50
# | 에폭 11 |  반복 321 / 351 | 시간 20[s] | 손실 0.51
# | 에폭 11 |  반복 341 / 351 | 시간 21[s] | 손실 0.51
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1238
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 421
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☒ 1050
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☒ 234
# ---
# 검증 정확도 26.940%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.48
# | 에폭 12 |  반복 41 / 351 | 시간 2[s] | 손실 0.49
# | 에폭 12 |  반복 61 / 351 | 시간 3[s] | 손실 0.49
# | 에폭 12 |  반복 81 / 351 | 시간 4[s] | 손실 0.48
# | 에폭 12 |  반복 101 / 351 | 시간 5[s] | 손실 0.48
# | 에폭 12 |  반복 121 / 351 | 시간 6[s] | 손실 0.48
# | 에폭 12 |  반복 141 / 351 | 시간 7[s] | 손실 0.47
# | 에폭 12 |  반복 161 / 351 | 시간 8[s] | 손실 0.48
# | 에폭 12 |  반복 181 / 351 | 시간 8[s] | 손실 0.49
# | 에폭 12 |  반복 201 / 351 | 시간 9[s] | 손실 0.49
# | 에폭 12 |  반복 221 / 351 | 시간 10[s] | 손실 0.48
# | 에폭 12 |  반복 241 / 351 | 시간 11[s] | 손실 0.48
# | 에폭 12 |  반복 261 / 351 | 시간 11[s] | 손실 0.47
# | 에폭 12 |  반복 281 / 351 | 시간 12[s] | 손실 0.46
# | 에폭 12 |  반복 301 / 351 | 시간 13[s] | 손실 0.45
# | 에폭 12 |  반복 321 / 351 | 시간 14[s] | 손실 0.45
# | 에폭 12 |  반복 341 / 351 | 시간 15[s] | 손실 0.47
# Q   58+77
# T 162
# ☒ 163
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☒ 1052
# ---
# Q 795+038
# T 1427
# ☒ 1431
# ---
# Q  838+62
# T 864
# ☒ 866
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 28.600%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.50
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.45
# | 에폭 13 |  반복 61 / 351 | 시간 2[s] | 손실 0.44
# | 에폭 13 |  반복 81 / 351 | 시간 3[s] | 손실 0.45
# | 에폭 13 |  반복 101 / 351 | 시간 4[s] | 손실 0.44
# | 에폭 13 |  반복 121 / 351 | 시간 5[s] | 손실 0.44
# | 에폭 13 |  반복 141 / 351 | 시간 6[s] | 손실 0.45
# | 에폭 13 |  반복 161 / 351 | 시간 7[s] | 손실 0.44
# | 에폭 13 |  반복 181 / 351 | 시간 8[s] | 손실 0.45
# | 에폭 13 |  반복 201 / 351 | 시간 9[s] | 손실 0.44
# | 에폭 13 |  반복 221 / 351 | 시간 10[s] | 손실 0.44
# | 에폭 13 |  반복 241 / 351 | 시간 10[s] | 손실 0.43
# | 에폭 13 |  반복 261 / 351 | 시간 11[s] | 손실 0.44
# | 에폭 13 |  반복 281 / 351 | 시간 12[s] | 손실 0.42
# | 에폭 13 |  반복 301 / 351 | 시간 13[s] | 손실 0.43
# | 에폭 13 |  반복 321 / 351 | 시간 14[s] | 손실 0.43
# | 에폭 13 |  반복 341 / 351 | 시간 14[s] | 손실 0.43
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1237
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☒ 167
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 851
# ---
# Q 292+167
# T 1053
# ☒ 1050
# ---
# Q 795+038
# T 1427
# ☒ 1431
# ---
# Q  838+62
# T 864
# ☒ 865
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 35.140%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.40
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.42
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.42
# | 에폭 14 |  반복 61 / 351 | 시간 2[s] | 손실 0.43
# | 에폭 14 |  반복 81 / 351 | 시간 3[s] | 손실 0.42
# | 에폭 14 |  반복 101 / 351 | 시간 4[s] | 손실 0.43
# | 에폭 14 |  반복 121 / 351 | 시간 5[s] | 손실 0.42
# | 에폭 14 |  반복 141 / 351 | 시간 6[s] | 손실 0.42
# | 에폭 14 |  반복 161 / 351 | 시간 7[s] | 손실 0.41
# | 에폭 14 |  반복 181 / 351 | 시간 8[s] | 손실 0.42
# | 에폭 14 |  반복 201 / 351 | 시간 10[s] | 손실 0.42
# | 에폭 14 |  반복 221 / 351 | 시간 11[s] | 손실 0.43
# | 에폭 14 |  반복 241 / 351 | 시간 13[s] | 손실 0.42
# | 에폭 14 |  반복 261 / 351 | 시간 17[s] | 손실 0.42
# | 에폭 14 |  반복 281 / 351 | 시간 17[s] | 손실 0.41
# | 에폭 14 |  반복 301 / 351 | 시간 18[s] | 손실 0.39
# | 에폭 14 |  반복 321 / 351 | 시간 20[s] | 손실 0.40
# | 에폭 14 |  반복 341 / 351 | 시간 21[s] | 손실 0.40
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1238
# ---
# Q  48+285
# T 666
# ☒ 664
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 39.180%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.40
# | 에폭 15 |  반복 21 / 351 | 시간 1[s] | 손실 0.37
# | 에폭 15 |  반복 41 / 351 | 시간 2[s] | 손실 0.39
# | 에폭 15 |  반복 61 / 351 | 시간 3[s] | 손실 0.39
# | 에폭 15 |  반복 81 / 351 | 시간 4[s] | 손실 0.40
# | 에폭 15 |  반복 101 / 351 | 시간 5[s] | 손실 0.40
# | 에폭 15 |  반복 121 / 351 | 시간 6[s] | 손실 0.39
# | 에폭 15 |  반복 141 / 351 | 시간 7[s] | 손실 0.38
# | 에폭 15 |  반복 161 / 351 | 시간 8[s] | 손실 0.39
# | 에폭 15 |  반복 181 / 351 | 시간 9[s] | 손실 0.40
# | 에폭 15 |  반복 201 / 351 | 시간 10[s] | 손실 0.37
# | 에폭 15 |  반복 221 / 351 | 시간 11[s] | 손실 0.38
# | 에폭 15 |  반복 241 / 351 | 시간 12[s] | 손실 0.38
# | 에폭 15 |  반복 261 / 351 | 시간 13[s] | 손실 0.37
# | 에폭 15 |  반복 281 / 351 | 시간 14[s] | 손실 0.37
# | 에폭 15 |  반복 301 / 351 | 시간 15[s] | 손실 0.39
# | 에폭 15 |  반복 321 / 351 | 시간 16[s] | 손실 0.38
# | 에폭 15 |  반복 341 / 351 | 시간 17[s] | 손실 0.38
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☒ 664
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☒ 235
# ---
# 검증 정확도 42.300%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.38
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.37
# | 에폭 16 |  반복 61 / 351 | 시간 2[s] | 손실 0.36
# | 에폭 16 |  반복 81 / 351 | 시간 4[s] | 손실 0.37
# | 에폭 16 |  반복 101 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 16 |  반복 121 / 351 | 시간 8[s] | 손실 0.37
# | 에폭 16 |  반복 141 / 351 | 시간 9[s] | 손실 0.35
# | 에폭 16 |  반복 161 / 351 | 시간 10[s] | 손실 0.35
# | 에폭 16 |  반복 181 / 351 | 시간 11[s] | 손실 0.37
# | 에폭 16 |  반복 201 / 351 | 시간 12[s] | 손실 0.38
# | 에폭 16 |  반복 221 / 351 | 시간 14[s] | 손실 0.38
# | 에폭 16 |  반복 241 / 351 | 시간 15[s] | 손실 0.37
# | 에폭 16 |  반복 261 / 351 | 시간 16[s] | 손실 0.37
# | 에폭 16 |  반복 281 / 351 | 시간 17[s] | 손실 0.38
# | 에폭 16 |  반복 301 / 351 | 시간 19[s] | 손실 0.36
# | 에폭 16 |  반복 321 / 351 | 시간 20[s] | 손실 0.36
# | 에폭 16 |  반복 341 / 351 | 시간 21[s] | 손실 0.35
# Q   58+77
# T 162
# ☒ 161
# ---
# Q 461+579
# T 1139
# ☒ 1239
# ---
# Q  48+285
# T 666
# ☒ 664
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 859
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 866
# ---
# Q  39+341
# T 236
# ☒ 234
# ---
# 검증 정확도 39.260%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.37
# | 에폭 17 |  반복 21 / 351 | 시간 1[s] | 손실 0.37
# | 에폭 17 |  반복 41 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 17 |  반복 61 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 17 |  반복 81 / 351 | 시간 3[s] | 손실 0.35
# | 에폭 17 |  반복 101 / 351 | 시간 5[s] | 손실 0.34
# | 에폭 17 |  반복 121 / 351 | 시간 6[s] | 손실 0.34
# | 에폭 17 |  반복 141 / 351 | 시간 7[s] | 손실 0.34
# | 에폭 17 |  반복 161 / 351 | 시간 8[s] | 손실 0.34
# | 에폭 17 |  반복 181 / 351 | 시간 9[s] | 손실 0.34
# | 에폭 17 |  반복 201 / 351 | 시간 10[s] | 손실 0.34
# | 에폭 17 |  반복 221 / 351 | 시간 11[s] | 손실 0.35
# | 에폭 17 |  반복 241 / 351 | 시간 12[s] | 손실 0.34
# | 에폭 17 |  반복 261 / 351 | 시간 13[s] | 손실 0.34
# | 에폭 17 |  반복 281 / 351 | 시간 14[s] | 손실 0.35
# | 에폭 17 |  반복 301 / 351 | 시간 15[s] | 손실 0.36
# | 에폭 17 |  반복 321 / 351 | 시간 16[s] | 손실 0.34
# | 에폭 17 |  반복 341 / 351 | 시간 17[s] | 손실 0.33
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☒ 665
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 853
# ---
# Q 292+167
# T 1053
# ☒ 1052
# ---
# Q 795+038
# T 1427
# ☒ 1430
# ---
# Q  838+62
# T 864
# ☒ 865
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 48.280%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 18 |  반복 21 / 351 | 시간 1[s] | 손실 0.35
# | 에폭 18 |  반복 41 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 18 |  반복 61 / 351 | 시간 3[s] | 손실 0.33
# | 에폭 18 |  반복 81 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 18 |  반복 101 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 18 |  반복 121 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 18 |  반복 141 / 351 | 시간 7[s] | 손실 0.34
# | 에폭 18 |  반복 161 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 18 |  반복 181 / 351 | 시간 10[s] | 손실 0.33
# | 에폭 18 |  반복 201 / 351 | 시간 11[s] | 손실 0.33
# | 에폭 18 |  반복 221 / 351 | 시간 12[s] | 손실 0.33
# | 에폭 18 |  반복 241 / 351 | 시간 13[s] | 손실 0.34
# | 에폭 18 |  반복 261 / 351 | 시간 14[s] | 손실 0.35
# | 에폭 18 |  반복 281 / 351 | 시간 15[s] | 손실 0.34
# | 에폭 18 |  반복 301 / 351 | 시간 16[s] | 손실 0.32
# | 에폭 18 |  반복 321 / 351 | 시간 17[s] | 손실 0.32
# | 에폭 18 |  반복 341 / 351 | 시간 18[s] | 손실 0.32
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1138
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☒ 1048
# ---
# Q 795+038
# T 1427
# ☒ 1430
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 50.060%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.30
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.31
# | 에폭 19 |  반복 61 / 351 | 시간 2[s] | 손실 0.33
# | 에폭 19 |  반복 81 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 19 |  반복 101 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 19 |  반복 121 / 351 | 시간 6[s] | 손실 0.32
# | 에폭 19 |  반복 141 / 351 | 시간 7[s] | 손실 0.31
# | 에폭 19 |  반복 161 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 19 |  반복 181 / 351 | 시간 9[s] | 손실 0.32
# | 에폭 19 |  반복 201 / 351 | 시간 10[s] | 손실 0.32
# | 에폭 19 |  반복 221 / 351 | 시간 12[s] | 손실 0.33
# | 에폭 19 |  반복 241 / 351 | 시간 13[s] | 손실 0.32
# | 에폭 19 |  반복 261 / 351 | 시간 14[s] | 손실 0.32
# | 에폭 19 |  반복 281 / 351 | 시간 15[s] | 손실 0.32
# | 에폭 19 |  반복 301 / 351 | 시간 16[s] | 손실 0.31
# | 에폭 19 |  반복 321 / 351 | 시간 16[s] | 손실 0.32
# | 에폭 19 |  반복 341 / 351 | 시간 18[s] | 손실 0.34
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 852
# ---
# Q 292+167
# T 1053
# ☒ 1052
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☒ 865
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 46.780%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 20 |  반복 21 / 351 | 시간 1[s] | 손실 0.31
# | 에폭 20 |  반복 41 / 351 | 시간 2[s] | 손실 0.31
# | 에폭 20 |  반복 61 / 351 | 시간 3[s] | 손실 0.31
# | 에폭 20 |  반복 81 / 351 | 시간 4[s] | 손실 0.29
# | 에폭 20 |  반복 101 / 351 | 시간 5[s] | 손실 0.30
# | 에폭 20 |  반복 121 / 351 | 시간 5[s] | 손실 0.30
# | 에폭 20 |  반복 141 / 351 | 시간 6[s] | 손실 0.31
# | 에폭 20 |  반복 161 / 351 | 시간 7[s] | 손실 0.31
# | 에폭 20 |  반복 181 / 351 | 시간 8[s] | 손실 0.30
# | 에폭 20 |  반복 201 / 351 | 시간 9[s] | 손실 0.30
# | 에폭 20 |  반복 221 / 351 | 시간 11[s] | 손실 0.31
# | 에폭 20 |  반복 241 / 351 | 시간 12[s] | 손실 0.31
# | 에폭 20 |  반복 261 / 351 | 시간 13[s] | 손실 0.32
# | 에폭 20 |  반복 281 / 351 | 시간 14[s] | 손실 0.31
# | 에폭 20 |  반복 301 / 351 | 시간 15[s] | 손실 0.31
# | 에폭 20 |  반복 321 / 351 | 시간 16[s] | 손실 0.28
# | 에폭 20 |  반복 341 / 351 | 시간 17[s] | 손실 0.29
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☒ 1049
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☒ 865
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 52.860%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.30
# | 에폭 21 |  반복 21 / 351 | 시간 2[s] | 손실 0.28
# | 에폭 21 |  반복 41 / 351 | 시간 3[s] | 손실 0.28
# | 에폭 21 |  반복 61 / 351 | 시간 5[s] | 손실 0.28
# | 에폭 21 |  반복 81 / 351 | 시간 6[s] | 손실 0.28
# | 에폭 21 |  반복 101 / 351 | 시간 7[s] | 손실 0.27
# | 에폭 21 |  반복 121 / 351 | 시간 8[s] | 손실 0.28
# | 에폭 21 |  반복 141 / 351 | 시간 9[s] | 손실 0.28
# | 에폭 21 |  반복 161 / 351 | 시간 10[s] | 손실 0.27
# | 에폭 21 |  반복 181 / 351 | 시간 12[s] | 손실 0.28
# | 에폭 21 |  반복 201 / 351 | 시간 13[s] | 손실 0.30
# | 에폭 21 |  반복 221 / 351 | 시간 15[s] | 손실 0.28
# | 에폭 21 |  반복 241 / 351 | 시간 16[s] | 손실 0.28
# | 에폭 21 |  반복 261 / 351 | 시간 17[s] | 손실 0.29
# | 에폭 21 |  반복 281 / 351 | 시간 18[s] | 손실 0.29
# | 에폭 21 |  반복 301 / 351 | 시간 19[s] | 손실 0.30
# | 에폭 21 |  반복 321 / 351 | 시간 21[s] | 손실 0.29
# | 에폭 21 |  반복 341 / 351 | 시간 22[s] | 손실 0.29
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 859
# ---
# Q 292+167
# T 1053
# ☒ 1054
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 863
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 53.100%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.28
# | 에폭 22 |  반복 21 / 351 | 시간 1[s] | 손실 0.29
# | 에폭 22 |  반복 41 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 22 |  반복 61 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 22 |  반복 81 / 351 | 시간 5[s] | 손실 0.30
# | 에폭 22 |  반복 101 / 351 | 시간 8[s] | 손실 0.29
# | 에폭 22 |  반복 121 / 351 | 시간 9[s] | 손실 0.29
# | 에폭 22 |  반복 141 / 351 | 시간 10[s] | 손실 0.28
# | 에폭 22 |  반복 161 / 351 | 시간 11[s] | 손실 0.28
# | 에폭 22 |  반복 181 / 351 | 시간 12[s] | 손실 0.29
# | 에폭 22 |  반복 201 / 351 | 시간 13[s] | 손실 0.27
# | 에폭 22 |  반복 221 / 351 | 시간 14[s] | 손실 0.28
# | 에폭 22 |  반복 241 / 351 | 시간 15[s] | 손실 0.28
# | 에폭 22 |  반복 261 / 351 | 시간 16[s] | 손실 0.27
# | 에폭 22 |  반복 281 / 351 | 시간 17[s] | 손실 0.26
# | 에폭 22 |  반복 301 / 351 | 시간 18[s] | 손실 0.28
# | 에폭 22 |  반복 321 / 351 | 시간 21[s] | 손실 0.28
# | 에폭 22 |  반복 341 / 351 | 시간 23[s] | 손실 0.29
# Q   58+77
# T 162
# ☒ 161
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☒ 1054
# ---
# Q 795+038
# T 1427
# ☒ 1430
# ---
# Q  838+62
# T 864
# ☒ 865
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 53.320%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.27
# | 에폭 23 |  반복 21 / 351 | 시간 1[s] | 손실 0.26
# | 에폭 23 |  반복 41 / 351 | 시간 2[s] | 손실 0.26
# | 에폭 23 |  반복 61 / 351 | 시간 4[s] | 손실 0.27
# | 에폭 23 |  반복 81 / 351 | 시간 6[s] | 손실 0.27
# | 에폭 23 |  반복 101 / 351 | 시간 9[s] | 손실 0.25
# | 에폭 23 |  반복 121 / 351 | 시간 10[s] | 손실 0.26
# | 에폭 23 |  반복 141 / 351 | 시간 11[s] | 손실 0.27
# | 에폭 23 |  반복 161 / 351 | 시간 13[s] | 손실 0.26
# | 에폭 23 |  반복 181 / 351 | 시간 14[s] | 손실 0.26
# | 에폭 23 |  반복 201 / 351 | 시간 15[s] | 손실 0.25
# | 에폭 23 |  반복 221 / 351 | 시간 16[s] | 손실 0.26
# | 에폭 23 |  반복 241 / 351 | 시간 17[s] | 손실 0.26
# | 에폭 23 |  반복 261 / 351 | 시간 19[s] | 손실 0.27
# | 에폭 23 |  반복 281 / 351 | 시간 20[s] | 손실 0.26
# | 에폭 23 |  반복 301 / 351 | 시간 21[s] | 손실 0.25
# | 에폭 23 |  반복 321 / 351 | 시간 23[s] | 손실 0.25
# | 에폭 23 |  반복 341 / 351 | 시간 24[s] | 손실 0.27
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☒ 1047
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 58.300%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.24
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.24
# | 에폭 24 |  반복 41 / 351 | 시간 2[s] | 손실 0.23
# | 에폭 24 |  반복 61 / 351 | 시간 3[s] | 손실 0.24
# | 에폭 24 |  반복 81 / 351 | 시간 3[s] | 손실 0.25
# | 에폭 24 |  반복 101 / 351 | 시간 5[s] | 손실 0.24
# | 에폭 24 |  반복 121 / 351 | 시간 6[s] | 손실 0.26
# | 에폭 24 |  반복 141 / 351 | 시간 7[s] | 손실 0.25
# | 에폭 24 |  반복 161 / 351 | 시간 8[s] | 손실 0.25
# | 에폭 24 |  반복 181 / 351 | 시간 9[s] | 손실 0.25
# | 에폭 24 |  반복 201 / 351 | 시간 11[s] | 손실 0.25
# | 에폭 24 |  반복 221 / 351 | 시간 12[s] | 손실 0.24
# | 에폭 24 |  반복 241 / 351 | 시간 13[s] | 손실 0.25
# | 에폭 24 |  반복 261 / 351 | 시간 14[s] | 손실 0.24
# | 에폭 24 |  반복 281 / 351 | 시간 15[s] | 손실 0.24
# | 에폭 24 |  반복 301 / 351 | 시간 16[s] | 손실 0.24
# | 에폭 24 |  반복 321 / 351 | 시간 18[s] | 손실 0.23
# | 에폭 24 |  반복 341 / 351 | 시간 19[s] | 손실 0.24
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☒ 1047
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 867
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 60.860%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.22
# | 에폭 25 |  반복 21 / 351 | 시간 1[s] | 손실 0.25
# | 에폭 25 |  반복 41 / 351 | 시간 2[s] | 손실 0.22
# | 에폭 25 |  반복 61 / 351 | 시간 4[s] | 손실 0.25
# | 에폭 25 |  반복 81 / 351 | 시간 5[s] | 손실 0.23
# | 에폭 25 |  반복 101 / 351 | 시간 8[s] | 손실 0.25
# | 에폭 25 |  반복 121 / 351 | 시간 9[s] | 손실 0.23
# | 에폭 25 |  반복 141 / 351 | 시간 10[s] | 손실 0.23
# | 에폭 25 |  반복 161 / 351 | 시간 11[s] | 손실 0.23
# | 에폭 25 |  반복 181 / 351 | 시간 12[s] | 손실 0.23
# | 에폭 25 |  반복 201 / 351 | 시간 13[s] | 손실 0.22
# | 에폭 25 |  반복 221 / 351 | 시간 14[s] | 손실 0.24
# | 에폭 25 |  반복 241 / 351 | 시간 16[s] | 손실 0.23
# | 에폭 25 |  반복 261 / 351 | 시간 17[s] | 손실 0.24
# | 에폭 25 |  반복 281 / 351 | 시간 18[s] | 손실 0.23
# | 에폭 25 |  반복 301 / 351 | 시간 20[s] | 손실 0.22
# | 에폭 25 |  반복 321 / 351 | 시간 21[s] | 손실 0.22
# | 에폭 25 |  반복 341 / 351 | 시간 22[s] | 손실 0.22
# Q   58+77
# T 162
# ☒ 161
# ---
# Q 461+579
# T 1139
# ☒ 1138
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☒ 1147
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☒ 866
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 64.360%

# %%
plt.plot(np.arange(1,len(acc_listRNNrelul)+1), acc_listRNNrelul, marker='o', label='leaky relu')
plt.plot(np.arange(1,len(reversed_acc_list_RNN_reverse)+1), reversed_acc_list_RNN_reverse, marker='o', label='leaky relu', color='green')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %%
plt.plot(np.arange(1,len(acc_listRNN)+1), acc_listRNN, marker='o', label='tanh')
# plt.plot(np.arange(1,len(acc_listRNNrelul)+1), acc_listRNNrelul, marker='o', color='green', label='leaky relu')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %%
plt.plot(np.arange(1,len(acc_listRNN)+1), acc_listRNN, marker='o', label='tanh')
plt.plot(np.arange(1,len(acc_listRNNrelul)+1), acc_listRNNrelul, marker='o', color='green', label='leaky relu')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %%
for idx,grad in enumerate(modell.grads):
    print(f"mean grad of {idx+1}'s layer: {grad.mean()}")
# Out:
# mean grad of 1's layer: 0.0006004275055602193
# mean grad of 2's layer: -5.424584378488362e-05
# mean grad of 3's layer: 0.0022414391860365868
# mean grad of 4's layer: 0.0026492481119930744
# mean grad of 5's layer: -0.0006089083035476506
# mean grad of 6's layer: -1.0426043445477262e-05
# mean grad of 7's layer: -0.00024216662859544158
# mean grad of 8's layer: -6.399465200956911e-05
# mean grad of 9's layer: 1.013037154162788e-10
# mean grad of 10's layer: -3.1342586859217647e-10

# %%
for idx,grad in enumerate(model.grads):
    print(f"mean grad of {idx+1}'s layer: {grad.mean()}")
# Out:
# mean grad of 1's layer: 0.06596656888723373
# mean grad of 2's layer: 0.006557966582477093
# mean grad of 3's layer: -4.8457281081937253e-05
# mean grad of 4's layer: -0.003033112734556198
# mean grad of 5's layer: 7.738301388595479e-22
# mean grad of 6's layer: 8.139319145308942e-23
# mean grad of 7's layer: -4.700915763426738e-13
# mean grad of 8's layer: 9.813224077486599e-21
# mean grad of 9's layer: 9.244908842763171e-18
# mean grad of 10's layer: -4.971037520239824e-28

# %%
plt.plot(np.arange(1,len(acc_listRNNrelu)+1), acc_listRNNrelu, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %%
plt.plot(np.arange(1,max_epoch+1), acc_listRNN, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %%
plt.plot(np.arange(1,max_epoch+1), acc_listRNN, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %% [markdown]
# rnn reverse

# %%
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
char_to_id, id_to_char = sequence.get_vocab()

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

model = Seq2seqRNN(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

reversed_acc_list_RNN = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    reversed_acc_list_RNN.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.82
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.10
# | 에폭 1 |  반복 41 / 351 | 시간 0[s] | 손실 1.94
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 1.92
# | 에폭 1 |  반복 81 / 351 | 시간 1[s] | 손실 1.90
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.86
# | 에폭 1 |  반복 121 / 351 | 시간 2[s] | 손실 1.84
# | 에폭 1 |  반복 141 / 351 | 시간 3[s] | 손실 1.82
# | 에폭 1 |  반복 161 / 351 | 시간 3[s] | 손실 1.78
# | 에폭 1 |  반복 181 / 351 | 시간 4[s] | 손실 1.73
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 1.69
# | 에폭 1 |  반복 221 / 351 | 시간 5[s] | 손실 1.67
# | 에폭 1 |  반복 241 / 351 | 시간 6[s] | 손실 1.65
# | 에폭 1 |  반복 261 / 351 | 시간 6[s] | 손실 1.62
# | 에폭 1 |  반복 281 / 351 | 시간 7[s] | 손실 1.59
# | 에폭 1 |  반복 301 / 351 | 시간 7[s] | 손실 1.57
# | 에폭 1 |  반복 321 / 351 | 시간 8[s] | 손실 1.56
# | 에폭 1 |  반복 341 / 351 | 시간 8[s] | 손실 1.53
# Q   58+77
# T 162
# ☒ 100
# ---
# Q 461+579
# T 1139
# ☒ 1033
# ---
# Q  48+285
# T 666
# ☒ 631
# ---
# Q   551+8
# T 163
# ☒ 111
# ---
# Q  55+763
# T 422
# ☒ 431
# ---
# Q 752+006
# T 857
# ☒ 731
# ---
# Q 292+167
# T 1053
# ☒ 1033
# ---
# Q 795+038
# T 1427
# ☒ 1669
# ---
# Q  838+62
# T 864
# ☒ 908
# ---
# Q  39+341
# T 236
# ☒ 267
# ---
# 검증 정확도 0.660%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.49
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.51
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 1.48
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.46
# | 에폭 2 |  반복 81 / 351 | 시간 1[s] | 손실 1.44
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.42
# | 에폭 2 |  반복 121 / 351 | 시간 2[s] | 손실 1.41
# | 에폭 2 |  반복 141 / 351 | 시간 2[s] | 손실 1.39
# | 에폭 2 |  반복 161 / 351 | 시간 3[s] | 손실 1.38
# | 에폭 2 |  반복 181 / 351 | 시간 3[s] | 손실 1.35
# | 에폭 2 |  반복 201 / 351 | 시간 4[s] | 손실 1.33
# | 에폭 2 |  반복 221 / 351 | 시간 4[s] | 손실 1.32
# | 에폭 2 |  반복 241 / 351 | 시간 5[s] | 손실 1.31
# | 에폭 2 |  반복 261 / 351 | 시간 6[s] | 손실 1.29
# | 에폭 2 |  반복 281 / 351 | 시간 6[s] | 손실 1.28
# | 에폭 2 |  반복 301 / 351 | 시간 7[s] | 손실 1.26
# | 에폭 2 |  반복 321 / 351 | 시간 7[s] | 손실 1.24
# | 에폭 2 |  반복 341 / 351 | 시간 8[s] | 손실 1.23
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1001
# ---
# Q  48+285
# T 666
# ☒ 654
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☒ 414
# ---
# Q 752+006
# T 857
# ☒ 810
# ---
# Q 292+167
# T 1053
# ☒ 1009
# ---
# Q 795+038
# T 1427
# ☒ 1401
# ---
# Q  838+62
# T 864
# ☒ 872
# ---
# Q  39+341
# T 236
# ☒ 226
# ---
# 검증 정확도 2.560%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.20
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.20
# | 에폭 3 |  반복 41 / 351 | 시간 0[s] | 손실 1.18
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.16
# | 에폭 3 |  반복 81 / 351 | 시간 1[s] | 손실 1.14
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 1.13
# | 에폭 3 |  반복 121 / 351 | 시간 2[s] | 손실 1.11
# | 에폭 3 |  반복 141 / 351 | 시간 3[s] | 손실 1.09
# | 에폭 3 |  반복 161 / 351 | 시간 3[s] | 손실 1.08
# | 에폭 3 |  반복 181 / 351 | 시간 4[s] | 손실 1.07
# | 에폭 3 |  반복 201 / 351 | 시간 4[s] | 손실 1.06
# | 에폭 3 |  반복 221 / 351 | 시간 5[s] | 손실 1.04
# | 에폭 3 |  반복 241 / 351 | 시간 6[s] | 손실 1.03
# | 에폭 3 |  반복 261 / 351 | 시간 7[s] | 손실 1.00
# | 에폭 3 |  반복 281 / 351 | 시간 7[s] | 손실 0.99
# | 에폭 3 |  반복 301 / 351 | 시간 8[s] | 손실 0.99
# | 에폭 3 |  반복 321 / 351 | 시간 8[s] | 손실 0.97
# | 에폭 3 |  반복 341 / 351 | 시간 9[s] | 손실 0.97
# Q   58+77
# T 162
# ☒ 150
# ---
# Q 461+579
# T 1139
# ☒ 1234
# ---
# Q  48+285
# T 666
# ☒ 664
# ---
# Q   551+8
# T 163
# ☒ 160
# ---
# Q  55+763
# T 422
# ☒ 414
# ---
# Q 752+006
# T 857
# ☒ 754
# ---
# Q 292+167
# T 1053
# ☒ 1054
# ---
# Q 795+038
# T 1427
# ☒ 1424
# ---
# Q  838+62
# T 864
# ☒ 860
# ---
# Q  39+341
# T 236
# ☒ 244
# ---
# 검증 정확도 5.440%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 0.92
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 0.94
# | 에폭 4 |  반복 41 / 351 | 시간 1[s] | 손실 0.93
# | 에폭 4 |  반복 61 / 351 | 시간 2[s] | 손실 0.91
# | 에폭 4 |  반복 81 / 351 | 시간 2[s] | 손실 0.91
# | 에폭 4 |  반복 101 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 4 |  반복 121 / 351 | 시간 4[s] | 손실 0.89
# | 에폭 4 |  반복 141 / 351 | 시간 4[s] | 손실 0.88
# | 에폭 4 |  반복 161 / 351 | 시간 5[s] | 손실 0.88
# | 에폭 4 |  반복 181 / 351 | 시간 6[s] | 손실 0.87
# | 에폭 4 |  반복 201 / 351 | 시간 6[s] | 손실 0.85
# | 에폭 4 |  반복 221 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 4 |  반복 241 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 4 |  반복 261 / 351 | 시간 8[s] | 손실 0.83
# | 에폭 4 |  반복 281 / 351 | 시간 8[s] | 손실 0.82
# | 에폭 4 |  반복 301 / 351 | 시간 9[s] | 손실 0.82
# | 에폭 4 |  반복 321 / 351 | 시간 9[s] | 손실 0.82
# | 에폭 4 |  반복 341 / 351 | 시간 10[s] | 손실 0.81
# Q   58+77
# T 162
# ☒ 153
# ---
# Q 461+579
# T 1139
# ☒ 1238
# ---
# Q  48+285
# T 666
# ☒ 661
# ---
# Q   551+8
# T 163
# ☒ 152
# ---
# Q  55+763
# T 422
# ☒ 426
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☒ 1058
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☒ 867
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 10.080%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 0.79
# | 에폭 5 |  반복 41 / 351 | 시간 1[s] | 손실 0.79
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 0.79
# | 에폭 5 |  반복 81 / 351 | 시간 2[s] | 손실 0.79
# | 에폭 5 |  반복 101 / 351 | 시간 2[s] | 손실 0.78
# | 에폭 5 |  반복 121 / 351 | 시간 3[s] | 손실 0.77
# | 에폭 5 |  반복 141 / 351 | 시간 3[s] | 손실 0.76
# | 에폭 5 |  반복 161 / 351 | 시간 4[s] | 손실 0.76
# | 에폭 5 |  반복 181 / 351 | 시간 4[s] | 손실 0.75
# | 에폭 5 |  반복 201 / 351 | 시간 5[s] | 손실 0.74
# | 에폭 5 |  반복 221 / 351 | 시간 6[s] | 손실 0.74
# | 에폭 5 |  반복 241 / 351 | 시간 6[s] | 손실 0.74
# | 에폭 5 |  반복 261 / 351 | 시간 6[s] | 손실 0.73
# | 에폭 5 |  반복 281 / 351 | 시간 7[s] | 손실 0.72
# | 에폭 5 |  반복 301 / 351 | 시간 8[s] | 손실 0.72
# | 에폭 5 |  반복 321 / 351 | 시간 8[s] | 손실 0.72
# | 에폭 5 |  반복 341 / 351 | 시간 9[s] | 손실 0.71
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1136
# ---
# Q  48+285
# T 666
# ☒ 669
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☒ 421
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☒ 1057
# ---
# Q 795+038
# T 1427
# ☒ 1421
# ---
# Q  838+62
# T 864
# ☒ 861
# ---
# Q  39+341
# T 236
# ☒ 243
# ---
# 검증 정확도 13.800%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.69
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 0.69
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 0.68
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 0.69
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 0.69
# | 에폭 6 |  반복 101 / 351 | 시간 2[s] | 손실 0.68
# | 에폭 6 |  반복 121 / 351 | 시간 3[s] | 손실 0.69
# | 에폭 6 |  반복 141 / 351 | 시간 4[s] | 손실 0.68
# | 에폭 6 |  반복 161 / 351 | 시간 4[s] | 손실 0.67
# | 에폭 6 |  반복 181 / 351 | 시간 5[s] | 손실 0.68
# | 에폭 6 |  반복 201 / 351 | 시간 5[s] | 손실 0.66
# | 에폭 6 |  반복 221 / 351 | 시간 6[s] | 손실 0.65
# | 에폭 6 |  반복 241 / 351 | 시간 6[s] | 손실 0.64
# | 에폭 6 |  반복 261 / 351 | 시간 7[s] | 손실 0.64
# | 에폭 6 |  반복 281 / 351 | 시간 7[s] | 손실 0.64
# | 에폭 6 |  반복 301 / 351 | 시간 8[s] | 손실 0.64
# | 에폭 6 |  반복 321 / 351 | 시간 8[s] | 손실 0.64
# | 에폭 6 |  반복 341 / 351 | 시간 9[s] | 손실 0.64
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1144
# ---
# Q  48+285
# T 666
# ☒ 660
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☒ 1058
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☒ 868
# ---
# Q  39+341
# T 236
# ☒ 238
# ---
# 검증 정확도 16.500%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.62
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 0.62
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 0.62
# | 에폭 7 |  반복 61 / 351 | 시간 1[s] | 손실 0.62
# | 에폭 7 |  반복 81 / 351 | 시간 2[s] | 손실 0.62
# | 에폭 7 |  반복 101 / 351 | 시간 2[s] | 손실 0.61
# | 에폭 7 |  반복 121 / 351 | 시간 3[s] | 손실 0.61
# | 에폭 7 |  반복 141 / 351 | 시간 3[s] | 손실 0.60
# | 에폭 7 |  반복 161 / 351 | 시간 4[s] | 손실 0.59
# | 에폭 7 |  반복 181 / 351 | 시간 4[s] | 손실 0.59
# | 에폭 7 |  반복 201 / 351 | 시간 5[s] | 손실 0.59
# | 에폭 7 |  반복 221 / 351 | 시간 6[s] | 손실 0.59
# | 에폭 7 |  반복 241 / 351 | 시간 6[s] | 손실 0.58
# | 에폭 7 |  반복 261 / 351 | 시간 7[s] | 손실 0.60
# | 에폭 7 |  반복 281 / 351 | 시간 7[s] | 손실 0.59
# | 에폭 7 |  반복 301 / 351 | 시간 8[s] | 손실 0.57
# | 에폭 7 |  반복 321 / 351 | 시간 9[s] | 손실 0.57
# | 에폭 7 |  반복 341 / 351 | 시간 10[s] | 손실 0.57
# Q   58+77
# T 162
# ☒ 161
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☒ 669
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☒ 861
# ---
# Q  39+341
# T 236
# ☒ 239
# ---
# 검증 정확도 21.300%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.57
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 8 |  반복 41 / 351 | 시간 1[s] | 손실 0.56
# | 에폭 8 |  반복 61 / 351 | 시간 1[s] | 손실 0.57
# | 에폭 8 |  반복 81 / 351 | 시간 2[s] | 손실 0.57
# | 에폭 8 |  반복 101 / 351 | 시간 3[s] | 손실 0.56
# | 에폭 8 |  반복 121 / 351 | 시간 3[s] | 손실 0.56
# | 에폭 8 |  반복 141 / 351 | 시간 4[s] | 손실 0.56
# | 에폭 8 |  반복 161 / 351 | 시간 4[s] | 손실 0.55
# | 에폭 8 |  반복 181 / 351 | 시간 5[s] | 손실 0.55
# | 에폭 8 |  반복 201 / 351 | 시간 6[s] | 손실 0.55
# | 에폭 8 |  반복 221 / 351 | 시간 6[s] | 손실 0.56
# | 에폭 8 |  반복 241 / 351 | 시간 7[s] | 손실 0.54
# | 에폭 8 |  반복 261 / 351 | 시간 7[s] | 손실 0.55
# | 에폭 8 |  반복 281 / 351 | 시간 8[s] | 손실 0.55
# | 에폭 8 |  반복 301 / 351 | 시간 9[s] | 손실 0.55
# | 에폭 8 |  반복 321 / 351 | 시간 9[s] | 손실 0.53
# | 에폭 8 |  반복 341 / 351 | 시간 10[s] | 손실 0.54
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☒ 669
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 860
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1425
# ---
# Q  838+62
# T 864
# ☒ 863
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 18.180%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.57
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 0.53
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 0.51
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 0.51
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 0.51
# | 에폭 9 |  반복 101 / 351 | 시간 2[s] | 손실 0.51
# | 에폭 9 |  반복 121 / 351 | 시간 3[s] | 손실 0.51
# | 에폭 9 |  반복 141 / 351 | 시간 3[s] | 손실 0.52
# | 에폭 9 |  반복 161 / 351 | 시간 4[s] | 손실 0.51
# | 에폭 9 |  반복 181 / 351 | 시간 5[s] | 손실 0.52
# | 에폭 9 |  반복 201 / 351 | 시간 5[s] | 손실 0.51
# | 에폭 9 |  반복 221 / 351 | 시간 6[s] | 손실 0.51
# | 에폭 9 |  반복 241 / 351 | 시간 6[s] | 손실 0.50
# | 에폭 9 |  반복 261 / 351 | 시간 7[s] | 손실 0.51
# | 에폭 9 |  반복 281 / 351 | 시간 7[s] | 손실 0.50
# | 에폭 9 |  반복 301 / 351 | 시간 8[s] | 손실 0.51
# | 에폭 9 |  반복 321 / 351 | 시간 8[s] | 손실 0.51
# | 에폭 9 |  반복 341 / 351 | 시간 9[s] | 손실 0.50
# Q   58+77
# T 162
# ☒ 161
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☒ 669
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☒ 1052
# ---
# Q 795+038
# T 1427
# ☒ 1425
# ---
# Q  838+62
# T 864
# ☒ 860
# ---
# Q  39+341
# T 236
# ☒ 234
# ---
# 검증 정확도 22.000%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.54
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.49
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.50
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 0.49
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 0.48
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 0.49
# | 에폭 10 |  반복 121 / 351 | 시간 2[s] | 손실 0.48
# | 에폭 10 |  반복 141 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 10 |  반복 161 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 10 |  반복 181 / 351 | 시간 4[s] | 손실 0.47
# | 에폭 10 |  반복 201 / 351 | 시간 5[s] | 손실 0.48
# | 에폭 10 |  반복 221 / 351 | 시간 5[s] | 손실 0.48
# | 에폭 10 |  반복 241 / 351 | 시간 6[s] | 손실 0.47
# | 에폭 10 |  반복 261 / 351 | 시간 7[s] | 손실 0.47
# | 에폭 10 |  반복 281 / 351 | 시간 8[s] | 손실 0.47
# | 에폭 10 |  반복 301 / 351 | 시간 8[s] | 손실 0.47
# | 에폭 10 |  반복 321 / 351 | 시간 9[s] | 손실 0.46
# | 에폭 10 |  반복 341 / 351 | 시간 9[s] | 손실 0.47
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1420
# ---
# Q  838+62
# T 864
# ☒ 863
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 29.820%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 11 |  반복 41 / 351 | 시간 0[s] | 손실 0.48
# | 에폭 11 |  반복 61 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 11 |  반복 81 / 351 | 시간 1[s] | 손실 0.47
# | 에폭 11 |  반복 101 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 11 |  반복 121 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 11 |  반복 141 / 351 | 시간 3[s] | 손실 0.45
# | 에폭 11 |  반복 161 / 351 | 시간 3[s] | 손실 0.48
# | 에폭 11 |  반복 181 / 351 | 시간 4[s] | 손실 0.46
# | 에폭 11 |  반복 201 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 11 |  반복 221 / 351 | 시간 5[s] | 손실 0.46
# | 에폭 11 |  반복 241 / 351 | 시간 6[s] | 손실 0.47
# | 에폭 11 |  반복 261 / 351 | 시간 6[s] | 손실 0.46
# | 에폭 11 |  반복 281 / 351 | 시간 7[s] | 손실 0.45
# | 에폭 11 |  반복 301 / 351 | 시간 7[s] | 손실 0.45
# | 에폭 11 |  반복 321 / 351 | 시간 8[s] | 손실 0.45
# | 에폭 11 |  반복 341 / 351 | 시간 9[s] | 손실 0.45
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☒ 668
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☒ 1054
# ---
# Q 795+038
# T 1427
# ☒ 1425
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☒ 238
# ---
# 검증 정확도 30.800%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.42
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.44
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.45
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 12 |  반복 101 / 351 | 시간 3[s] | 손실 0.44
# | 에폭 12 |  반복 121 / 351 | 시간 4[s] | 손실 0.44
# | 에폭 12 |  반복 141 / 351 | 시간 5[s] | 손실 0.44
# | 에폭 12 |  반복 161 / 351 | 시간 5[s] | 손실 0.44
# | 에폭 12 |  반복 181 / 351 | 시간 6[s] | 손실 0.44
# | 에폭 12 |  반복 201 / 351 | 시간 6[s] | 손실 0.43
# | 에폭 12 |  반복 221 / 351 | 시간 7[s] | 손실 0.43
# | 에폭 12 |  반복 241 / 351 | 시간 7[s] | 손실 0.43
# | 에폭 12 |  반복 261 / 351 | 시간 8[s] | 손실 0.45
# | 에폭 12 |  반복 281 / 351 | 시간 8[s] | 손실 0.44
# | 에폭 12 |  반복 301 / 351 | 시간 9[s] | 손실 0.44
# | 에폭 12 |  반복 321 / 351 | 시간 9[s] | 손실 0.44
# | 에폭 12 |  반복 341 / 351 | 시간 10[s] | 손실 0.44
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 29.340%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.44
# | 에폭 13 |  반복 41 / 351 | 시간 0[s] | 손실 0.43
# | 에폭 13 |  반복 61 / 351 | 시간 1[s] | 손실 0.42
# | 에폭 13 |  반복 81 / 351 | 시간 1[s] | 손실 0.42
# | 에폭 13 |  반복 101 / 351 | 시간 2[s] | 손실 0.41
# | 에폭 13 |  반복 121 / 351 | 시간 2[s] | 손실 0.42
# | 에폭 13 |  반복 141 / 351 | 시간 3[s] | 손실 0.41
# | 에폭 13 |  반복 161 / 351 | 시간 3[s] | 손실 0.42
# | 에폭 13 |  반복 181 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 13 |  반복 201 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 13 |  반복 221 / 351 | 시간 5[s] | 손실 0.41
# | 에폭 13 |  반복 241 / 351 | 시간 5[s] | 손실 0.41
# | 에폭 13 |  반복 261 / 351 | 시간 6[s] | 손실 0.41
# | 에폭 13 |  반복 281 / 351 | 시간 7[s] | 손실 0.41
# | 에폭 13 |  반복 301 / 351 | 시간 7[s] | 손실 0.41
# | 에폭 13 |  반복 321 / 351 | 시간 8[s] | 손실 0.42
# | 에폭 13 |  반복 341 / 351 | 시간 8[s] | 손실 0.41
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1136
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1425
# ---
# Q  838+62
# T 864
# ☒ 863
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 33.140%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.42
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.41
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 0.41
# | 에폭 14 |  반복 81 / 351 | 시간 2[s] | 손실 0.41
# | 에폭 14 |  반복 101 / 351 | 시간 2[s] | 손실 0.41
# | 에폭 14 |  반복 121 / 351 | 시간 2[s] | 손실 0.42
# | 에폭 14 |  반복 141 / 351 | 시간 3[s] | 손실 0.41
# | 에폭 14 |  반복 161 / 351 | 시간 4[s] | 손실 0.41
# | 에폭 14 |  반복 181 / 351 | 시간 5[s] | 손실 0.40
# | 에폭 14 |  반복 201 / 351 | 시간 5[s] | 손실 0.41
# | 에폭 14 |  반복 221 / 351 | 시간 6[s] | 손실 0.40
# | 에폭 14 |  반복 241 / 351 | 시간 6[s] | 손실 0.40
# | 에폭 14 |  반복 261 / 351 | 시간 7[s] | 손실 0.41
# | 에폭 14 |  반복 281 / 351 | 시간 8[s] | 손실 0.41
# | 에폭 14 |  반복 301 / 351 | 시간 9[s] | 손실 0.42
# | 에폭 14 |  반복 321 / 351 | 시간 10[s] | 손실 0.42
# | 에폭 14 |  반복 341 / 351 | 시간 10[s] | 손실 0.40
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1425
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 37.500%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.40
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.38
# | 에폭 15 |  반복 41 / 351 | 시간 2[s] | 손실 0.39
# | 에폭 15 |  반복 61 / 351 | 시간 2[s] | 손실 0.41
# | 에폭 15 |  반복 81 / 351 | 시간 3[s] | 손실 0.41
# | 에폭 15 |  반복 101 / 351 | 시간 3[s] | 손실 0.42
# | 에폭 15 |  반복 121 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 15 |  반복 141 / 351 | 시간 5[s] | 손실 0.41
# | 에폭 15 |  반복 161 / 351 | 시간 7[s] | 손실 0.39
# | 에폭 15 |  반복 181 / 351 | 시간 7[s] | 손실 0.39
# | 에폭 15 |  반복 201 / 351 | 시간 8[s] | 손실 0.38
# | 에폭 15 |  반복 221 / 351 | 시간 9[s] | 손실 0.39
# | 에폭 15 |  반복 241 / 351 | 시간 10[s] | 손실 0.39
# | 에폭 15 |  반복 261 / 351 | 시간 10[s] | 손실 0.39
# | 에폭 15 |  반복 281 / 351 | 시간 11[s] | 손실 0.39
# | 에폭 15 |  반복 301 / 351 | 시간 12[s] | 손실 0.38
# | 에폭 15 |  반복 321 / 351 | 시간 13[s] | 손실 0.39
# | 에폭 15 |  반복 341 / 351 | 시간 13[s] | 손실 0.39
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1141
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☒ 863
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 36.460%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.37
# | 에폭 16 |  반복 21 / 351 | 시간 1[s] | 손실 0.39
# | 에폭 16 |  반복 41 / 351 | 시간 2[s] | 손실 0.39
# | 에폭 16 |  반복 61 / 351 | 시간 2[s] | 손실 0.39
# | 에폭 16 |  반복 81 / 351 | 시간 3[s] | 손실 0.41
# | 에폭 16 |  반복 101 / 351 | 시간 4[s] | 손실 0.41
# | 에폭 16 |  반복 121 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 16 |  반복 141 / 351 | 시간 6[s] | 손실 0.40
# | 에폭 16 |  반복 161 / 351 | 시간 6[s] | 손실 0.39
# | 에폭 16 |  반복 181 / 351 | 시간 7[s] | 손실 0.38
# | 에폭 16 |  반복 201 / 351 | 시간 8[s] | 손실 0.38
# | 에폭 16 |  반복 221 / 351 | 시간 9[s] | 손실 0.39
# | 에폭 16 |  반복 241 / 351 | 시간 10[s] | 손실 0.38
# | 에폭 16 |  반복 261 / 351 | 시간 11[s] | 손실 0.39
# | 에폭 16 |  반복 281 / 351 | 시간 11[s] | 손실 0.38
# | 에폭 16 |  반복 301 / 351 | 시간 12[s] | 손실 0.38
# | 에폭 16 |  반복 321 / 351 | 시간 13[s] | 손실 0.37
# | 에폭 16 |  반복 341 / 351 | 시간 14[s] | 손실 0.37
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 859
# ---
# Q 292+167
# T 1053
# ☒ 1052
# ---
# Q 795+038
# T 1427
# ☒ 1424
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 35.460%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.38
# | 에폭 17 |  반복 21 / 351 | 시간 1[s] | 손실 0.38
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.38
# | 에폭 17 |  반복 61 / 351 | 시간 2[s] | 손실 0.36
# | 에폭 17 |  반복 81 / 351 | 시간 3[s] | 손실 0.38
# | 에폭 17 |  반복 101 / 351 | 시간 3[s] | 손실 0.37
# | 에폭 17 |  반복 121 / 351 | 시간 4[s] | 손실 0.36
# | 에폭 17 |  반복 141 / 351 | 시간 5[s] | 손실 0.37
# | 에폭 17 |  반복 161 / 351 | 시간 5[s] | 손실 0.36
# | 에폭 17 |  반복 181 / 351 | 시간 6[s] | 손실 0.37
# | 에폭 17 |  반복 201 / 351 | 시간 7[s] | 손실 0.37
# | 에폭 17 |  반복 221 / 351 | 시간 7[s] | 손실 0.38
# | 에폭 17 |  반복 241 / 351 | 시간 8[s] | 손실 0.37
# | 에폭 17 |  반복 261 / 351 | 시간 8[s] | 손실 0.37
# | 에폭 17 |  반복 281 / 351 | 시간 9[s] | 손실 0.39
# | 에폭 17 |  반복 301 / 351 | 시간 10[s] | 손실 0.40
# | 에폭 17 |  반복 321 / 351 | 시간 10[s] | 손실 0.38
# | 에폭 17 |  반복 341 / 351 | 시간 11[s] | 손실 0.37
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 856
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1424
# ---
# Q  838+62
# T 864
# ☒ 865
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 39.280%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.37
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 18 |  반복 41 / 351 | 시간 1[s] | 손실 0.35
# | 에폭 18 |  반복 61 / 351 | 시간 1[s] | 손실 0.37
# | 에폭 18 |  반복 81 / 351 | 시간 1[s] | 손실 0.38
# | 에폭 18 |  반복 101 / 351 | 시간 2[s] | 손실 0.37
# | 에폭 18 |  반복 121 / 351 | 시간 2[s] | 손실 0.36
# | 에폭 18 |  반복 141 / 351 | 시간 3[s] | 손실 0.37
# | 에폭 18 |  반복 161 / 351 | 시간 3[s] | 손실 0.37
# | 에폭 18 |  반복 181 / 351 | 시간 4[s] | 손실 0.36
# | 에폭 18 |  반복 201 / 351 | 시간 4[s] | 손실 0.35
# | 에폭 18 |  반복 221 / 351 | 시간 5[s] | 손실 0.36
# | 에폭 18 |  반복 241 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 18 |  반복 261 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 18 |  반복 281 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 18 |  반복 301 / 351 | 시간 6[s] | 손실 0.37
# | 에폭 18 |  반복 321 / 351 | 시간 7[s] | 손실 0.36
# | 에폭 18 |  반복 341 / 351 | 시간 7[s] | 손실 0.36
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1425
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 35.900%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.38
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.37
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 19 |  반복 61 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 19 |  반복 81 / 351 | 시간 1[s] | 손실 0.37
# | 에폭 19 |  반복 101 / 351 | 시간 2[s] | 손실 0.37
# | 에폭 19 |  반복 121 / 351 | 시간 2[s] | 손실 0.37
# | 에폭 19 |  반복 141 / 351 | 시간 3[s] | 손실 0.36
# | 에폭 19 |  반복 161 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 19 |  반복 181 / 351 | 시간 4[s] | 손실 0.35
# | 에폭 19 |  반복 201 / 351 | 시간 4[s] | 손실 0.35
# | 에폭 19 |  반복 221 / 351 | 시간 5[s] | 손실 0.36
# | 에폭 19 |  반복 241 / 351 | 시간 5[s] | 손실 0.36
# | 에폭 19 |  반복 261 / 351 | 시간 6[s] | 손실 0.35
# | 에폭 19 |  반복 281 / 351 | 시간 7[s] | 손실 0.36
# | 에폭 19 |  반복 301 / 351 | 시간 7[s] | 손실 0.35
# | 에폭 19 |  반복 321 / 351 | 시간 8[s] | 손실 0.35
# | 에폭 19 |  반복 341 / 351 | 시간 8[s] | 손실 0.36
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☒ 1052
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☒ 239
# ---
# 검증 정확도 36.220%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.40
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.35
# | 에폭 20 |  반복 41 / 351 | 시간 0[s] | 손실 0.35
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.37
# | 에폭 20 |  반복 81 / 351 | 시간 2[s] | 손실 0.35
# | 에폭 20 |  반복 101 / 351 | 시간 2[s] | 손실 0.35
# | 에폭 20 |  반복 121 / 351 | 시간 3[s] | 손실 0.35
# | 에폭 20 |  반복 141 / 351 | 시간 3[s] | 손실 0.35
# | 에폭 20 |  반복 161 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 20 |  반복 181 / 351 | 시간 4[s] | 손실 0.35
# | 에폭 20 |  반복 201 / 351 | 시간 5[s] | 손실 0.34
# | 에폭 20 |  반복 221 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 20 |  반복 241 / 351 | 시간 6[s] | 손실 0.35
# | 에폭 20 |  반복 261 / 351 | 시간 7[s] | 손실 0.36
# | 에폭 20 |  반복 281 / 351 | 시간 7[s] | 손실 0.34
# | 에폭 20 |  반복 301 / 351 | 시간 8[s] | 손실 0.35
# | 에폭 20 |  반복 321 / 351 | 시간 9[s] | 손실 0.33
# | 에폭 20 |  반복 341 / 351 | 시간 9[s] | 손실 0.33
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1136
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 856
# ---
# Q 292+167
# T 1053
# ☒ 1051
# ---
# Q 795+038
# T 1427
# ☒ 1424
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 41.520%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.37
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 21 |  반복 41 / 351 | 시간 1[s] | 손실 0.34
# | 에폭 21 |  반복 61 / 351 | 시간 1[s] | 손실 0.33
# | 에폭 21 |  반복 81 / 351 | 시간 2[s] | 손실 0.32
# | 에폭 21 |  반복 101 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 21 |  반복 121 / 351 | 시간 3[s] | 손실 0.33
# | 에폭 21 |  반복 141 / 351 | 시간 3[s] | 손실 0.33
# | 에폭 21 |  반복 161 / 351 | 시간 4[s] | 손실 0.34
# | 에폭 21 |  반복 181 / 351 | 시간 4[s] | 손실 0.34
# | 에폭 21 |  반복 201 / 351 | 시간 5[s] | 손실 0.36
# | 에폭 21 |  반복 221 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 21 |  반복 241 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 21 |  반복 261 / 351 | 시간 7[s] | 손실 0.33
# | 에폭 21 |  반복 281 / 351 | 시간 8[s] | 손실 0.34
# | 에폭 21 |  반복 301 / 351 | 시간 8[s] | 손실 0.34
# | 에폭 21 |  반복 321 / 351 | 시간 9[s] | 손실 0.35
# | 에폭 21 |  반복 341 / 351 | 시간 9[s] | 손실 0.34
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1136
# ---
# Q  48+285
# T 666
# ☒ 664
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 859
# ---
# Q 292+167
# T 1053
# ☒ 1052
# ---
# Q 795+038
# T 1427
# ☒ 1424
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 43.020%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 0.32
# | 에폭 22 |  반복 61 / 351 | 시간 1[s] | 손실 0.32
# | 에폭 22 |  반복 81 / 351 | 시간 1[s] | 손실 0.32
# | 에폭 22 |  반복 101 / 351 | 시간 2[s] | 손실 0.32
# | 에폭 22 |  반복 121 / 351 | 시간 2[s] | 손실 0.33
# | 에폭 22 |  반복 141 / 351 | 시간 3[s] | 손실 0.33
# | 에폭 22 |  반복 161 / 351 | 시간 3[s] | 손실 0.37
# | 에폭 22 |  반복 181 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 22 |  반복 201 / 351 | 시간 5[s] | 손실 0.32
# | 에폭 22 |  반복 221 / 351 | 시간 5[s] | 손실 0.34
# | 에폭 22 |  반복 241 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 22 |  반복 261 / 351 | 시간 6[s] | 손실 0.32
# | 에폭 22 |  반복 281 / 351 | 시간 7[s] | 손실 0.34
# | 에폭 22 |  반복 301 / 351 | 시간 7[s] | 손실 0.33
# | 에폭 22 |  반복 321 / 351 | 시간 8[s] | 손실 0.36
# | 에폭 22 |  반복 341 / 351 | 시간 8[s] | 손실 0.35
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☒ 663
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1422
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☒ 238
# ---
# 검증 정확도 41.480%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.33
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 23 |  반복 41 / 351 | 시간 1[s] | 손실 0.33
# | 에폭 23 |  반복 61 / 351 | 시간 2[s] | 손실 0.33
# | 에폭 23 |  반복 81 / 351 | 시간 2[s] | 손실 0.32
# | 에폭 23 |  반복 101 / 351 | 시간 3[s] | 손실 0.32
# | 에폭 23 |  반복 121 / 351 | 시간 4[s] | 손실 0.32
# | 에폭 23 |  반복 141 / 351 | 시간 4[s] | 손실 0.31
# | 에폭 23 |  반복 161 / 351 | 시간 5[s] | 손실 0.32
# | 에폭 23 |  반복 181 / 351 | 시간 6[s] | 손실 0.32
# | 에폭 23 |  반복 201 / 351 | 시간 6[s] | 손실 0.32
# | 에폭 23 |  반복 221 / 351 | 시간 7[s] | 손실 0.32
# | 에폭 23 |  반복 241 / 351 | 시간 8[s] | 손실 0.33
# | 에폭 23 |  반복 261 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 23 |  반복 281 / 351 | 시간 9[s] | 손실 0.34
# | 에폭 23 |  반복 301 / 351 | 시간 9[s] | 손실 0.34
# | 에폭 23 |  반복 321 / 351 | 시간 10[s] | 손실 0.34
# | 에폭 23 |  반복 341 / 351 | 시간 10[s] | 손실 0.33
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☒ 164
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 856
# ---
# Q 292+167
# T 1053
# ☒ 1052
# ---
# Q 795+038
# T 1427
# ☒ 1425
# ---
# Q  838+62
# T 864
# ☒ 865
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 42.280%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 24 |  반복 41 / 351 | 시간 1[s] | 손실 0.31
# | 에폭 24 |  반복 61 / 351 | 시간 1[s] | 손실 0.32
# | 에폭 24 |  반복 81 / 351 | 시간 2[s] | 손실 0.32
# | 에폭 24 |  반복 101 / 351 | 시간 2[s] | 손실 0.33
# | 에폭 24 |  반복 121 / 351 | 시간 3[s] | 손실 0.33
# | 에폭 24 |  반복 141 / 351 | 시간 3[s] | 손실 0.32
# | 에폭 24 |  반복 161 / 351 | 시간 4[s] | 손실 0.32
# | 에폭 24 |  반복 181 / 351 | 시간 4[s] | 손실 0.32
# | 에폭 24 |  반복 201 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 24 |  반복 221 / 351 | 시간 5[s] | 손실 0.31
# | 에폭 24 |  반복 241 / 351 | 시간 6[s] | 손실 0.32
# | 에폭 24 |  반복 261 / 351 | 시간 7[s] | 손실 0.32
# | 에폭 24 |  반복 281 / 351 | 시간 7[s] | 손실 0.31
# | 에폭 24 |  반복 301 / 351 | 시간 8[s] | 손실 0.31
# | 에폭 24 |  반복 321 / 351 | 시간 9[s] | 손실 0.30
# | 에폭 24 |  반복 341 / 351 | 시간 9[s] | 손실 0.31
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 859
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1426
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☒ 238
# ---
# 검증 정확도 47.380%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 25 |  반복 41 / 351 | 시간 1[s] | 손실 0.30
# | 에폭 25 |  반복 61 / 351 | 시간 2[s] | 손실 0.33
# | 에폭 25 |  반복 81 / 351 | 시간 2[s] | 손실 0.32
# | 에폭 25 |  반복 101 / 351 | 시간 3[s] | 손실 0.32
# | 에폭 25 |  반복 121 / 351 | 시간 3[s] | 손실 0.33
# | 에폭 25 |  반복 141 / 351 | 시간 4[s] | 손실 0.31
# | 에폭 25 |  반복 161 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 25 |  반복 181 / 351 | 시간 5[s] | 손실 0.30
# | 에폭 25 |  반복 201 / 351 | 시간 6[s] | 손실 0.30
# | 에폭 25 |  반복 221 / 351 | 시간 6[s] | 손실 0.30
# | 에폭 25 |  반복 241 / 351 | 시간 7[s] | 손실 0.31
# | 에폭 25 |  반복 261 / 351 | 시간 8[s] | 손실 0.31
# | 에폭 25 |  반복 281 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 25 |  반복 301 / 351 | 시간 8[s] | 손실 0.30
# | 에폭 25 |  반복 321 / 351 | 시간 9[s] | 손실 0.31
# | 에폭 25 |  반복 341 / 351 | 시간 10[s] | 손실 0.31
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 859
# ---
# Q 292+167
# T 1053
# ☒ 1052
# ---
# Q 795+038
# T 1427
# ☒ 1424
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 46.500%

# %%
plt.plot(np.arange(1,max_epoch+1), acc_listRNN, marker='o', label='origin')
plt.plot(np.arange(1,max_epoch+1), reversed_acc_list_RNN, marker='o', color='green', label='reverse')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %% [markdown]
# ## seq2seq 개선
#
# 입력 데이터 반전(Reverse)

# %%
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
char_to_id, id_to_char = sequence.get_vocab()

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

model = Seq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

reversed_acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    reversed_acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.60
# | 에폭 1 |  반복 21 / 351 | 시간 5[s] | 손실 2.34
# | 에폭 1 |  반복 41 / 351 | 시간 7[s] | 손실 2.06
# | 에폭 1 |  반복 61 / 351 | 시간 8[s] | 손실 1.94
# | 에폭 1 |  반복 81 / 351 | 시간 9[s] | 손실 1.90
# | 에폭 1 |  반복 101 / 351 | 시간 10[s] | 손실 1.86
# | 에폭 1 |  반복 121 / 351 | 시간 12[s] | 손실 1.85
# | 에폭 1 |  반복 141 / 351 | 시간 16[s] | 손실 1.84
# | 에폭 1 |  반복 161 / 351 | 시간 18[s] | 손실 1.84
# | 에폭 1 |  반복 181 / 351 | 시간 19[s] | 손실 1.84
# | 에폭 1 |  반복 201 / 351 | 시간 21[s] | 손실 1.83
# | 에폭 1 |  반복 221 / 351 | 시간 22[s] | 손실 1.83
# | 에폭 1 |  반복 241 / 351 | 시간 23[s] | 손실 1.81
# | 에폭 1 |  반복 261 / 351 | 시간 24[s] | 손실 1.77
# | 에폭 1 |  반복 281 / 351 | 시간 25[s] | 손실 1.75
# | 에폭 1 |  반복 301 / 351 | 시간 27[s] | 손실 1.73
# | 에폭 1 |  반복 321 / 351 | 시간 31[s] | 손실 1.72
# | 에폭 1 |  반복 341 / 351 | 시간 32[s] | 손실 1.70
# Q   58+77
# T 162
# ☒ 102
# ---
# Q 461+579
# T 1139
# ☒ 1022
# ---
# Q  48+285
# T 666
# ☒ 502
# ---
# Q   551+8
# T 163
# ☒ 102
# ---
# Q  55+763
# T 422
# ☒ 502
# ---
# Q 752+006
# T 857
# ☒ 1002
# ---
# Q 292+167
# T 1053
# ☒ 1022
# ---
# Q 795+038
# T 1427
# ☒ 1024
# ---
# Q  838+62
# T 864
# ☒ 577
# ---
# Q  39+341
# T 236
# ☒ 577
# ---
# 검증 정확도 0.220%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.68
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.68
# | 에폭 2 |  반복 41 / 351 | 시간 1[s] | 손실 1.67
# | 에폭 2 |  반복 61 / 351 | 시간 2[s] | 손실 1.66
# | 에폭 2 |  반복 81 / 351 | 시간 3[s] | 손실 1.65
# | 에폭 2 |  반복 101 / 351 | 시간 4[s] | 손실 1.63
# | 에폭 2 |  반복 121 / 351 | 시간 5[s] | 손실 1.62
# | 에폭 2 |  반복 141 / 351 | 시간 6[s] | 손실 1.61
# | 에폭 2 |  반복 161 / 351 | 시간 7[s] | 손실 1.60
# | 에폭 2 |  반복 181 / 351 | 시간 8[s] | 손실 1.59
# | 에폭 2 |  반복 201 / 351 | 시간 9[s] | 손실 1.59
# | 에폭 2 |  반복 221 / 351 | 시간 10[s] | 손실 1.57
# | 에폭 2 |  반복 241 / 351 | 시간 11[s] | 손실 1.56
# | 에폭 2 |  반복 261 / 351 | 시간 12[s] | 손실 1.55
# | 에폭 2 |  반복 281 / 351 | 시간 13[s] | 손실 1.54
# | 에폭 2 |  반복 301 / 351 | 시간 14[s] | 손실 1.54
# | 에폭 2 |  반복 321 / 351 | 시간 15[s] | 손실 1.53
# | 에폭 2 |  반복 341 / 351 | 시간 16[s] | 손실 1.52
# Q   58+77
# T 162
# ☒ 116
# ---
# Q 461+579
# T 1139
# ☒ 1000
# ---
# Q  48+285
# T 666
# ☒ 638
# ---
# Q   551+8
# T 163
# ☒ 110
# ---
# Q  55+763
# T 422
# ☒ 490
# ---
# Q 752+006
# T 857
# ☒ 820
# ---
# Q 292+167
# T 1053
# ☒ 1000
# ---
# Q 795+038
# T 1427
# ☒ 1399
# ---
# Q  838+62
# T 864
# ☒ 890
# ---
# Q  39+341
# T 236
# ☒ 293
# ---
# 검증 정확도 0.280%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.51
# | 에폭 3 |  반복 21 / 351 | 시간 1[s] | 손실 1.50
# | 에폭 3 |  반복 41 / 351 | 시간 2[s] | 손실 1.49
# | 에폭 3 |  반복 61 / 351 | 시간 3[s] | 손실 1.48
# | 에폭 3 |  반복 81 / 351 | 시간 4[s] | 손실 1.47
# | 에폭 3 |  반복 101 / 351 | 시간 5[s] | 손실 1.45
# | 에폭 3 |  반복 121 / 351 | 시간 6[s] | 손실 1.43
# | 에폭 3 |  반복 141 / 351 | 시간 7[s] | 손실 1.42
# | 에폭 3 |  반복 161 / 351 | 시간 8[s] | 손실 1.41
# | 에폭 3 |  반복 181 / 351 | 시간 10[s] | 손실 1.39
# | 에폭 3 |  반복 201 / 351 | 시간 11[s] | 손실 1.38
# | 에폭 3 |  반복 221 / 351 | 시간 13[s] | 손실 1.36
# | 에폭 3 |  반복 241 / 351 | 시간 14[s] | 손실 1.35
# | 에폭 3 |  반복 261 / 351 | 시간 15[s] | 손실 1.34
# | 에폭 3 |  반복 281 / 351 | 시간 16[s] | 손실 1.33
# | 에폭 3 |  반복 301 / 351 | 시간 17[s] | 손실 1.32
# | 에폭 3 |  반복 321 / 351 | 시간 19[s] | 손실 1.32
# | 에폭 3 |  반복 341 / 351 | 시간 20[s] | 손실 1.31
# Q   58+77
# T 162
# ☒ 177
# ---
# Q 461+579
# T 1139
# ☒ 1109
# ---
# Q  48+285
# T 666
# ☒ 671
# ---
# Q   551+8
# T 163
# ☒ 147
# ---
# Q  55+763
# T 422
# ☒ 491
# ---
# Q 752+006
# T 857
# ☒ 891
# ---
# Q 292+167
# T 1053
# ☒ 1001
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 891
# ---
# Q  39+341
# T 236
# ☒ 291
# ---
# 검증 정확도 1.760%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.28
# | 에폭 4 |  반복 21 / 351 | 시간 1[s] | 손실 1.29
# | 에폭 4 |  반복 41 / 351 | 시간 2[s] | 손실 1.27
# | 에폭 4 |  반복 61 / 351 | 시간 3[s] | 손실 1.27
# | 에폭 4 |  반복 81 / 351 | 시간 4[s] | 손실 1.26
# | 에폭 4 |  반복 101 / 351 | 시간 6[s] | 손실 1.25
# | 에폭 4 |  반복 121 / 351 | 시간 7[s] | 손실 1.24
# | 에폭 4 |  반복 141 / 351 | 시간 8[s] | 손실 1.23
# | 에폭 4 |  반복 161 / 351 | 시간 9[s] | 손실 1.22
# | 에폭 4 |  반복 181 / 351 | 시간 10[s] | 손실 1.22
# | 에폭 4 |  반복 201 / 351 | 시간 12[s] | 손실 1.20
# | 에폭 4 |  반복 221 / 351 | 시간 13[s] | 손실 1.21
# | 에폭 4 |  반복 241 / 351 | 시간 14[s] | 손실 1.19
# | 에폭 4 |  반복 261 / 351 | 시간 15[s] | 손실 1.17
# | 에폭 4 |  반복 281 / 351 | 시간 16[s] | 손실 1.17
# | 에폭 4 |  반복 301 / 351 | 시간 18[s] | 손실 1.16
# | 에폭 4 |  반복 321 / 351 | 시간 19[s] | 손실 1.16
# | 에폭 4 |  반복 341 / 351 | 시간 20[s] | 손실 1.14
# Q   58+77
# T 162
# ☒ 157
# ---
# Q 461+579
# T 1139
# ☒ 1134
# ---
# Q  48+285
# T 666
# ☒ 637
# ---
# Q   551+8
# T 163
# ☒ 148
# ---
# Q  55+763
# T 422
# ☒ 411
# ---
# Q 752+006
# T 857
# ☒ 875
# ---
# Q 292+167
# T 1053
# ☒ 1011
# ---
# Q 795+038
# T 1427
# ☒ 1371
# ---
# Q  838+62
# T 864
# ☒ 885
# ---
# Q  39+341
# T 236
# ☒ 211
# ---
# 검증 정확도 3.200%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.13
# | 에폭 5 |  반복 21 / 351 | 시간 1[s] | 손실 1.13
# | 에폭 5 |  반복 41 / 351 | 시간 2[s] | 손실 1.12
# | 에폭 5 |  반복 61 / 351 | 시간 3[s] | 손실 1.12
# | 에폭 5 |  반복 81 / 351 | 시간 5[s] | 손실 1.11
# | 에폭 5 |  반복 101 / 351 | 시간 6[s] | 손실 1.10
# | 에폭 5 |  반복 121 / 351 | 시간 7[s] | 손실 1.09
# | 에폭 5 |  반복 141 / 351 | 시간 8[s] | 손실 1.08
# | 에폭 5 |  반복 161 / 351 | 시간 10[s] | 손실 1.07
# | 에폭 5 |  반복 181 / 351 | 시간 11[s] | 손실 1.06
# | 에폭 5 |  반복 201 / 351 | 시간 12[s] | 손실 1.05
# | 에폭 5 |  반복 221 / 351 | 시간 13[s] | 손실 1.04
# | 에폭 5 |  반복 241 / 351 | 시간 15[s] | 손실 1.03
# | 에폭 5 |  반복 261 / 351 | 시간 16[s] | 손실 1.03
# | 에폭 5 |  반복 281 / 351 | 시간 17[s] | 손실 1.02
# | 에폭 5 |  반복 301 / 351 | 시간 18[s] | 손실 1.01
# | 에폭 5 |  반복 321 / 351 | 시간 20[s] | 손실 1.00
# | 에폭 5 |  반복 341 / 351 | 시간 22[s] | 손실 0.99
# Q   58+77
# T 162
# ☒ 159
# ---
# Q 461+579
# T 1139
# ☒ 1079
# ---
# Q  48+285
# T 666
# ☒ 658
# ---
# Q   551+8
# T 163
# ☒ 168
# ---
# Q  55+763
# T 422
# ☒ 413
# ---
# Q 752+006
# T 857
# ☒ 850
# ---
# Q 292+167
# T 1053
# ☒ 1049
# ---
# Q 795+038
# T 1427
# ☒ 1419
# ---
# Q  838+62
# T 864
# ☒ 861
# ---
# Q  39+341
# T 236
# ☒ 239
# ---
# 검증 정확도 5.560%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 6 |  반복 21 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 6 |  반복 41 / 351 | 시간 2[s] | 손실 0.99
# | 에폭 6 |  반복 61 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 6 |  반복 81 / 351 | 시간 5[s] | 손실 0.97
# | 에폭 6 |  반복 101 / 351 | 시간 6[s] | 손실 0.97
# | 에폭 6 |  반복 121 / 351 | 시간 8[s] | 손실 0.95
# | 에폭 6 |  반복 141 / 351 | 시간 9[s] | 손실 0.94
# | 에폭 6 |  반복 161 / 351 | 시간 10[s] | 손실 0.94
# | 에폭 6 |  반복 181 / 351 | 시간 12[s] | 손실 0.94
# | 에폭 6 |  반복 201 / 351 | 시간 13[s] | 손실 0.92
# | 에폭 6 |  반복 221 / 351 | 시간 14[s] | 손실 0.92
# | 에폭 6 |  반복 241 / 351 | 시간 15[s] | 손실 0.91
# | 에폭 6 |  반복 261 / 351 | 시간 17[s] | 손실 0.90
# | 에폭 6 |  반복 281 / 351 | 시간 18[s] | 손실 0.91
# | 에폭 6 |  반복 301 / 351 | 시간 19[s] | 손실 0.91
# | 에폭 6 |  반복 321 / 351 | 시간 21[s] | 손실 0.90
# | 에폭 6 |  반복 341 / 351 | 시간 22[s] | 손실 0.89
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1144
# ---
# Q  48+285
# T 666
# ☒ 658
# ---
# Q   551+8
# T 163
# ☒ 164
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 860
# ---
# Q 292+167
# T 1053
# ☒ 1055
# ---
# Q 795+038
# T 1427
# ☒ 1404
# ---
# Q  838+62
# T 864
# ☒ 865
# ---
# Q  39+341
# T 236
# ☒ 239
# ---
# 검증 정확도 8.040%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 7 |  반복 21 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 7 |  반복 41 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 7 |  반복 61 / 351 | 시간 4[s] | 손실 0.86
# | 에폭 7 |  반복 81 / 351 | 시간 5[s] | 손실 0.85
# | 에폭 7 |  반복 101 / 351 | 시간 6[s] | 손실 0.85
# | 에폭 7 |  반복 121 / 351 | 시간 8[s] | 손실 0.85
# | 에폭 7 |  반복 141 / 351 | 시간 9[s] | 손실 0.84
# | 에폭 7 |  반복 161 / 351 | 시간 10[s] | 손실 0.84
# | 에폭 7 |  반복 181 / 351 | 시간 12[s] | 손실 0.83
# | 에폭 7 |  반복 201 / 351 | 시간 13[s] | 손실 0.82
# | 에폭 7 |  반복 221 / 351 | 시간 14[s] | 손실 0.81
# | 에폭 7 |  반복 241 / 351 | 시간 16[s] | 손실 0.81
# | 에폭 7 |  반복 261 / 351 | 시간 17[s] | 손실 0.80
# | 에폭 7 |  반복 281 / 351 | 시간 18[s] | 손실 0.81
# | 에폭 7 |  반복 301 / 351 | 시간 20[s] | 손실 0.81
# | 에폭 7 |  반복 321 / 351 | 시간 21[s] | 손실 0.79
# | 에폭 7 |  반복 341 / 351 | 시간 22[s] | 손실 0.80
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1146
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 860
# ---
# Q 292+167
# T 1053
# ☒ 1057
# ---
# Q 795+038
# T 1427
# ☒ 1430
# ---
# Q  838+62
# T 864
# ☒ 873
# ---
# Q  39+341
# T 236
# ☒ 232
# ---
# 검증 정확도 11.040%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.81
# | 에폭 8 |  반복 21 / 351 | 시간 1[s] | 손실 0.78
# | 에폭 8 |  반복 41 / 351 | 시간 2[s] | 손실 0.77
# | 에폭 8 |  반복 61 / 351 | 시간 3[s] | 손실 0.77
# | 에폭 8 |  반복 81 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 8 |  반복 101 / 351 | 시간 6[s] | 손실 0.76
# | 에폭 8 |  반복 121 / 351 | 시간 7[s] | 손실 0.76
# | 에폭 8 |  반복 141 / 351 | 시간 8[s] | 손실 0.74
# | 에폭 8 |  반복 161 / 351 | 시간 9[s] | 손실 0.75
# | 에폭 8 |  반복 181 / 351 | 시간 11[s] | 손실 0.75
# | 에폭 8 |  반복 201 / 351 | 시간 12[s] | 손실 0.74
# | 에폭 8 |  반복 221 / 351 | 시간 13[s] | 손실 0.74
# | 에폭 8 |  반복 241 / 351 | 시간 14[s] | 손실 0.73
# | 에폭 8 |  반복 261 / 351 | 시간 16[s] | 손실 0.71
# | 에폭 8 |  반복 281 / 351 | 시간 17[s] | 손실 0.72
# | 에폭 8 |  반복 301 / 351 | 시간 18[s] | 손실 0.72
# | 에폭 8 |  반복 321 / 351 | 시간 19[s] | 손실 0.71
# | 에폭 8 |  반복 341 / 351 | 시간 21[s] | 손실 0.72
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1144
# ---
# Q  48+285
# T 666
# ☒ 665
# ---
# Q   551+8
# T 163
# ☒ 160
# ---
# Q  55+763
# T 422
# ☒ 418
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☒ 1054
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☒ 858
# ---
# Q  39+341
# T 236
# ☒ 232
# ---
# 검증 정확도 13.140%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.70
# | 에폭 9 |  반복 21 / 351 | 시간 1[s] | 손실 0.73
# | 에폭 9 |  반복 41 / 351 | 시간 2[s] | 손실 0.71
# | 에폭 9 |  반복 61 / 351 | 시간 3[s] | 손실 0.71
# | 에폭 9 |  반복 81 / 351 | 시간 4[s] | 손실 0.69
# | 에폭 9 |  반복 101 / 351 | 시간 6[s] | 손실 0.69
# | 에폭 9 |  반복 121 / 351 | 시간 7[s] | 손실 0.68
# | 에폭 9 |  반복 141 / 351 | 시간 8[s] | 손실 0.69
# | 에폭 9 |  반복 161 / 351 | 시간 9[s] | 손실 0.69
# | 에폭 9 |  반복 181 / 351 | 시간 10[s] | 손실 0.67
# | 에폭 9 |  반복 201 / 351 | 시간 12[s] | 손실 0.67
# | 에폭 9 |  반복 221 / 351 | 시간 13[s] | 손실 0.68
# | 에폭 9 |  반복 241 / 351 | 시간 14[s] | 손실 0.67
# | 에폭 9 |  반복 261 / 351 | 시간 15[s] | 손실 0.67
# | 에폭 9 |  반복 281 / 351 | 시간 16[s] | 손실 0.67
# | 에폭 9 |  반복 301 / 351 | 시간 18[s] | 손실 0.65
# | 에폭 9 |  반복 321 / 351 | 시간 19[s] | 손실 0.64
# | 에폭 9 |  반복 341 / 351 | 시간 20[s] | 손실 0.65
# Q   58+77
# T 162
# ☒ 163
# ---
# Q 461+579
# T 1139
# ☒ 1143
# ---
# Q  48+285
# T 666
# ☒ 663
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☒ 856
# ---
# Q 292+167
# T 1053
# ☒ 1056
# ---
# Q 795+038
# T 1427
# ☒ 1434
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 15.540%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.63
# | 에폭 10 |  반복 21 / 351 | 시간 1[s] | 손실 0.64
# | 에폭 10 |  반복 41 / 351 | 시간 2[s] | 손실 0.64
# | 에폭 10 |  반복 61 / 351 | 시간 3[s] | 손실 0.66
# | 에폭 10 |  반복 81 / 351 | 시간 4[s] | 손실 0.69
# | 에폭 10 |  반복 101 / 351 | 시간 5[s] | 손실 0.65
# | 에폭 10 |  반복 121 / 351 | 시간 7[s] | 손실 0.64
# | 에폭 10 |  반복 141 / 351 | 시간 8[s] | 손실 0.62
# | 에폭 10 |  반복 161 / 351 | 시간 9[s] | 손실 0.61
# | 에폭 10 |  반복 181 / 351 | 시간 10[s] | 손실 0.62
# | 에폭 10 |  반복 201 / 351 | 시간 11[s] | 손실 0.62
# | 에폭 10 |  반복 221 / 351 | 시간 12[s] | 손실 0.62
# | 에폭 10 |  반복 241 / 351 | 시간 14[s] | 손실 0.62
# | 에폭 10 |  반복 261 / 351 | 시간 15[s] | 손실 0.61
# | 에폭 10 |  반복 281 / 351 | 시간 16[s] | 손실 0.61
# | 에폭 10 |  반복 301 / 351 | 시간 17[s] | 손실 0.61
# | 에폭 10 |  반복 321 / 351 | 시간 18[s] | 손실 0.60
# | 에폭 10 |  반복 341 / 351 | 시간 20[s] | 손실 0.60
# Q   58+77
# T 162
# ☒ 158
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 856
# ---
# Q 292+167
# T 1053
# ☒ 1055
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 866
# ---
# Q  39+341
# T 236
# ☒ 232
# ---
# 검증 정확도 17.640%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.63
# | 에폭 11 |  반복 21 / 351 | 시간 1[s] | 손실 0.60
# | 에폭 11 |  반복 41 / 351 | 시간 2[s] | 손실 0.60
# | 에폭 11 |  반복 61 / 351 | 시간 3[s] | 손실 0.60
# | 에폭 11 |  반복 81 / 351 | 시간 5[s] | 손실 0.59
# | 에폭 11 |  반복 101 / 351 | 시간 6[s] | 손실 0.59
# | 에폭 11 |  반복 121 / 351 | 시간 7[s] | 손실 0.58
# | 에폭 11 |  반복 141 / 351 | 시간 9[s] | 손실 0.58
# | 에폭 11 |  반복 161 / 351 | 시간 10[s] | 손실 0.58
# | 에폭 11 |  반복 181 / 351 | 시간 11[s] | 손실 0.60
# | 에폭 11 |  반복 201 / 351 | 시간 12[s] | 손실 0.60
# | 에폭 11 |  반복 221 / 351 | 시간 14[s] | 손실 0.59
# | 에폭 11 |  반복 241 / 351 | 시간 15[s] | 손실 0.59
# | 에폭 11 |  반복 261 / 351 | 시간 16[s] | 손실 0.57
# | 에폭 11 |  반복 281 / 351 | 시간 18[s] | 손실 0.56
# | 에폭 11 |  반복 301 / 351 | 시간 19[s] | 손실 0.56
# | 에폭 11 |  반복 321 / 351 | 시간 20[s] | 손실 0.56
# | 에폭 11 |  반복 341 / 351 | 시간 21[s] | 손실 0.56
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1137
# ---
# Q  48+285
# T 666
# ☒ 665
# ---
# Q   551+8
# T 163
# ☒ 164
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☒ 1055
# ---
# Q 795+038
# T 1427
# ☒ 1431
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☒ 234
# ---
# 검증 정확도 22.960%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.54
# | 에폭 12 |  반복 21 / 351 | 시간 1[s] | 손실 0.56
# | 에폭 12 |  반복 41 / 351 | 시간 2[s] | 손실 0.57
# | 에폭 12 |  반복 61 / 351 | 시간 3[s] | 손실 0.57
# | 에폭 12 |  반복 81 / 351 | 시간 5[s] | 손실 0.55
# | 에폭 12 |  반복 101 / 351 | 시간 6[s] | 손실 0.55
# | 에폭 12 |  반복 121 / 351 | 시간 7[s] | 손실 0.55
# | 에폭 12 |  반복 141 / 351 | 시간 9[s] | 손실 0.55
# | 에폭 12 |  반복 161 / 351 | 시간 10[s] | 손실 0.55
# | 에폭 12 |  반복 181 / 351 | 시간 11[s] | 손실 0.55
# | 에폭 12 |  반복 201 / 351 | 시간 12[s] | 손실 0.54
# | 에폭 12 |  반복 221 / 351 | 시간 14[s] | 손실 0.54
# | 에폭 12 |  반복 241 / 351 | 시간 15[s] | 손실 0.54
# | 에폭 12 |  반복 261 / 351 | 시간 16[s] | 손실 0.53
# | 에폭 12 |  반복 281 / 351 | 시간 17[s] | 손실 0.54
# | 에폭 12 |  반복 301 / 351 | 시간 19[s] | 손실 0.53
# | 에폭 12 |  반복 321 / 351 | 시간 20[s] | 손실 0.52
# | 에폭 12 |  반복 341 / 351 | 시간 21[s] | 손실 0.54
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1137
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☒ 1055
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 866
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 23.860%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.53
# | 에폭 13 |  반복 21 / 351 | 시간 1[s] | 손실 0.53
# | 에폭 13 |  반복 41 / 351 | 시간 2[s] | 손실 0.53
# | 에폭 13 |  반복 61 / 351 | 시간 4[s] | 손실 0.53
# | 에폭 13 |  반복 81 / 351 | 시간 5[s] | 손실 0.52
# | 에폭 13 |  반복 101 / 351 | 시간 6[s] | 손실 0.52
# | 에폭 13 |  반복 121 / 351 | 시간 7[s] | 손실 0.52
# | 에폭 13 |  반복 141 / 351 | 시간 8[s] | 손실 0.52
# | 에폭 13 |  반복 161 / 351 | 시간 10[s] | 손실 0.51
# | 에폭 13 |  반복 181 / 351 | 시간 12[s] | 손실 0.52
# | 에폭 13 |  반복 201 / 351 | 시간 13[s] | 손실 0.52
# | 에폭 13 |  반복 221 / 351 | 시간 14[s] | 손실 0.52
# | 에폭 13 |  반복 241 / 351 | 시간 16[s] | 손실 0.52
# | 에폭 13 |  반복 261 / 351 | 시간 17[s] | 손실 0.52
# | 에폭 13 |  반복 281 / 351 | 시간 18[s] | 손실 0.51
# | 에폭 13 |  반복 301 / 351 | 시간 20[s] | 손실 0.50
# | 에폭 13 |  반복 321 / 351 | 시간 21[s] | 손실 0.50
# | 에폭 13 |  반복 341 / 351 | 시간 22[s] | 손실 0.49
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1136
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☒ 160
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 852
# ---
# Q 292+167
# T 1053
# ☒ 1051
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☒ 861
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 26.040%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.48
# | 에폭 14 |  반복 21 / 351 | 시간 1[s] | 손실 0.50
# | 에폭 14 |  반복 41 / 351 | 시간 3[s] | 손실 0.49
# | 에폭 14 |  반복 61 / 351 | 시간 4[s] | 손실 0.50
# | 에폭 14 |  반복 81 / 351 | 시간 6[s] | 손실 0.50
# | 에폭 14 |  반복 101 / 351 | 시간 7[s] | 손실 0.51
# | 에폭 14 |  반복 121 / 351 | 시간 9[s] | 손실 0.49
# | 에폭 14 |  반복 141 / 351 | 시간 10[s] | 손실 0.49
# | 에폭 14 |  반복 161 / 351 | 시간 11[s] | 손실 0.49
# | 에폭 14 |  반복 181 / 351 | 시간 13[s] | 손실 0.49
# | 에폭 14 |  반복 201 / 351 | 시간 14[s] | 손실 0.49
# | 에폭 14 |  반복 221 / 351 | 시간 15[s] | 손실 0.48
# | 에폭 14 |  반복 241 / 351 | 시간 17[s] | 손실 0.48
# | 에폭 14 |  반복 261 / 351 | 시간 18[s] | 손실 0.51
# | 에폭 14 |  반복 281 / 351 | 시간 19[s] | 손실 0.50
# | 에폭 14 |  반복 301 / 351 | 시간 21[s] | 손실 0.49
# | 에폭 14 |  반복 321 / 351 | 시간 22[s] | 손실 0.48
# | 에폭 14 |  반복 341 / 351 | 시간 23[s] | 손실 0.47
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☒ 668
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☒ 1051
# ---
# Q 795+038
# T 1427
# ☒ 1426
# ---
# Q  838+62
# T 864
# ☒ 866
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 28.000%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.48
# | 에폭 15 |  반복 21 / 351 | 시간 1[s] | 손실 0.47
# | 에폭 15 |  반복 41 / 351 | 시간 2[s] | 손실 0.48
# | 에폭 15 |  반복 61 / 351 | 시간 4[s] | 손실 0.50
# | 에폭 15 |  반복 81 / 351 | 시간 5[s] | 손실 0.54
# | 에폭 15 |  반복 101 / 351 | 시간 6[s] | 손실 0.49
# | 에폭 15 |  반복 121 / 351 | 시간 8[s] | 손실 0.48
# | 에폭 15 |  반복 141 / 351 | 시간 9[s] | 손실 0.48
# | 에폭 15 |  반복 161 / 351 | 시간 10[s] | 손실 0.47
# | 에폭 15 |  반복 181 / 351 | 시간 12[s] | 손실 0.47
# | 에폭 15 |  반복 201 / 351 | 시간 13[s] | 손실 0.46
# | 에폭 15 |  반복 221 / 351 | 시간 14[s] | 손실 0.47
# | 에폭 15 |  반복 241 / 351 | 시간 16[s] | 손실 0.47
# | 에폭 15 |  반복 261 / 351 | 시간 17[s] | 손실 0.48
# | 에폭 15 |  반복 281 / 351 | 시간 18[s] | 손실 0.49
# | 에폭 15 |  반복 301 / 351 | 시간 19[s] | 손실 0.47
# | 에폭 15 |  반복 321 / 351 | 시간 21[s] | 손실 0.45
# | 에폭 15 |  반복 341 / 351 | 시간 22[s] | 손실 0.45
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 856
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 31.840%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 16 |  반복 21 / 351 | 시간 1[s] | 손실 0.45
# | 에폭 16 |  반복 41 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 16 |  반복 61 / 351 | 시간 3[s] | 손실 0.45
# | 에폭 16 |  반복 81 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 16 |  반복 101 / 351 | 시간 6[s] | 손실 0.45
# | 에폭 16 |  반복 121 / 351 | 시간 8[s] | 손실 0.44
# | 에폭 16 |  반복 141 / 351 | 시간 9[s] | 손실 0.44
# | 에폭 16 |  반복 161 / 351 | 시간 10[s] | 손실 0.44
# | 에폭 16 |  반복 181 / 351 | 시간 11[s] | 손실 0.44
# | 에폭 16 |  반복 201 / 351 | 시간 13[s] | 손실 0.45
# | 에폭 16 |  반복 221 / 351 | 시간 14[s] | 손실 0.45
# | 에폭 16 |  반복 241 / 351 | 시간 15[s] | 손실 0.45
# | 에폭 16 |  반복 261 / 351 | 시간 16[s] | 손실 0.45
# | 에폭 16 |  반복 281 / 351 | 시간 17[s] | 손실 0.44
# | 에폭 16 |  반복 301 / 351 | 시간 19[s] | 손실 0.45
# | 에폭 16 |  반복 321 / 351 | 시간 20[s] | 손실 0.44
# | 에폭 16 |  반복 341 / 351 | 시간 21[s] | 손실 0.45
# Q   58+77
# T 162
# ☒ 159
# ---
# Q 461+579
# T 1139
# ☒ 1136
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☒ 160
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☒ 1051
# ---
# Q 795+038
# T 1427
# ☒ 1426
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☒ 238
# ---
# 검증 정확도 30.320%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.43
# | 에폭 17 |  반복 21 / 351 | 시간 1[s] | 손실 0.44
# | 에폭 17 |  반복 41 / 351 | 시간 2[s] | 손실 0.44
# | 에폭 17 |  반복 61 / 351 | 시간 4[s] | 손실 0.45
# | 에폭 17 |  반복 81 / 351 | 시간 5[s] | 손실 0.42
# | 에폭 17 |  반복 101 / 351 | 시간 6[s] | 손실 0.43
# | 에폭 17 |  반복 121 / 351 | 시간 8[s] | 손실 0.44
# | 에폭 17 |  반복 141 / 351 | 시간 9[s] | 손실 0.44
# | 에폭 17 |  반복 161 / 351 | 시간 10[s] | 손실 0.44
# | 에폭 17 |  반복 181 / 351 | 시간 11[s] | 손실 0.45
# | 에폭 17 |  반복 201 / 351 | 시간 13[s] | 손실 0.43
# | 에폭 17 |  반복 221 / 351 | 시간 14[s] | 손실 0.43
# | 에폭 17 |  반복 241 / 351 | 시간 16[s] | 손실 0.44
# | 에폭 17 |  반복 261 / 351 | 시간 17[s] | 손실 0.44
# | 에폭 17 |  반복 281 / 351 | 시간 19[s] | 손실 0.44
# | 에폭 17 |  반복 301 / 351 | 시간 20[s] | 손실 0.44
# | 에폭 17 |  반복 321 / 351 | 시간 21[s] | 손실 0.43
# | 에폭 17 |  반복 341 / 351 | 시간 23[s] | 손실 0.42
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1137
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☒ 164
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☒ 1051
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☒ 235
# ---
# 검증 정확도 31.020%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.40
# | 에폭 18 |  반복 21 / 351 | 시간 2[s] | 손실 0.42
# | 에폭 18 |  반복 41 / 351 | 시간 4[s] | 손실 0.42
# | 에폭 18 |  반복 61 / 351 | 시간 6[s] | 손실 0.42
# | 에폭 18 |  반복 81 / 351 | 시간 8[s] | 손실 0.41
# | 에폭 18 |  반복 101 / 351 | 시간 10[s] | 손실 0.42
# | 에폭 18 |  반복 121 / 351 | 시간 11[s] | 손실 0.42
# | 에폭 18 |  반복 141 / 351 | 시간 13[s] | 손실 0.43
# | 에폭 18 |  반복 161 / 351 | 시간 15[s] | 손실 0.43
# | 에폭 18 |  반복 181 / 351 | 시간 17[s] | 손실 0.42
# | 에폭 18 |  반복 201 / 351 | 시간 19[s] | 손실 0.42
# | 에폭 18 |  반복 221 / 351 | 시간 20[s] | 손실 0.42
# | 에폭 18 |  반복 241 / 351 | 시간 21[s] | 손실 0.43
# | 에폭 18 |  반복 261 / 351 | 시간 23[s] | 손실 0.42
# | 에폭 18 |  반복 281 / 351 | 시간 24[s] | 손실 0.41
# | 에폭 18 |  반복 301 / 351 | 시간 25[s] | 손실 0.42
# | 에폭 18 |  반복 321 / 351 | 시간 26[s] | 손실 0.42
# | 에폭 18 |  반복 341 / 351 | 시간 27[s] | 손실 0.41
# Q   58+77
# T 162
# ☒ 163
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1430
# ---
# Q  838+62
# T 864
# ☒ 863
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 37.580%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 19 |  반복 21 / 351 | 시간 1[s] | 손실 0.40
# | 에폭 19 |  반복 41 / 351 | 시간 11[s] | 손실 0.42
# | 에폭 19 |  반복 61 / 351 | 시간 19[s] | 손실 0.41
# | 에폭 19 |  반복 81 / 351 | 시간 20[s] | 손실 0.41
# | 에폭 19 |  반복 101 / 351 | 시간 23[s] | 손실 0.41
# | 에폭 19 |  반복 121 / 351 | 시간 26[s] | 손실 0.41
# | 에폭 19 |  반복 141 / 351 | 시간 28[s] | 손실 0.41
# | 에폭 19 |  반복 161 / 351 | 시간 29[s] | 손실 0.40
# | 에폭 19 |  반복 181 / 351 | 시간 30[s] | 손실 0.40
# | 에폭 19 |  반복 201 / 351 | 시간 32[s] | 손실 0.40
# | 에폭 19 |  반복 221 / 351 | 시간 33[s] | 손실 0.40
# | 에폭 19 |  반복 241 / 351 | 시간 34[s] | 손실 0.41
# | 에폭 19 |  반복 261 / 351 | 시간 36[s] | 손실 0.42
# | 에폭 19 |  반복 281 / 351 | 시간 37[s] | 손실 0.42
# | 에폭 19 |  반복 301 / 351 | 시간 38[s] | 손실 0.43
# | 에폭 19 |  반복 321 / 351 | 시간 39[s] | 손실 0.40
# | 에폭 19 |  반복 341 / 351 | 시간 40[s] | 손실 0.41
# Q   58+77
# T 162
# ☒ 164
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☒ 1051
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 866
# ---
# Q  39+341
# T 236
# ☒ 235
# ---
# 검증 정확도 37.380%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.39
# | 에폭 20 |  반복 21 / 351 | 시간 1[s] | 손실 0.40
# | 에폭 20 |  반복 41 / 351 | 시간 2[s] | 손실 0.40
# | 에폭 20 |  반복 61 / 351 | 시간 3[s] | 손실 0.39
# | 에폭 20 |  반복 81 / 351 | 시간 4[s] | 손실 0.40
# | 에폭 20 |  반복 101 / 351 | 시간 5[s] | 손실 0.40
# | 에폭 20 |  반복 121 / 351 | 시간 6[s] | 손실 0.39
# | 에폭 20 |  반복 141 / 351 | 시간 8[s] | 손실 0.39
# | 에폭 20 |  반복 161 / 351 | 시간 9[s] | 손실 0.39
# | 에폭 20 |  반복 181 / 351 | 시간 21[s] | 손실 0.39
# | 에폭 20 |  반복 201 / 351 | 시간 25[s] | 손실 0.40
# | 에폭 20 |  반복 221 / 351 | 시간 32[s] | 손실 0.39
# | 에폭 20 |  반복 241 / 351 | 시간 40[s] | 손실 0.40
# | 에폭 20 |  반복 261 / 351 | 시간 41[s] | 손실 0.39
# | 에폭 20 |  반복 281 / 351 | 시간 45[s] | 손실 0.39
# | 에폭 20 |  반복 301 / 351 | 시간 46[s] | 손실 0.38
# | 에폭 20 |  반복 321 / 351 | 시간 50[s] | 손실 0.38
# | 에폭 20 |  반복 341 / 351 | 시간 51[s] | 손실 0.37
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 856
# ---
# Q 292+167
# T 1053
# ☒ 1051
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☒ 235
# ---
# 검증 정확도 40.380%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.37
# | 에폭 21 |  반복 21 / 351 | 시간 1[s] | 손실 0.39
# | 에폭 21 |  반복 41 / 351 | 시간 3[s] | 손실 0.38
# | 에폭 21 |  반복 61 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 21 |  반복 81 / 351 | 시간 5[s] | 손실 0.37
# | 에폭 21 |  반복 101 / 351 | 시간 7[s] | 손실 0.38
# | 에폭 21 |  반복 121 / 351 | 시간 8[s] | 손실 0.38
# | 에폭 21 |  반복 141 / 351 | 시간 9[s] | 손실 0.38
# | 에폭 21 |  반복 161 / 351 | 시간 11[s] | 손실 0.38
# | 에폭 21 |  반복 181 / 351 | 시간 12[s] | 손실 0.39
# | 에폭 21 |  반복 201 / 351 | 시간 13[s] | 손실 0.42
# | 에폭 21 |  반복 221 / 351 | 시간 14[s] | 손실 0.39
# | 에폭 21 |  반복 241 / 351 | 시간 17[s] | 손실 0.38
# | 에폭 21 |  반복 261 / 351 | 시간 19[s] | 손실 0.38
# | 에폭 21 |  반복 281 / 351 | 시간 22[s] | 손실 0.38
# | 에폭 21 |  반복 301 / 351 | 시간 30[s] | 손실 0.38
# | 에폭 21 |  반복 321 / 351 | 시간 38[s] | 손실 0.38
# | 에폭 21 |  반복 341 / 351 | 시간 44[s] | 손실 0.38
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 856
# ---
# Q 292+167
# T 1053
# ☒ 1051
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 866
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 40.320%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.37
# | 에폭 22 |  반복 21 / 351 | 시간 1[s] | 손실 0.37
# | 에폭 22 |  반복 41 / 351 | 시간 2[s] | 손실 0.38
# | 에폭 22 |  반복 61 / 351 | 시간 4[s] | 손실 0.36
# | 에폭 22 |  반복 81 / 351 | 시간 5[s] | 손실 0.37
# | 에폭 22 |  반복 101 / 351 | 시간 7[s] | 손실 0.37
# | 에폭 22 |  반복 121 / 351 | 시간 15[s] | 손실 0.37
# | 에폭 22 |  반복 141 / 351 | 시간 19[s] | 손실 0.38
# | 에폭 22 |  반복 161 / 351 | 시간 23[s] | 손실 0.37
# | 에폭 22 |  반복 181 / 351 | 시간 24[s] | 손실 0.37
# | 에폭 22 |  반복 201 / 351 | 시간 26[s] | 손실 0.37
# | 에폭 22 |  반복 221 / 351 | 시간 28[s] | 손실 0.36
# | 에폭 22 |  반복 241 / 351 | 시간 29[s] | 손실 0.37
# | 에폭 22 |  반복 261 / 351 | 시간 30[s] | 손실 0.38
# | 에폭 22 |  반복 281 / 351 | 시간 32[s] | 손실 0.37
# | 에폭 22 |  반복 301 / 351 | 시간 33[s] | 손실 0.39
# | 에폭 22 |  반복 321 / 351 | 시간 34[s] | 손실 0.37
# | 에폭 22 |  반복 341 / 351 | 시간 35[s] | 손실 0.37
# Q   58+77
# T 162
# ☒ 161
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 42.200%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 23 |  반복 21 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 23 |  반복 41 / 351 | 시간 2[s] | 손실 0.36
# | 에폭 23 |  반복 61 / 351 | 시간 4[s] | 손실 0.36
# | 에폭 23 |  반복 81 / 351 | 시간 5[s] | 손실 0.39
# | 에폭 23 |  반복 101 / 351 | 시간 7[s] | 손실 0.38
# | 에폭 23 |  반복 121 / 351 | 시간 8[s] | 손실 0.36
# | 에폭 23 |  반복 141 / 351 | 시간 10[s] | 손실 0.36
# | 에폭 23 |  반복 161 / 351 | 시간 11[s] | 손실 0.35
# | 에폭 23 |  반복 181 / 351 | 시간 13[s] | 손실 0.37
# | 에폭 23 |  반복 201 / 351 | 시간 14[s] | 손실 0.39
# | 에폭 23 |  반복 221 / 351 | 시간 16[s] | 손실 0.36
# | 에폭 23 |  반복 241 / 351 | 시간 25[s] | 손실 0.35
# | 에폭 23 |  반복 261 / 351 | 시간 27[s] | 손실 0.36
# | 에폭 23 |  반복 281 / 351 | 시간 29[s] | 손실 0.36
# | 에폭 23 |  반복 301 / 351 | 시간 33[s] | 손실 0.37
# | 에폭 23 |  반복 321 / 351 | 시간 35[s] | 손실 0.37
# | 에폭 23 |  반복 341 / 351 | 시간 37[s] | 손실 0.36
# Q   58+77
# T 162
# ☒ 163
# ---
# Q 461+579
# T 1139
# ☒ 1138
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☒ 164
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 858
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☒ 866
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 44.040%
# | 에폭 24 |  반복 1 / 351 | 시간 1[s] | 손실 0.34
# | 에폭 24 |  반복 21 / 351 | 시간 14[s] | 손실 0.35
# | 에폭 24 |  반복 41 / 351 | 시간 19[s] | 손실 0.37
# | 에폭 24 |  반복 61 / 351 | 시간 20[s] | 손실 0.37
# | 에폭 24 |  반복 81 / 351 | 시간 21[s] | 손실 0.37
# | 에폭 24 |  반복 101 / 351 | 시간 22[s] | 손실 0.35
# | 에폭 24 |  반복 121 / 351 | 시간 24[s] | 손실 0.36
# | 에폭 24 |  반복 141 / 351 | 시간 25[s] | 손실 0.35
# | 에폭 24 |  반복 161 / 351 | 시간 27[s] | 손실 0.34
# | 에폭 24 |  반복 181 / 351 | 시간 32[s] | 손실 0.35
# | 에폭 24 |  반복 201 / 351 | 시간 44[s] | 손실 0.36
# | 에폭 24 |  반복 221 / 351 | 시간 45[s] | 손실 0.35
# | 에폭 24 |  반복 241 / 351 | 시간 47[s] | 손실 0.37
# | 에폭 24 |  반복 261 / 351 | 시간 49[s] | 손실 0.40
# | 에폭 24 |  반복 281 / 351 | 시간 50[s] | 손실 0.35
# | 에폭 24 |  반복 301 / 351 | 시간 57[s] | 손실 0.34
# | 에폭 24 |  반복 321 / 351 | 시간 58[s] | 손실 0.34
# | 에폭 24 |  반복 341 / 351 | 시간 60[s] | 손실 0.34
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1136
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 855
# ---
# Q 292+167
# T 1053
# ☒ 1050
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☒ 865
# ---
# Q  39+341
# T 236
# ☒ 238
# ---
# 검증 정확도 41.120%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.33
# | 에폭 25 |  반복 21 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 25 |  반복 41 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 25 |  반복 61 / 351 | 시간 8[s] | 손실 0.34
# | 에폭 25 |  반복 81 / 351 | 시간 9[s] | 손실 0.35
# | 에폭 25 |  반복 101 / 351 | 시간 11[s] | 손실 0.35
# | 에폭 25 |  반복 121 / 351 | 시간 12[s] | 손실 0.36
# | 에폭 25 |  반복 141 / 351 | 시간 14[s] | 손실 0.35
# | 에폭 25 |  반복 161 / 351 | 시간 15[s] | 손실 0.35
# | 에폭 25 |  반복 181 / 351 | 시간 18[s] | 손실 0.35
# | 에폭 25 |  반복 201 / 351 | 시간 19[s] | 손실 0.34
# | 에폭 25 |  반복 221 / 351 | 시간 21[s] | 손실 0.34
# | 에폭 25 |  반복 241 / 351 | 시간 28[s] | 손실 0.35
# | 에폭 25 |  반복 261 / 351 | 시간 29[s] | 손실 0.36
# | 에폭 25 |  반복 281 / 351 | 시간 31[s] | 손실 0.35
# | 에폭 25 |  반복 301 / 351 | 시간 33[s] | 손실 0.34
# | 에폭 25 |  반복 321 / 351 | 시간 34[s] | 손실 0.34
# | 에폭 25 |  반복 341 / 351 | 시간 36[s] | 손실 0.34
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1138
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 856
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 44.400%

# %%
plt.plot(np.arange(1,max_epoch+1), acc_list, marker='o', color='blue')
plt.plot(np.arange(1,max_epoch+1), reversed_acc_list, marker='o', color='red')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()

# %% [markdown]
# 엿보기(Peeky)

# %%
class PeekyDecoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(H+D, 4*H) / np.sqrt(H+D)).astype('f') ## Encoder가 인코딩한 벡터도 입력으로 주어지기 때문에 H 차원 증가
        lstm_Wh = (rn(H, 4*H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4*H).astype('f')
        affine_W = (rn(H+H,V) / np.sqrt(H+H)).astype('f') ## Encoder가 인코딩한 벡터도 입력으로 주어지기 때문에 H 차원 증가
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)
        
        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads
        self.cache = None
    
    def forward(self, xs, h):
        N, T = xs.shape
        N, H = h.shape

        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        ## repeat를 수행하면 hs: (N,H) -> (N*T,H)
        hs = np.repeat(h, T, axis=0).reshape(N, T, H)
        out = np.concatenate((hs, out), axis=2) ## -> (N, T, H+D)

        out = self.lstm.forward(out) ## Encoder의 hidden state를 lstm 계층에 전달, (N, T, H)
        out = np.concatenate((hs, out), axis=2) ## -> (N, T, 2*H)

        score = self.affine.forward(out) ## Encoder의 hidden state affine 계층에 전달, (N, T, V)
        self.cache = H
        return score
    
    def backward(self, dscore):
        H = self.cache

        ## Affine 계층 역전파
        dout = self.affine.backward(dscore) ## (N, T, V) -> (N, T, 2*H)
        dout, dhs0 = dout[:, :, H:], dout[:, :, :H] ## LSTM / h -> (N, T, H), forward에서 (hs, out)을 concat 했으므로
        ## LSTM 계층 역전파
        dout = self.lstm.backward(dout) ## (N, T, H) -> (N, T, H+D)
        dembed, dhs1 = dout[:, :, H:], dout[:, :, :H] ## (N, T, D), (N, T, H)
        self.embed.backward(dembed) ## (N, T, D)

        dhs = dhs0 + dhs1 ## (N, T, H)
        ## repeat 노드의 미분은 합으로 계산
        dh = self.lstm.dh + np.sum(dhs, axis=1) ## (N, H) + (N, H)
        return dh ## (N, H)
    
    def generate(self, h, start_id, sample_size):
        sampled = [] 
        char_id = start_id
        self.lstm.set_state(h) ## hidden state 전달 받기

        H = h.shape[1] ## h: (1, H)
        peeky_h = h.reshape(1,1,H)
        for _ in range(sample_size):
            x = np.array([char_id]).reshape((1,1))
            out = self.embed.forward(x)

            out = np.concatenate((peeky_h, out), axis=2) ## hidden state를 LSTM 계층에 추가
            out = self.lstm.forward(out)
            out = np.concatenate((peeky_h, out), axis=2) ## hidden state를 Affine 계층에 추가
            score = self.affine.forward(out)

            char_id = np.argmax(score.flatten()) ## score.flatten -> (H,)
            sampled.append(char_id)

        return sampled

# %%
class PeekySeq2seq(Seq2seq):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = PeekyDecoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

# %%
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
char_to_id, id_to_char = sequence.get_vocab()

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

peeky_acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    peeky_acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.61
# | 에폭 1 |  반복 21 / 351 | 시간 2[s] | 손실 2.26
# | 에폭 1 |  반복 41 / 351 | 시간 6[s] | 손실 1.98
# | 에폭 1 |  반복 61 / 351 | 시간 7[s] | 손실 1.93
# | 에폭 1 |  반복 81 / 351 | 시간 8[s] | 손실 1.88
# | 에폭 1 |  반복 101 / 351 | 시간 10[s] | 손실 1.82
# | 에폭 1 |  반복 121 / 351 | 시간 11[s] | 손실 1.80
# | 에폭 1 |  반복 141 / 351 | 시간 12[s] | 손실 1.78
# | 에폭 1 |  반복 161 / 351 | 시간 14[s] | 손실 1.78
# | 에폭 1 |  반복 181 / 351 | 시간 15[s] | 손실 1.77
# | 에폭 1 |  반복 201 / 351 | 시간 17[s] | 손실 1.76
# | 에폭 1 |  반복 221 / 351 | 시간 18[s] | 손실 1.75
# | 에폭 1 |  반복 241 / 351 | 시간 19[s] | 손실 1.75
# | 에폭 1 |  반복 261 / 351 | 시간 20[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 22[s] | 손실 1.74
# | 에폭 1 |  반복 301 / 351 | 시간 24[s] | 손실 1.72
# | 에폭 1 |  반복 321 / 351 | 시간 25[s] | 손실 1.72
# | 에폭 1 |  반복 341 / 351 | 시간 26[s] | 손실 1.71
# Q   58+77
# T 162
# ☒ 107
# ---
# Q 461+579
# T 1139
# ☒ 1111
# ---
# Q  48+285
# T 666
# ☒ 105
# ---
# Q   551+8
# T 163
# ☒ 101
# ---
# Q  55+763
# T 422
# ☒ 105
# ---
# Q 752+006
# T 857
# ☒ 1011
# ---
# Q 292+167
# T 1053
# ☒ 1011
# ---
# Q 795+038
# T 1427
# ☒ 1111
# ---
# Q  838+62
# T 864
# ☒ 102
# ---
# Q  39+341
# T 236
# ☒ 447
# ---
# 검증 정확도 0.300%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.69
# | 에폭 2 |  반복 21 / 351 | 시간 1[s] | 손실 1.69
# | 에폭 2 |  반복 41 / 351 | 시간 2[s] | 손실 1.68
# | 에폭 2 |  반복 61 / 351 | 시간 3[s] | 손실 1.68
# | 에폭 2 |  반복 81 / 351 | 시간 4[s] | 손실 1.66
# | 에폭 2 |  반복 101 / 351 | 시간 6[s] | 손실 1.65
# | 에폭 2 |  반복 121 / 351 | 시간 7[s] | 손실 1.64
# | 에폭 2 |  반복 141 / 351 | 시간 8[s] | 손실 1.63
# | 에폭 2 |  반복 161 / 351 | 시간 10[s] | 손실 1.61
# | 에폭 2 |  반복 181 / 351 | 시간 11[s] | 손실 1.60
# | 에폭 2 |  반복 201 / 351 | 시간 12[s] | 손실 1.58
# | 에폭 2 |  반복 221 / 351 | 시간 14[s] | 손실 1.56
# | 에폭 2 |  반복 241 / 351 | 시간 15[s] | 손실 1.54
# | 에폭 2 |  반복 261 / 351 | 시간 16[s] | 손실 1.52
# | 에폭 2 |  반복 281 / 351 | 시간 18[s] | 손실 1.50
# | 에폭 2 |  반복 301 / 351 | 시간 19[s] | 손실 1.48
# | 에폭 2 |  반복 321 / 351 | 시간 21[s] | 손실 1.45
# | 에폭 2 |  반복 341 / 351 | 시간 22[s] | 손실 1.43
# Q   58+77
# T 162
# ☒ 177
# ---
# Q 461+579
# T 1139
# ☒ 1025
# ---
# Q  48+285
# T 666
# ☒ 695
# ---
# Q   551+8
# T 163
# ☒ 111
# ---
# Q  55+763
# T 422
# ☒ 371
# ---
# Q 752+006
# T 857
# ☒ 717
# ---
# Q 292+167
# T 1053
# ☒ 1022
# ---
# Q 795+038
# T 1427
# ☒ 1435
# ---
# Q  838+62
# T 864
# ☒ 892
# ---
# Q  39+341
# T 236
# ☒ 211
# ---
# 검증 정확도 0.920%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.40
# | 에폭 3 |  반복 21 / 351 | 시간 1[s] | 손실 1.40
# | 에폭 3 |  반복 41 / 351 | 시간 2[s] | 손실 1.38
# | 에폭 3 |  반복 61 / 351 | 시간 4[s] | 손실 1.36
# | 에폭 3 |  반복 81 / 351 | 시간 5[s] | 손실 1.35
# | 에폭 3 |  반복 101 / 351 | 시간 7[s] | 손실 1.33
# | 에폭 3 |  반복 121 / 351 | 시간 8[s] | 손실 1.31
# | 에폭 3 |  반복 141 / 351 | 시간 10[s] | 손실 1.29
# | 에폭 3 |  반복 161 / 351 | 시간 11[s] | 손실 1.29
# | 에폭 3 |  반복 181 / 351 | 시간 13[s] | 손실 1.27
# | 에폭 3 |  반복 201 / 351 | 시간 14[s] | 손실 1.24
# | 에폭 3 |  반복 221 / 351 | 시간 16[s] | 손실 1.23
# | 에폭 3 |  반복 241 / 351 | 시간 17[s] | 손실 1.21
# | 에폭 3 |  반복 261 / 351 | 시간 18[s] | 손실 1.20
# | 에폭 3 |  반복 281 / 351 | 시간 20[s] | 손실 1.18
# | 에폭 3 |  반복 301 / 351 | 시간 21[s] | 손실 1.17
# | 에폭 3 |  반복 321 / 351 | 시간 22[s] | 손실 1.15
# | 에폭 3 |  반복 341 / 351 | 시간 24[s] | 손실 1.13
# Q   58+77
# T 162
# ☒ 154
# ---
# Q 461+579
# T 1139
# ☒ 1037
# ---
# Q  48+285
# T 666
# ☒ 665
# ---
# Q   551+8
# T 163
# ☒ 156
# ---
# Q  55+763
# T 422
# ☒ 403
# ---
# Q 752+006
# T 857
# ☒ 877
# ---
# Q 292+167
# T 1053
# ☒ 1033
# ---
# Q 795+038
# T 1427
# ☒ 1443
# ---
# Q  838+62
# T 864
# ☒ 858
# ---
# Q  39+341
# T 236
# ☒ 215
# ---
# 검증 정확도 3.260%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.09
# | 에폭 4 |  반복 21 / 351 | 시간 1[s] | 손실 1.10
# | 에폭 4 |  반복 41 / 351 | 시간 3[s] | 손실 1.09
# | 에폭 4 |  반복 61 / 351 | 시간 4[s] | 손실 1.07
# | 에폭 4 |  반복 81 / 351 | 시간 5[s] | 손실 1.05
# | 에폭 4 |  반복 101 / 351 | 시간 7[s] | 손실 1.03
# | 에폭 4 |  반복 121 / 351 | 시간 8[s] | 손실 1.01
# | 에폭 4 |  반복 141 / 351 | 시간 9[s] | 손실 1.01
# | 에폭 4 |  반복 161 / 351 | 시간 11[s] | 손실 0.98
# | 에폭 4 |  반복 181 / 351 | 시간 13[s] | 손실 0.97
# | 에폭 4 |  반복 201 / 351 | 시간 15[s] | 손실 0.96
# | 에폭 4 |  반복 221 / 351 | 시간 17[s] | 손실 0.94
# | 에폭 4 |  반복 241 / 351 | 시간 19[s] | 손실 0.93
# | 에폭 4 |  반복 261 / 351 | 시간 22[s] | 손실 0.90
# | 에폭 4 |  반복 281 / 351 | 시간 24[s] | 손실 0.90
# | 에폭 4 |  반복 301 / 351 | 시간 25[s] | 손실 0.88
# | 에폭 4 |  반복 321 / 351 | 시간 27[s] | 손실 0.88
# | 에폭 4 |  반복 341 / 351 | 시간 28[s] | 손실 0.87
# Q   58+77
# T 162
# ☒ 163
# ---
# Q 461+579
# T 1139
# ☒ 1150
# ---
# Q  48+285
# T 666
# ☒ 667
# ---
# Q   551+8
# T 163
# ☒ 166
# ---
# Q  55+763
# T 422
# ☒ 429
# ---
# Q 752+006
# T 857
# ☒ 761
# ---
# Q 292+167
# T 1053
# ☒ 1054
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 869
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 8.760%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 5 |  반복 21 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 5 |  반복 41 / 351 | 시간 3[s] | 손실 0.83
# | 에폭 5 |  반복 61 / 351 | 시간 4[s] | 손실 0.82
# | 에폭 5 |  반복 81 / 351 | 시간 6[s] | 손실 0.81
# | 에폭 5 |  반복 101 / 351 | 시간 8[s] | 손실 0.80
# | 에폭 5 |  반복 121 / 351 | 시간 10[s] | 손실 0.79
# | 에폭 5 |  반복 141 / 351 | 시간 12[s] | 손실 0.77
# | 에폭 5 |  반복 161 / 351 | 시간 13[s] | 손실 0.77
# | 에폭 5 |  반복 181 / 351 | 시간 15[s] | 손실 0.77
# | 에폭 5 |  반복 201 / 351 | 시간 17[s] | 손실 0.76
# | 에폭 5 |  반복 221 / 351 | 시간 19[s] | 손실 0.75
# | 에폭 5 |  반복 241 / 351 | 시간 20[s] | 손실 0.74
# | 에폭 5 |  반복 261 / 351 | 시간 22[s] | 손실 0.73
# | 에폭 5 |  반복 281 / 351 | 시간 24[s] | 손실 0.73
# | 에폭 5 |  반복 301 / 351 | 시간 25[s] | 손실 0.73
# | 에폭 5 |  반복 321 / 351 | 시간 27[s] | 손실 0.71
# | 에폭 5 |  반복 341 / 351 | 시간 29[s] | 손실 0.71
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☒ 669
# ---
# Q   551+8
# T 163
# ☒ 160
# ---
# Q  55+763
# T 422
# ☒ 421
# ---
# Q 752+006
# T 857
# ☒ 851
# ---
# Q 292+167
# T 1053
# ☒ 1050
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 861
# ---
# Q  39+341
# T 236
# ☒ 231
# ---
# 검증 정확도 12.080%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.69
# | 에폭 6 |  반복 21 / 351 | 시간 1[s] | 손실 0.70
# | 에폭 6 |  반복 41 / 351 | 시간 3[s] | 손실 0.68
# | 에폭 6 |  반복 61 / 351 | 시간 4[s] | 손실 0.67
# | 에폭 6 |  반복 81 / 351 | 시간 6[s] | 손실 0.67
# | 에폭 6 |  반복 101 / 351 | 시간 8[s] | 손실 0.66
# | 에폭 6 |  반복 121 / 351 | 시간 9[s] | 손실 0.66
# | 에폭 6 |  반복 141 / 351 | 시간 11[s] | 손실 0.65
# | 에폭 6 |  반복 161 / 351 | 시간 13[s] | 손실 0.65
# | 에폭 6 |  반복 181 / 351 | 시간 14[s] | 손실 0.64
# | 에폭 6 |  반복 201 / 351 | 시간 16[s] | 손실 0.64
# | 에폭 6 |  반복 221 / 351 | 시간 18[s] | 손실 0.63
# | 에폭 6 |  반복 241 / 351 | 시간 21[s] | 손실 0.64
# | 에폭 6 |  반복 261 / 351 | 시간 23[s] | 손실 0.63
# | 에폭 6 |  반복 281 / 351 | 시간 25[s] | 손실 0.62
# | 에폭 6 |  반복 301 / 351 | 시간 27[s] | 손실 0.62
# | 에폭 6 |  반복 321 / 351 | 시간 29[s] | 손실 0.61
# | 에폭 6 |  반복 341 / 351 | 시간 31[s] | 손실 0.61
# Q   58+77
# T 162
# ☒ 164
# ---
# Q 461+579
# T 1139
# ☒ 1149
# ---
# Q  48+285
# T 666
# ☒ 668
# ---
# Q   551+8
# T 163
# ☒ 169
# ---
# Q  55+763
# T 422
# ☒ 420
# ---
# Q 752+006
# T 857
# ☒ 859
# ---
# Q 292+167
# T 1053
# ☒ 1050
# ---
# Q 795+038
# T 1427
# ☒ 1429
# ---
# Q  838+62
# T 864
# ☒ 861
# ---
# Q  39+341
# T 236
# ☒ 237
# ---
# 검증 정확도 17.260%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.60
# | 에폭 7 |  반복 21 / 351 | 시간 1[s] | 손실 0.60
# | 에폭 7 |  반복 41 / 351 | 시간 3[s] | 손실 0.59
# | 에폭 7 |  반복 61 / 351 | 시간 4[s] | 손실 0.59
# | 에폭 7 |  반복 81 / 351 | 시간 6[s] | 손실 0.58
# | 에폭 7 |  반복 101 / 351 | 시간 8[s] | 손실 0.57
# | 에폭 7 |  반복 121 / 351 | 시간 9[s] | 손실 0.57
# | 에폭 7 |  반복 141 / 351 | 시간 11[s] | 손실 0.57
# | 에폭 7 |  반복 161 / 351 | 시간 13[s] | 손실 0.56
# | 에폭 7 |  반복 181 / 351 | 시간 14[s] | 손실 0.55
# | 에폭 7 |  반복 201 / 351 | 시간 16[s] | 손실 0.57
# | 에폭 7 |  반복 221 / 351 | 시간 18[s] | 손실 0.55
# | 에폭 7 |  반복 241 / 351 | 시간 19[s] | 손실 0.55
# | 에폭 7 |  반복 261 / 351 | 시간 21[s] | 손실 0.53
# | 에폭 7 |  반복 281 / 351 | 시간 23[s] | 손실 0.53
# | 에폭 7 |  반복 301 / 351 | 시간 24[s] | 손실 0.53
# | 에폭 7 |  반복 321 / 351 | 시간 26[s] | 손실 0.52
# | 에폭 7 |  반복 341 / 351 | 시간 27[s] | 손실 0.51
# Q   58+77
# T 162
# ☒ 161
# ---
# Q 461+579
# T 1139
# ☒ 1141
# ---
# Q  48+285
# T 666
# ☒ 665
# ---
# Q   551+8
# T 163
# ☒ 161
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 859
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1428
# ---
# Q  838+62
# T 864
# ☒ 862
# ---
# Q  39+341
# T 236
# ☒ 235
# ---
# 검증 정확도 27.380%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.49
# | 에폭 8 |  반복 21 / 351 | 시간 1[s] | 손실 0.51
# | 에폭 8 |  반복 41 / 351 | 시간 2[s] | 손실 0.51
# | 에폭 8 |  반복 61 / 351 | 시간 4[s] | 손실 0.50
# | 에폭 8 |  반복 81 / 351 | 시간 5[s] | 손실 0.49
# | 에폭 8 |  반복 101 / 351 | 시간 7[s] | 손실 0.48
# | 에폭 8 |  반복 121 / 351 | 시간 8[s] | 손실 0.47
# | 에폭 8 |  반복 141 / 351 | 시간 10[s] | 손실 0.46
# | 에폭 8 |  반복 161 / 351 | 시간 11[s] | 손실 0.46
# | 에폭 8 |  반복 181 / 351 | 시간 13[s] | 손실 0.45
# | 에폭 8 |  반복 201 / 351 | 시간 14[s] | 손실 0.44
# | 에폭 8 |  반복 221 / 351 | 시간 16[s] | 손실 0.44
# | 에폭 8 |  반복 241 / 351 | 시간 17[s] | 손실 0.42
# | 에폭 8 |  반복 261 / 351 | 시간 19[s] | 손실 0.41
# | 에폭 8 |  반복 281 / 351 | 시간 20[s] | 손실 0.41
# | 에폭 8 |  반복 301 / 351 | 시간 22[s] | 손실 0.40
# | 에폭 8 |  반복 321 / 351 | 시간 23[s] | 손실 0.39
# | 에폭 8 |  반복 341 / 351 | 시간 24[s] | 손실 0.38
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 859
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 47.540%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.38
# | 에폭 9 |  반복 21 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 9 |  반복 41 / 351 | 시간 3[s] | 손실 0.35
# | 에폭 9 |  반복 61 / 351 | 시간 4[s] | 손실 0.34
# | 에폭 9 |  반복 81 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 9 |  반복 101 / 351 | 시간 7[s] | 손실 0.33
# | 에폭 9 |  반복 121 / 351 | 시간 9[s] | 손실 0.32
# | 에폭 9 |  반복 141 / 351 | 시간 10[s] | 손실 0.31
# | 에폭 9 |  반복 161 / 351 | 시간 12[s] | 손실 0.30
# | 에폭 9 |  반복 181 / 351 | 시간 13[s] | 손실 0.28
# | 에폭 9 |  반복 201 / 351 | 시간 15[s] | 손실 0.29
# | 에폭 9 |  반복 221 / 351 | 시간 16[s] | 손실 0.27
# | 에폭 9 |  반복 241 / 351 | 시간 18[s] | 손실 0.26
# | 에폭 9 |  반복 261 / 351 | 시간 19[s] | 손실 0.25
# | 에폭 9 |  반복 281 / 351 | 시간 21[s] | 손실 0.25
# | 에폭 9 |  반복 301 / 351 | 시간 22[s] | 손실 0.24
# | 에폭 9 |  반복 321 / 351 | 시간 24[s] | 손실 0.23
# | 에폭 9 |  반복 341 / 351 | 시간 25[s] | 손실 0.21
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 76.320%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.22
# | 에폭 10 |  반복 21 / 351 | 시간 1[s] | 손실 0.20
# | 에폭 10 |  반복 41 / 351 | 시간 3[s] | 손실 0.20
# | 에폭 10 |  반복 61 / 351 | 시간 4[s] | 손실 0.20
# | 에폭 10 |  반복 81 / 351 | 시간 6[s] | 손실 0.18
# | 에폭 10 |  반복 101 / 351 | 시간 7[s] | 손실 0.18
# | 에폭 10 |  반복 121 / 351 | 시간 9[s] | 손실 0.17
# | 에폭 10 |  반복 141 / 351 | 시간 11[s] | 손실 0.16
# | 에폭 10 |  반복 161 / 351 | 시간 12[s] | 손실 0.17
# | 에폭 10 |  반복 181 / 351 | 시간 14[s] | 손실 0.16
# | 에폭 10 |  반복 201 / 351 | 시간 15[s] | 손실 0.15
# | 에폭 10 |  반복 221 / 351 | 시간 17[s] | 손실 0.15
# | 에폭 10 |  반복 241 / 351 | 시간 19[s] | 손실 0.15
# | 에폭 10 |  반복 261 / 351 | 시간 20[s] | 손실 0.15
# | 에폭 10 |  반복 281 / 351 | 시간 22[s] | 손실 0.14
# | 에폭 10 |  반복 301 / 351 | 시간 24[s] | 손실 0.14
# | 에폭 10 |  반복 321 / 351 | 시간 26[s] | 손실 0.14
# | 에폭 10 |  반복 341 / 351 | 시간 29[s] | 손실 0.13
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☒ 1140
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 88.380%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.12
# | 에폭 11 |  반복 21 / 351 | 시간 1[s] | 손실 0.12
# | 에폭 11 |  반복 41 / 351 | 시간 3[s] | 손실 0.10
# | 에폭 11 |  반복 61 / 351 | 시간 5[s] | 손실 0.11
# | 에폭 11 |  반복 81 / 351 | 시간 6[s] | 손실 0.11
# | 에폭 11 |  반복 101 / 351 | 시간 7[s] | 손실 0.11
# | 에폭 11 |  반복 121 / 351 | 시간 9[s] | 손실 0.10
# | 에폭 11 |  반복 141 / 351 | 시간 10[s] | 손실 0.10
# | 에폭 11 |  반복 161 / 351 | 시간 12[s] | 손실 0.10
# | 에폭 11 |  반복 181 / 351 | 시간 14[s] | 손실 0.09
# | 에폭 11 |  반복 201 / 351 | 시간 15[s] | 손실 0.10
# | 에폭 11 |  반복 221 / 351 | 시간 17[s] | 손실 0.10
# | 에폭 11 |  반복 241 / 351 | 시간 18[s] | 손실 0.09
# | 에폭 11 |  반복 261 / 351 | 시간 20[s] | 손실 0.09
# | 에폭 11 |  반복 281 / 351 | 시간 21[s] | 손실 0.09
# | 에폭 11 |  반복 301 / 351 | 시간 23[s] | 손실 0.08
# | 에폭 11 |  반복 321 / 351 | 시간 24[s] | 손실 0.08
# | 에폭 11 |  반복 341 / 351 | 시간 26[s] | 손실 0.08
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 92.880%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.08
# | 에폭 12 |  반복 21 / 351 | 시간 2[s] | 손실 0.07
# | 에폭 12 |  반복 41 / 351 | 시간 3[s] | 손실 0.08
# | 에폭 12 |  반복 61 / 351 | 시간 5[s] | 손실 0.07
# | 에폭 12 |  반복 81 / 351 | 시간 6[s] | 손실 0.07
# | 에폭 12 |  반복 101 / 351 | 시간 8[s] | 손실 0.07
# | 에폭 12 |  반복 121 / 351 | 시간 9[s] | 손실 0.07
# | 에폭 12 |  반복 141 / 351 | 시간 11[s] | 손실 0.07
# | 에폭 12 |  반복 161 / 351 | 시간 13[s] | 손실 0.07
# | 에폭 12 |  반복 181 / 351 | 시간 14[s] | 손실 0.06
# | 에폭 12 |  반복 201 / 351 | 시간 16[s] | 손실 0.06
# | 에폭 12 |  반복 221 / 351 | 시간 17[s] | 손실 0.06
# | 에폭 12 |  반복 241 / 351 | 시간 19[s] | 손실 0.06
# | 에폭 12 |  반복 261 / 351 | 시간 20[s] | 손실 0.06
# | 에폭 12 |  반복 281 / 351 | 시간 22[s] | 손실 0.05
# | 에폭 12 |  반복 301 / 351 | 시간 23[s] | 손실 0.06
# | 에폭 12 |  반복 321 / 351 | 시간 25[s] | 손실 0.06
# | 에폭 12 |  반복 341 / 351 | 시간 27[s] | 손실 0.06
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 92.660%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 13 |  반복 21 / 351 | 시간 1[s] | 손실 0.06
# | 에폭 13 |  반복 41 / 351 | 시간 3[s] | 손실 0.06
# | 에폭 13 |  반복 61 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 13 |  반복 81 / 351 | 시간 6[s] | 손실 0.06
# | 에폭 13 |  반복 101 / 351 | 시간 7[s] | 손실 0.05
# | 에폭 13 |  반복 121 / 351 | 시간 9[s] | 손실 0.05
# | 에폭 13 |  반복 141 / 351 | 시간 10[s] | 손실 0.05
# | 에폭 13 |  반복 161 / 351 | 시간 12[s] | 손실 0.05
# | 에폭 13 |  반복 181 / 351 | 시간 14[s] | 손실 0.05
# | 에폭 13 |  반복 201 / 351 | 시간 15[s] | 손실 0.05
# | 에폭 13 |  반복 221 / 351 | 시간 17[s] | 손실 0.04
# | 에폭 13 |  반복 241 / 351 | 시간 18[s] | 손실 0.04
# | 에폭 13 |  반복 261 / 351 | 시간 20[s] | 손실 0.04
# | 에폭 13 |  반복 281 / 351 | 시간 22[s] | 손실 0.04
# | 에폭 13 |  반복 301 / 351 | 시간 23[s] | 손실 0.04
# | 에폭 13 |  반복 321 / 351 | 시간 25[s] | 손실 0.04
# | 에폭 13 |  반복 341 / 351 | 시간 26[s] | 손실 0.03
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 97.580%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 14 |  반복 21 / 351 | 시간 1[s] | 손실 0.03
# | 에폭 14 |  반복 41 / 351 | 시간 2[s] | 손실 0.04
# | 에폭 14 |  반복 61 / 351 | 시간 4[s] | 손실 0.03
# | 에폭 14 |  반복 81 / 351 | 시간 5[s] | 손실 0.04
# | 에폭 14 |  반복 101 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 14 |  반복 121 / 351 | 시간 8[s] | 손실 0.04
# | 에폭 14 |  반복 141 / 351 | 시간 10[s] | 손실 0.04
# | 에폭 14 |  반복 161 / 351 | 시간 11[s] | 손실 0.04
# | 에폭 14 |  반복 181 / 351 | 시간 13[s] | 손실 0.03
# | 에폭 14 |  반복 201 / 351 | 시간 15[s] | 손실 0.03
# | 에폭 14 |  반복 221 / 351 | 시간 16[s] | 손실 0.04
# | 에폭 14 |  반복 241 / 351 | 시간 18[s] | 손실 0.03
# | 에폭 14 |  반복 261 / 351 | 시간 19[s] | 손실 0.03
# | 에폭 14 |  반복 281 / 351 | 시간 21[s] | 손실 0.03
# | 에폭 14 |  반복 301 / 351 | 시간 22[s] | 손실 0.04
# | 에폭 14 |  반복 321 / 351 | 시간 24[s] | 손실 0.04
# | 에폭 14 |  반복 341 / 351 | 시간 26[s] | 손실 0.04
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 97.040%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.03
# | 에폭 15 |  반복 21 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 15 |  반복 41 / 351 | 시간 3[s] | 손실 0.03
# | 에폭 15 |  반복 61 / 351 | 시간 4[s] | 손실 0.04
# | 에폭 15 |  반복 81 / 351 | 시간 6[s] | 손실 0.03
# | 에폭 15 |  반복 101 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 15 |  반복 121 / 351 | 시간 9[s] | 손실 0.04
# | 에폭 15 |  반복 141 / 351 | 시간 10[s] | 손실 0.03
# | 에폭 15 |  반복 161 / 351 | 시간 12[s] | 손실 0.03
# | 에폭 15 |  반복 181 / 351 | 시간 13[s] | 손실 0.03
# | 에폭 15 |  반복 201 / 351 | 시간 15[s] | 손실 0.03
# | 에폭 15 |  반복 221 / 351 | 시간 16[s] | 손실 0.02
# | 에폭 15 |  반복 241 / 351 | 시간 18[s] | 손실 0.02
# | 에폭 15 |  반복 261 / 351 | 시간 19[s] | 손실 0.03
# | 에폭 15 |  반복 281 / 351 | 시간 21[s] | 손실 0.02
# | 에폭 15 |  반복 301 / 351 | 시간 22[s] | 손실 0.02
# | 에폭 15 |  반복 321 / 351 | 시간 24[s] | 손실 0.02
# | 에폭 15 |  반복 341 / 351 | 시간 25[s] | 손실 0.02
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 98.240%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.03
# | 에폭 16 |  반복 21 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 16 |  반복 41 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 16 |  반복 61 / 351 | 시간 5[s] | 손실 0.02
# | 에폭 16 |  반복 81 / 351 | 시간 6[s] | 손실 0.02
# | 에폭 16 |  반복 101 / 351 | 시간 8[s] | 손실 0.02
# | 에폭 16 |  반복 121 / 351 | 시간 9[s] | 손실 0.02
# | 에폭 16 |  반복 141 / 351 | 시간 11[s] | 손실 0.02
# | 에폭 16 |  반복 161 / 351 | 시간 12[s] | 손실 0.02
# | 에폭 16 |  반복 181 / 351 | 시간 14[s] | 손실 0.04
# | 에폭 16 |  반복 201 / 351 | 시간 15[s] | 손실 0.06
# | 에폭 16 |  반복 221 / 351 | 시간 17[s] | 손실 0.05
# | 에폭 16 |  반복 241 / 351 | 시간 18[s] | 손실 0.05
# | 에폭 16 |  반복 261 / 351 | 시간 20[s] | 손실 0.04
# | 에폭 16 |  반복 281 / 351 | 시간 22[s] | 손실 0.03
# | 에폭 16 |  반복 301 / 351 | 시간 23[s] | 손실 0.03
# | 에폭 16 |  반복 321 / 351 | 시간 25[s] | 손실 0.03
# | 에폭 16 |  반복 341 / 351 | 시간 26[s] | 손실 0.03
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 94.100%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 17 |  반복 21 / 351 | 시간 1[s] | 손실 0.03
# | 에폭 17 |  반복 41 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 17 |  반복 61 / 351 | 시간 4[s] | 손실 0.02
# | 에폭 17 |  반복 81 / 351 | 시간 6[s] | 손실 0.02
# | 에폭 17 |  반복 101 / 351 | 시간 7[s] | 손실 0.02
# | 에폭 17 |  반복 121 / 351 | 시간 9[s] | 손실 0.01
# | 에폭 17 |  반복 141 / 351 | 시간 10[s] | 손실 0.01
# | 에폭 17 |  반복 161 / 351 | 시간 12[s] | 손실 0.01
# | 에폭 17 |  반복 181 / 351 | 시간 14[s] | 손실 0.01
# | 에폭 17 |  반복 201 / 351 | 시간 16[s] | 손실 0.01
# | 에폭 17 |  반복 221 / 351 | 시간 17[s] | 손실 0.01
# | 에폭 17 |  반복 241 / 351 | 시간 19[s] | 손실 0.01
# | 에폭 17 |  반복 261 / 351 | 시간 20[s] | 손실 0.01
# | 에폭 17 |  반복 281 / 351 | 시간 22[s] | 손실 0.01
# | 에폭 17 |  반복 301 / 351 | 시간 23[s] | 손실 0.01
# | 에폭 17 |  반복 321 / 351 | 시간 25[s] | 손실 0.02
# | 에폭 17 |  반복 341 / 351 | 시간 26[s] | 손실 0.01
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 98.940%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 18 |  반복 21 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 18 |  반복 41 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 18 |  반복 61 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 18 |  반복 81 / 351 | 시간 6[s] | 손실 0.02
# | 에폭 18 |  반복 101 / 351 | 시간 7[s] | 손실 0.03
# | 에폭 18 |  반복 121 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 18 |  반복 141 / 351 | 시간 11[s] | 손실 0.04
# | 에폭 18 |  반복 161 / 351 | 시간 12[s] | 손실 0.05
# | 에폭 18 |  반복 181 / 351 | 시간 14[s] | 손실 0.06
# | 에폭 18 |  반복 201 / 351 | 시간 15[s] | 손실 0.05
# | 에폭 18 |  반복 221 / 351 | 시간 17[s] | 손실 0.04
# | 에폭 18 |  반복 241 / 351 | 시간 18[s] | 손실 0.05
# | 에폭 18 |  반복 261 / 351 | 시간 20[s] | 손실 0.04
# | 에폭 18 |  반복 281 / 351 | 시간 21[s] | 손실 0.03
# | 에폭 18 |  반복 301 / 351 | 시간 23[s] | 손실 0.02
# | 에폭 18 |  반복 321 / 351 | 시간 24[s] | 손실 0.01
# | 에폭 18 |  반복 341 / 351 | 시간 26[s] | 손실 0.01
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 98.580%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 19 |  반복 21 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 19 |  반복 41 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 19 |  반복 61 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 19 |  반복 81 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 19 |  반복 101 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 19 |  반복 121 / 351 | 시간 10[s] | 손실 0.01
# | 에폭 19 |  반복 141 / 351 | 시간 11[s] | 손실 0.01
# | 에폭 19 |  반복 161 / 351 | 시간 13[s] | 손실 0.01
# | 에폭 19 |  반복 181 / 351 | 시간 15[s] | 손실 0.01
# | 에폭 19 |  반복 201 / 351 | 시간 17[s] | 손실 0.01
# | 에폭 19 |  반복 221 / 351 | 시간 18[s] | 손실 0.01
# | 에폭 19 |  반복 241 / 351 | 시간 20[s] | 손실 0.01
# | 에폭 19 |  반복 261 / 351 | 시간 22[s] | 손실 0.01
# | 에폭 19 |  반복 281 / 351 | 시간 23[s] | 손실 0.01
# | 에폭 19 |  반복 301 / 351 | 시간 25[s] | 손실 0.01
# | 에폭 19 |  반복 321 / 351 | 시간 27[s] | 손실 0.01
# | 에폭 19 |  반복 341 / 351 | 시간 28[s] | 손실 0.01
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 99.160%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 20 |  반복 21 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 20 |  반복 41 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 20 |  반복 61 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 20 |  반복 81 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 20 |  반복 101 / 351 | 시간 9[s] | 손실 0.01
# | 에폭 20 |  반복 121 / 351 | 시간 10[s] | 손실 0.01
# | 에폭 20 |  반복 141 / 351 | 시간 12[s] | 손실 0.01
# | 에폭 20 |  반복 161 / 351 | 시간 14[s] | 손실 0.01
# | 에폭 20 |  반복 181 / 351 | 시간 15[s] | 손실 0.01
# | 에폭 20 |  반복 201 / 351 | 시간 17[s] | 손실 0.02
# | 에폭 20 |  반복 221 / 351 | 시간 19[s] | 손실 0.03
# | 에폭 20 |  반복 241 / 351 | 시간 21[s] | 손실 0.03
# | 에폭 20 |  반복 261 / 351 | 시간 22[s] | 손실 0.04
# | 에폭 20 |  반복 281 / 351 | 시간 24[s] | 손실 0.05
# | 에폭 20 |  반복 301 / 351 | 시간 25[s] | 손실 0.06
# | 에폭 20 |  반복 321 / 351 | 시간 27[s] | 손실 0.05
# | 에폭 20 |  반복 341 / 351 | 시간 29[s] | 손실 0.05
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 96.820%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.03
# | 에폭 21 |  반복 21 / 351 | 시간 1[s] | 손실 0.03
# | 에폭 21 |  반복 41 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 21 |  반복 61 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 21 |  반복 81 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 21 |  반복 101 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 21 |  반복 121 / 351 | 시간 10[s] | 손실 0.01
# | 에폭 21 |  반복 141 / 351 | 시간 12[s] | 손실 0.01
# | 에폭 21 |  반복 161 / 351 | 시간 13[s] | 손실 0.01
# | 에폭 21 |  반복 181 / 351 | 시간 15[s] | 손실 0.01
# | 에폭 21 |  반복 201 / 351 | 시간 17[s] | 손실 0.01
# | 에폭 21 |  반복 221 / 351 | 시간 18[s] | 손실 0.01
# | 에폭 21 |  반복 241 / 351 | 시간 20[s] | 손실 0.01
# | 에폭 21 |  반복 261 / 351 | 시간 22[s] | 손실 0.01
# | 에폭 21 |  반복 281 / 351 | 시간 23[s] | 손실 0.01
# | 에폭 21 |  반복 301 / 351 | 시간 25[s] | 손실 0.01
# | 에폭 21 |  반복 321 / 351 | 시간 27[s] | 손실 0.01
# | 에폭 21 |  반복 341 / 351 | 시간 28[s] | 손실 0.01
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 98.100%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 22 |  반복 21 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 22 |  반복 41 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 22 |  반복 61 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 22 |  반복 81 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 22 |  반복 101 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 22 |  반복 121 / 351 | 시간 10[s] | 손실 0.01
# | 에폭 22 |  반복 141 / 351 | 시간 12[s] | 손실 0.01
# | 에폭 22 |  반복 161 / 351 | 시간 13[s] | 손실 0.01
# | 에폭 22 |  반복 181 / 351 | 시간 15[s] | 손실 0.00
# | 에폭 22 |  반복 201 / 351 | 시간 17[s] | 손실 0.00
# | 에폭 22 |  반복 221 / 351 | 시간 19[s] | 손실 0.01
# | 에폭 22 |  반복 241 / 351 | 시간 21[s] | 손실 0.01
# | 에폭 22 |  반복 261 / 351 | 시간 23[s] | 손실 0.01
# | 에폭 22 |  반복 281 / 351 | 시간 24[s] | 손실 0.01
# | 에폭 22 |  반복 301 / 351 | 시간 26[s] | 손실 0.01
# | 에폭 22 |  반복 321 / 351 | 시간 28[s] | 손실 0.01
# | 에폭 22 |  반복 341 / 351 | 시간 29[s] | 손실 0.03
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1436
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 90.980%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 23 |  반복 21 / 351 | 시간 1[s] | 손실 0.09
# | 에폭 23 |  반복 41 / 351 | 시간 3[s] | 손실 0.08
# | 에폭 23 |  반복 61 / 351 | 시간 5[s] | 손실 0.08
# | 에폭 23 |  반복 81 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 23 |  반복 101 / 351 | 시간 8[s] | 손실 0.02
# | 에폭 23 |  반복 121 / 351 | 시간 10[s] | 손실 0.02
# | 에폭 23 |  반복 141 / 351 | 시간 12[s] | 손실 0.01
# | 에폭 23 |  반복 161 / 351 | 시간 14[s] | 손실 0.01
# | 에폭 23 |  반복 181 / 351 | 시간 15[s] | 손실 0.01
# | 에폭 23 |  반복 201 / 351 | 시간 17[s] | 손실 0.01
# | 에폭 23 |  반복 221 / 351 | 시간 19[s] | 손실 0.01
# | 에폭 23 |  반복 241 / 351 | 시간 21[s] | 손실 0.01
# | 에폭 23 |  반복 261 / 351 | 시간 23[s] | 손실 0.01
# | 에폭 23 |  반복 281 / 351 | 시간 24[s] | 손실 0.01
# | 에폭 23 |  반복 301 / 351 | 시간 26[s] | 손실 0.01
# | 에폭 23 |  반복 321 / 351 | 시간 28[s] | 손실 0.01
# | 에폭 23 |  반복 341 / 351 | 시간 30[s] | 손실 0.00
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 99.580%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 24 |  반복 21 / 351 | 시간 1[s] | 손실 0.00
# | 에폭 24 |  반복 41 / 351 | 시간 3[s] | 손실 0.00
# | 에폭 24 |  반복 61 / 351 | 시간 5[s] | 손실 0.00
# | 에폭 24 |  반복 81 / 351 | 시간 6[s] | 손실 0.00
# | 에폭 24 |  반복 101 / 351 | 시간 8[s] | 손실 0.00
# | 에폭 24 |  반복 121 / 351 | 시간 10[s] | 손실 0.00
# | 에폭 24 |  반복 141 / 351 | 시간 12[s] | 손실 0.00
# | 에폭 24 |  반복 161 / 351 | 시간 14[s] | 손실 0.00
# | 에폭 24 |  반복 181 / 351 | 시간 15[s] | 손실 0.00
# | 에폭 24 |  반복 201 / 351 | 시간 17[s] | 손실 0.00
# | 에폭 24 |  반복 221 / 351 | 시간 19[s] | 손실 0.00
# | 에폭 24 |  반복 241 / 351 | 시간 21[s] | 손실 0.00
# | 에폭 24 |  반복 261 / 351 | 시간 22[s] | 손실 0.00
# | 에폭 24 |  반복 281 / 351 | 시간 24[s] | 손실 0.00
# | 에폭 24 |  반복 301 / 351 | 시간 25[s] | 손실 0.00
# | 에폭 24 |  반복 321 / 351 | 시간 27[s] | 손실 0.00
# | 에폭 24 |  반복 341 / 351 | 시간 29[s] | 손실 0.01
# Q   58+77
# T 162
# ☑ 162
# ---
# Q 461+579
# T 1139
# ☑ 1139
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☑ 1427
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 99.500%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 25 |  반복 21 / 351 | 시간 1[s] | 손실 0.00
# | 에폭 25 |  반복 41 / 351 | 시간 3[s] | 손실 0.00
# | 에폭 25 |  반복 61 / 351 | 시간 4[s] | 손실 0.00
# | 에폭 25 |  반복 81 / 351 | 시간 6[s] | 손실 0.00
# | 에폭 25 |  반복 101 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 25 |  반복 121 / 351 | 시간 9[s] | 손실 0.01
# | 에폭 25 |  반복 141 / 351 | 시간 11[s] | 손실 0.01
# | 에폭 25 |  반복 161 / 351 | 시간 12[s] | 손실 0.01
# | 에폭 25 |  반복 181 / 351 | 시간 14[s] | 손실 0.01
# | 에폭 25 |  반복 201 / 351 | 시간 16[s] | 손실 0.01
# | 에폭 25 |  반복 221 / 351 | 시간 17[s] | 손실 0.01
# | 에폭 25 |  반복 241 / 351 | 시간 19[s] | 손실 0.01
# | 에폭 25 |  반복 261 / 351 | 시간 21[s] | 손실 0.01
# | 에폭 25 |  반복 281 / 351 | 시간 22[s] | 손실 0.01
# | 에폭 25 |  반복 301 / 351 | 시간 24[s] | 손실 0.03
# | 에폭 25 |  반복 321 / 351 | 시간 26[s] | 손실 0.03
# | 에폭 25 |  반복 341 / 351 | 시간 27[s] | 손실 0.04
# Q   58+77
# T 162
# ☒ 161
# ---
# Q 461+579
# T 1139
# ☒ 1239
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☑ 163
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☑ 857
# ---
# Q 292+167
# T 1053
# ☑ 1053
# ---
# Q 795+038
# T 1427
# ☒ 1437
# ---
# Q  838+62
# T 864
# ☑ 864
# ---
# Q  39+341
# T 236
# ☑ 236
# ---
# 검증 정확도 88.640%

# %%
plt.plot(np.arange(1,max_epoch+1), acc_list, marker='o', color='blue')
plt.plot(np.arange(1,max_epoch+1), reversed_acc_list, marker='o', color='red')
plt.plot(np.arange(1,max_epoch+1), peeky_acc_list, marker='o', color='green')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.yticks(np.arange(0.0, 1.2, 0.2))
plt.show()
